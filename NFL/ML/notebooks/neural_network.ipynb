# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
import os

# %%
parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(parent_dir)
print(parent_dir)
interpolated_dir = os.path.join(parent_dir, "dataset_interpolated_fixed")
# features = ["game_completed", "relative_strength", "score_difference", "type.id", "home_has_possession", "end.down", "end.yardsToEndzone", "end.distance", "field_position_shift", "home_timeouts_left", "away_timeouts_left"]
features = ["game_completed", "relative_strength", "score_difference", "home_has_possession", "end.down", "end.distance", "end.yardsToEndzone", "home_timeouts_left", "away_timeouts_left", "predicted_drive_points_prob_0_2pts", "predicted_drive_points_prob_3_6pts", "predicted_drive_points_prob_7plus_pts"]
# Out:
# /Users/aly/Documents/University_of_Waterloo/Winter 2025/Research/code/NFL/ML

# %%
# Reset the modules
modules_to_reload = [
    'process_data',
]

for module_name in modules_to_reload:
    if module_name in sys.modules:
        del sys.modules[module_name]

import process_data

training_data = process_data.load_data(interpolated_dir, 
                                       years = [2016, 2017,2018, 2019, 2020, 2021, 2022, 2023], 
                                       history_length = 0, 
                                       features = features, 
                                       label_feature = "home_win")

                                       
test_data = process_data.load_data(interpolated_dir, 
                                       years = [2024, 2025],
                                       history_length = 0, 
                                       features = features, 
                                       label_feature = "home_win",
                                       train = False
                                       )
# Out:
# Loading data for 2022
#   Processing 271 CSV files in parallel with 8 workers...
#   Completed processing 2022
# Loading data for 2025
# skipping  2025
# Loading data for 2024
# skipping  2024
# Loading data for 2023
#   Processing 272 CSV files in parallel with 8 workers...
#   Completed processing 2023
# Loading data for .DS_Store
# Loading data for 2017
#   Processing 254 CSV files in parallel with 8 workers...
#   Completed processing 2017
# Loading data for 2019
#   Processing 256 CSV files in parallel with 8 workers...
#   Completed processing 2019
# Loading data for 2021
#   Processing 272 CSV files in parallel with 8 workers...
#   Completed processing 2021
# Loading data for 2020
#   Processing 255 CSV files in parallel with 8 workers...
#   Completed processing 2020
# Loading data for 2018
#   Processing 255 CSV files in parallel with 8 workers...
#   Completed processing 2018
# Loading data for 2016
#   Processing 254 CSV files in parallel with 8 workers...
#   Completed processing 2016
# Loading data for 2022
# skipping  2022
# Loading data for 2025
#   Processing 272 CSV files in parallel with 8 workers...
#   Completed processing 2025
# Loading data for 2024
#   Processing 272 CSV files in parallel with 8 workers...
#   Completed processing 2024
# Loading data for 2023
# skipping  2023
# Loading data for .DS_Store
# Loading data for 2017
# skipping  2017
# Loading data for 2019
# skipping  2019
# Loading data for 2021
# skipping  2021
# Loading data for 2020
# skipping  2020
# Loading data for 2018
# skipping  2018
# Loading data for 2016
# skipping  2016

# %%
modules_to_reload = [
    'models.direct_prediction_network',
    'models.direct_prediction_network_transformer',
]

for module_name in modules_to_reload:
    if module_name in sys.modules:
        del sys.modules[module_name]

from models.direct_prediction_network import setup_direct_models
from models.direct_prediction_network_transformer import setup_direct_transformer_models


models = setup_direct_models(training_data, None, num_models = 200, features=features, optimize_hyperparams=False)
# Out:
# Range [0.000, 0.005): 3393 train, 377 validation
# Starting training on device: cpu
# Early stopping at epoch 47
# Best epoch: 37, Train Acc: 0.6920, Train Loss: 0.5812, Val Acc: 0.6790, Val Loss: 0.5911
# Restored model from best epoch 37 with val_loss: 0.591102
# NFL direct model 1/200 completed
# Range [0.005, 0.010): 1139 train, 127 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.6383, Train Loss: 0.6384, Val Acc: 0.7008, Val Loss: 0.6330
# Restored model from best epoch 3 with val_loss: 0.633029
# NFL direct model 2/200 completed
# Range [0.010, 0.015): 2235 train, 249 validation
# Starting training on device: cpu
# Early stopping at epoch 29
# Best epoch: 19, Train Acc: 0.6573, Train Loss: 0.5960, Val Acc: 0.6546, Val Loss: 0.6115
# Restored model from best epoch 19 with val_loss: 0.611514
# NFL direct model 3/200 completed
# Range [0.015, 0.020): 1883 train, 210 validation
# Starting training on device: cpu
# Early stopping at epoch 45
# Best epoch: 35, Train Acc: 0.6925, Train Loss: 0.5823, Val Acc: 0.6476, Val Loss: 0.5880
# Restored model from best epoch 35 with val_loss: 0.587972
# NFL direct model 4/200 completed
# Range [0.020, 0.025): 2074 train, 231 validation
# Starting training on device: cpu
# Early stopping at epoch 30
# Best epoch: 20, Train Acc: 0.6591, Train Loss: 0.6124, Val Acc: 0.6494, Val Loss: 0.5982
# Restored model from best epoch 20 with val_loss: 0.598167
# NFL direct model 5/200 completed
# Range [0.025, 0.030): 2161 train, 241 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.6381, Train Loss: 0.6314, Val Acc: 0.5685, Val Loss: 0.6859
# Restored model from best epoch 2 with val_loss: 0.685864
# NFL direct model 6/200 completed
# Range [0.030, 0.035): 2041 train, 227 validation
# Starting training on device: cpu
# Early stopping at epoch 39
# Best epoch: 29, Train Acc: 0.6952, Train Loss: 0.5777, Val Acc: 0.6388, Val Loss: 0.6018
# Restored model from best epoch 29 with val_loss: 0.601770
# NFL direct model 7/200 completed
# Range [0.035, 0.040): 2243 train, 250 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.6527, Train Loss: 0.6220, Val Acc: 0.6560, Val Loss: 0.6393
# Restored model from best epoch 7 with val_loss: 0.639293
# NFL direct model 8/200 completed
# Range [0.040, 0.045): 2115 train, 236 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.6615, Train Loss: 0.6340, Val Acc: 0.6483, Val Loss: 0.6104
# Restored model from best epoch 7 with val_loss: 0.610407
# NFL direct model 9/200 completed
# Range [0.045, 0.050): 2267 train, 252 validation
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 5, Train Acc: 0.6537, Train Loss: 0.6249, Val Acc: 0.6944, Val Loss: 0.6015
# Restored model from best epoch 5 with val_loss: 0.601541
# NFL direct model 10/200 completed
# Range [0.050, 0.055): 2220 train, 247 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.6419, Train Loss: 0.6373, Val Acc: 0.6316, Val Loss: 0.6280
# Restored model from best epoch 2 with val_loss: 0.628008
# NFL direct model 11/200 completed
# Range [0.055, 0.060): 2097 train, 234 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.6676, Train Loss: 0.6177, Val Acc: 0.6709, Val Loss: 0.6232
# Restored model from best epoch 3 with val_loss: 0.623190
# NFL direct model 12/200 completed
# Range [0.060, 0.065): 2318 train, 258 validation
# Starting training on device: cpu
# Early stopping at epoch 11
# Best epoch: 1, Train Acc: 0.6100, Train Loss: 0.6535, Val Acc: 0.5891, Val Loss: 0.7073
# Restored model from best epoch 1 with val_loss: 0.707332
# NFL direct model 13/200 completed
# Range [0.065, 0.070): 2241 train, 250 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.6573, Train Loss: 0.6113, Val Acc: 0.7200, Val Loss: 0.6000
# Restored model from best epoch 6 with val_loss: 0.599954
# NFL direct model 14/200 completed
# Range [0.070, 0.075): 2275 train, 253 validation
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 8, Train Acc: 0.6633, Train Loss: 0.6092, Val Acc: 0.6917, Val Loss: 0.5860
# Restored model from best epoch 8 with val_loss: 0.586036
# NFL direct model 15/200 completed
# Range [0.075, 0.080): 2212 train, 246 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.6700, Train Loss: 0.6115, Val Acc: 0.6220, Val Loss: 0.6456
# Restored model from best epoch 7 with val_loss: 0.645604
# NFL direct model 16/200 completed
# Range [0.080, 0.085): 2286 train, 255 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.6772, Train Loss: 0.6007, Val Acc: 0.6784, Val Loss: 0.5948
# Restored model from best epoch 4 with val_loss: 0.594824
# NFL direct model 17/200 completed
# Range [0.085, 0.090): 2315 train, 258 validation
# Starting training on device: cpu
# Early stopping at epoch 40
# Best epoch: 30, Train Acc: 0.7136, Train Loss: 0.5531, Val Acc: 0.7054, Val Loss: 0.4935
# Restored model from best epoch 30 with val_loss: 0.493482
# NFL direct model 18/200 completed
# Range [0.090, 0.095): 2205 train, 245 validation
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 8, Train Acc: 0.6776, Train Loss: 0.6061, Val Acc: 0.6898, Val Loss: 0.5903
# Restored model from best epoch 8 with val_loss: 0.590313
# NFL direct model 19/200 completed
# Range [0.095, 0.100): 2305 train, 257 validation
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 10, Train Acc: 0.6716, Train Loss: 0.5985, Val Acc: 0.6654, Val Loss: 0.6020
# Restored model from best epoch 10 with val_loss: 0.602035
# NFL direct model 20/200 completed
# Range [0.100, 0.105): 2294 train, 255 validation
# Starting training on device: cpu
# Early stopping at epoch 21
# Best epoch: 11, Train Acc: 0.6879, Train Loss: 0.5848, Val Acc: 0.6627, Val Loss: 0.6104
# Restored model from best epoch 11 with val_loss: 0.610371
# NFL direct model 21/200 completed
# Range [0.105, 0.110): 2244 train, 250 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.6832, Train Loss: 0.5963, Val Acc: 0.7160, Val Loss: 0.5710
# Restored model from best epoch 7 with val_loss: 0.571032
# NFL direct model 22/200 completed
# Range [0.110, 0.115): 2311 train, 257 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.6642, Train Loss: 0.6150, Val Acc: 0.6031, Val Loss: 0.5524
# Restored model from best epoch 3 with val_loss: 0.552420
# NFL direct model 23/200 completed
# Range [0.115, 0.120): 2235 train, 249 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.6613, Train Loss: 0.6109, Val Acc: 0.6586, Val Loss: 0.6028
# Restored model from best epoch 2 with val_loss: 0.602839
# NFL direct model 24/200 completed
# Range [0.120, 0.125): 2291 train, 255 validation
# Starting training on device: cpu
# Early stopping at epoch 25
# Best epoch: 15, Train Acc: 0.7010, Train Loss: 0.5676, Val Acc: 0.6627, Val Loss: 0.5782
# Restored model from best epoch 15 with val_loss: 0.578197
# NFL direct model 25/200 completed
# Range [0.125, 0.130): 2341 train, 261 validation
# Starting training on device: cpu
# Early stopping at epoch 35
# Best epoch: 25, Train Acc: 0.7142, Train Loss: 0.5419, Val Acc: 0.6820, Val Loss: 0.5403
# Restored model from best epoch 25 with val_loss: 0.540312
# NFL direct model 26/200 completed
# Range [0.130, 0.135): 2284 train, 254 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.6861, Train Loss: 0.5963, Val Acc: 0.7087, Val Loss: 0.5748
# Restored model from best epoch 3 with val_loss: 0.574833
# NFL direct model 27/200 completed
# Range [0.135, 0.140): 2243 train, 250 validation
# Starting training on device: cpu
# Early stopping at epoch 28
# Best epoch: 18, Train Acc: 0.7062, Train Loss: 0.5665, Val Acc: 0.6680, Val Loss: 0.6164
# Restored model from best epoch 18 with val_loss: 0.616374
# NFL direct model 28/200 completed
# Range [0.140, 0.145): 2242 train, 250 validation
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 10, Train Acc: 0.6994, Train Loss: 0.5771, Val Acc: 0.6800, Val Loss: 0.6278
# Restored model from best epoch 10 with val_loss: 0.627761
# NFL direct model 29/200 completed
# Range [0.145, 0.150): 2248 train, 250 validation
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 9, Train Acc: 0.7060, Train Loss: 0.5818, Val Acc: 0.6840, Val Loss: 0.5993
# Restored model from best epoch 9 with val_loss: 0.599339
# NFL direct model 30/200 completed
# Range [0.150, 0.155): 2324 train, 259 validation
# Starting training on device: cpu
# Early stopping at epoch 33
# Best epoch: 23, Train Acc: 0.7276, Train Loss: 0.5383, Val Acc: 0.7027, Val Loss: 0.5461
# Restored model from best epoch 23 with val_loss: 0.546083
# NFL direct model 31/200 completed
# Range [0.155, 0.160): 2149 train, 239 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.7101, Train Loss: 0.5725, Val Acc: 0.6527, Val Loss: 0.6171
# Restored model from best epoch 6 with val_loss: 0.617057
# NFL direct model 32/200 completed
# Range [0.160, 0.165): 2342 train, 261 validation
# Starting training on device: cpu
# Early stopping at epoch 36
# Best epoch: 26, Train Acc: 0.7314, Train Loss: 0.5255, Val Acc: 0.6897, Val Loss: 0.5927
# Restored model from best epoch 26 with val_loss: 0.592702
# NFL direct model 33/200 completed
# Range [0.165, 0.170): 2180 train, 243 validation
# Starting training on device: cpu
# Early stopping at epoch 11
# Best epoch: 1, Train Acc: 0.6234, Train Loss: 0.6421, Val Acc: 0.6584, Val Loss: 0.6213
# Restored model from best epoch 1 with val_loss: 0.621282
# NFL direct model 34/200 completed
# Range [0.170, 0.175): 2304 train, 257 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.6901, Train Loss: 0.5878, Val Acc: 0.7160, Val Loss: 0.5778
# Restored model from best epoch 4 with val_loss: 0.577801
# NFL direct model 35/200 completed
# Range [0.175, 0.180): 2300 train, 256 validation
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 10, Train Acc: 0.6948, Train Loss: 0.5764, Val Acc: 0.7109, Val Loss: 0.5683
# Restored model from best epoch 10 with val_loss: 0.568272
# NFL direct model 36/200 completed
# Range [0.180, 0.185): 2200 train, 245 validation
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 9, Train Acc: 0.7045, Train Loss: 0.5579, Val Acc: 0.7347, Val Loss: 0.5699
# Restored model from best epoch 9 with val_loss: 0.569857
# NFL direct model 37/200 completed
# Range [0.185, 0.190): 2241 train, 249 validation
# Starting training on device: cpu
# Early stopping at epoch 11
# Best epoch: 1, Train Acc: 0.6595, Train Loss: 0.6219, Val Acc: 0.6867, Val Loss: 0.5934
# Restored model from best epoch 1 with val_loss: 0.593433
# NFL direct model 38/200 completed
# Range [0.190, 0.195): 2232 train, 248 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.6882, Train Loss: 0.6024, Val Acc: 0.6855, Val Loss: 0.5889
# Restored model from best epoch 2 with val_loss: 0.588866
# NFL direct model 39/200 completed
# Range [0.195, 0.200): 2286 train, 254 validation
# Starting training on device: cpu
# Early stopping at epoch 25
# Best epoch: 15, Train Acc: 0.7353, Train Loss: 0.5354, Val Acc: 0.6339, Val Loss: 0.6026
# Restored model from best epoch 15 with val_loss: 0.602627
# NFL direct model 40/200 completed
# Range [0.200, 0.205): 2232 train, 249 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.7133, Train Loss: 0.5685, Val Acc: 0.6827, Val Loss: 0.5810
# Restored model from best epoch 7 with val_loss: 0.581041
# NFL direct model 41/200 completed
# Range [0.205, 0.210): 2255 train, 251 validation
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 8, Train Acc: 0.7011, Train Loss: 0.5630, Val Acc: 0.7371, Val Loss: 0.5450
# Restored model from best epoch 8 with val_loss: 0.544951
# NFL direct model 42/200 completed
# Range [0.210, 0.215): 2411 train, 268 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.6918, Train Loss: 0.5947, Val Acc: 0.7127, Val Loss: 0.6078
# Restored model from best epoch 2 with val_loss: 0.607771
# NFL direct model 43/200 completed
# Range [0.215, 0.220): 2185 train, 243 validation
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 5, Train Acc: 0.6920, Train Loss: 0.5829, Val Acc: 0.7037, Val Loss: 0.5255
# Restored model from best epoch 5 with val_loss: 0.525534
# NFL direct model 44/200 completed
# Range [0.220, 0.225): 2283 train, 254 validation
# Starting training on device: cpu
# Early stopping at epoch 21
# Best epoch: 11, Train Acc: 0.7262, Train Loss: 0.5440, Val Acc: 0.7520, Val Loss: 0.5129
# Restored model from best epoch 11 with val_loss: 0.512879
# NFL direct model 45/200 completed
# Range [0.225, 0.230): 2292 train, 255 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.7072, Train Loss: 0.5671, Val Acc: 0.7373, Val Loss: 0.5354
# Restored model from best epoch 4 with val_loss: 0.535404
# NFL direct model 46/200 completed
# Range [0.230, 0.235): 2232 train, 248 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.7110, Train Loss: 0.5523, Val Acc: 0.6855, Val Loss: 0.5930
# Restored model from best epoch 7 with val_loss: 0.592968
# NFL direct model 47/200 completed
# Range [0.235, 0.240): 2323 train, 259 validation
# Starting training on device: cpu
# Early stopping at epoch 23
# Best epoch: 13, Train Acc: 0.7297, Train Loss: 0.5397, Val Acc: 0.7143, Val Loss: 0.4747
# Restored model from best epoch 13 with val_loss: 0.474699
# NFL direct model 48/200 completed
# Range [0.240, 0.245): 2203 train, 245 validation
# Starting training on device: cpu
# Early stopping at epoch 23
# Best epoch: 13, Train Acc: 0.7167, Train Loss: 0.5565, Val Acc: 0.6286, Val Loss: 0.6206
# Restored model from best epoch 13 with val_loss: 0.620599
# NFL direct model 49/200 completed
# Range [0.245, 0.250): 2040 train, 227 validation
# Starting training on device: cpu
# Early stopping at epoch 22
# Best epoch: 12, Train Acc: 0.7074, Train Loss: 0.5557, Val Acc: 0.6916, Val Loss: 0.5757
# Restored model from best epoch 12 with val_loss: 0.575702
# NFL direct model 50/200 completed
# Range [0.250, 0.255): 6714 train, 746 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.7125, Train Loss: 0.5594, Val Acc: 0.7172, Val Loss: 0.5369
# Restored model from best epoch 6 with val_loss: 0.536924
# NFL direct model 51/200 completed
# Range [0.255, 0.260): 1301 train, 145 validation
# Starting training on device: cpu
# Early stopping at epoch 26
# Best epoch: 16, Train Acc: 0.7571, Train Loss: 0.5038, Val Acc: 0.7103, Val Loss: 0.5674
# Restored model from best epoch 16 with val_loss: 0.567379
# NFL direct model 52/200 completed
# Range [0.260, 0.265): 1753 train, 195 validation
# Starting training on device: cpu
# Early stopping at epoch 11
# Best epoch: 1, Train Acc: 0.6378, Train Loss: 0.6460, Val Acc: 0.6667, Val Loss: 0.6884
# Restored model from best epoch 1 with val_loss: 0.688407
# NFL direct model 53/200 completed
# Range [0.265, 0.270): 2403 train, 267 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.7245, Train Loss: 0.5483, Val Acc: 0.6629, Val Loss: 0.5367
# Restored model from best epoch 7 with val_loss: 0.536714
# NFL direct model 54/200 completed
# Range [0.270, 0.275): 2106 train, 234 validation
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 8, Train Acc: 0.7179, Train Loss: 0.5426, Val Acc: 0.7009, Val Loss: 0.5805
# Restored model from best epoch 8 with val_loss: 0.580455
# NFL direct model 55/200 completed
# Range [0.275, 0.280): 2423 train, 270 validation
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 5, Train Acc: 0.7000, Train Loss: 0.5563, Val Acc: 0.7074, Val Loss: 0.5308
# Restored model from best epoch 5 with val_loss: 0.530753
# NFL direct model 56/200 completed
# Range [0.280, 0.285): 2113 train, 235 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.7179, Train Loss: 0.5619, Val Acc: 0.6979, Val Loss: 0.5531
# Restored model from best epoch 6 with val_loss: 0.553147
# NFL direct model 57/200 completed
# Range [0.285, 0.290): 2479 train, 276 validation
# Starting training on device: cpu
# Early stopping at epoch 26
# Best epoch: 16, Train Acc: 0.7398, Train Loss: 0.5144, Val Acc: 0.7246, Val Loss: 0.5247
# Restored model from best epoch 16 with val_loss: 0.524678
# NFL direct model 58/200 completed
# Range [0.290, 0.295): 2220 train, 247 validation
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 9, Train Acc: 0.7081, Train Loss: 0.5474, Val Acc: 0.7045, Val Loss: 0.5322
# Restored model from best epoch 9 with val_loss: 0.532174
# NFL direct model 59/200 completed
# Range [0.295, 0.300): 2266 train, 252 validation
# Starting training on device: cpu
# Early stopping at epoch 28
# Best epoch: 18, Train Acc: 0.7480, Train Loss: 0.5067, Val Acc: 0.6984, Val Loss: 0.5641
# Restored model from best epoch 18 with val_loss: 0.564093
# NFL direct model 60/200 completed
# Range [0.300, 0.305): 2277 train, 254 validation
# Starting training on device: cpu
# Early stopping at epoch 36
# Best epoch: 26, Train Acc: 0.7532, Train Loss: 0.4852, Val Acc: 0.7126, Val Loss: 0.5248
# Restored model from best epoch 26 with val_loss: 0.524835
# NFL direct model 61/200 completed
# Range [0.305, 0.310): 2205 train, 245 validation
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 5, Train Acc: 0.7274, Train Loss: 0.5449, Val Acc: 0.7224, Val Loss: 0.5375
# Restored model from best epoch 5 with val_loss: 0.537462
# NFL direct model 62/200 completed
# Range [0.310, 0.315): 2309 train, 257 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.7285, Train Loss: 0.5508, Val Acc: 0.7393, Val Loss: 0.5208
# Restored model from best epoch 4 with val_loss: 0.520775
# NFL direct model 63/200 completed
# Range [0.315, 0.320): 2282 train, 254 validation
# Starting training on device: cpu
# Early stopping at epoch 27
# Best epoch: 17, Train Acc: 0.7463, Train Loss: 0.5108, Val Acc: 0.7598, Val Loss: 0.4699
# Restored model from best epoch 17 with val_loss: 0.469935
# NFL direct model 64/200 completed
# Range [0.320, 0.325): 2301 train, 256 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.7032, Train Loss: 0.5648, Val Acc: 0.7422, Val Loss: 0.5331
# Restored model from best epoch 2 with val_loss: 0.533131
# NFL direct model 65/200 completed
# Range [0.325, 0.330): 2222 train, 247 validation
# Starting training on device: cpu
# Early stopping at epoch 11
# Best epoch: 1, Train Acc: 0.6598, Train Loss: 0.6148, Val Acc: 0.6964, Val Loss: 0.5653
# Restored model from best epoch 1 with val_loss: 0.565283
# NFL direct model 66/200 completed
# Range [0.330, 0.335): 2290 train, 255 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.7336, Train Loss: 0.5260, Val Acc: 0.7176, Val Loss: 0.5622
# Restored model from best epoch 7 with val_loss: 0.562239
# NFL direct model 67/200 completed
# Range [0.335, 0.340): 2318 train, 258 validation
# Starting training on device: cpu
# Early stopping at epoch 31
# Best epoch: 21, Train Acc: 0.7649, Train Loss: 0.4911, Val Acc: 0.7093, Val Loss: 0.4735
# Restored model from best epoch 21 with val_loss: 0.473502
# NFL direct model 68/200 completed
# Range [0.340, 0.345): 2279 train, 254 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.7345, Train Loss: 0.5334, Val Acc: 0.7283, Val Loss: 0.5278
# Restored model from best epoch 4 with val_loss: 0.527798
# NFL direct model 69/200 completed
# Range [0.345, 0.350): 2349 train, 262 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.7305, Train Loss: 0.5387, Val Acc: 0.7176, Val Loss: 0.5928
# Restored model from best epoch 3 with val_loss: 0.592763
# NFL direct model 70/200 completed
# Range [0.350, 0.355): 2272 train, 253 validation
# Starting training on device: cpu
# Early stopping at epoch 30
# Best epoch: 20, Train Acc: 0.7746, Train Loss: 0.4736, Val Acc: 0.7470, Val Loss: 0.5648
# Restored model from best epoch 20 with val_loss: 0.564767
# NFL direct model 71/200 completed
# Range [0.355, 0.360): 2321 train, 258 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.7346, Train Loss: 0.5174, Val Acc: 0.7093, Val Loss: 0.4873
# Restored model from best epoch 6 with val_loss: 0.487323
# NFL direct model 72/200 completed
# Range [0.360, 0.365): 2238 train, 249 validation
# Starting training on device: cpu
# Early stopping at epoch 26
# Best epoch: 16, Train Acc: 0.7551, Train Loss: 0.4976, Val Acc: 0.7430, Val Loss: 0.5311
# Restored model from best epoch 16 with val_loss: 0.531084
# NFL direct model 73/200 completed
# Range [0.365, 0.370): 2331 train, 259 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.7169, Train Loss: 0.5654, Val Acc: 0.7568, Val Loss: 0.4632
# Restored model from best epoch 2 with val_loss: 0.463162
# NFL direct model 74/200 completed
# Range [0.370, 0.375): 2235 train, 249 validation
# Starting training on device: cpu
# Early stopping at epoch 37
# Best epoch: 27, Train Acc: 0.7924, Train Loss: 0.4464, Val Acc: 0.7390, Val Loss: 0.5104
# Restored model from best epoch 27 with val_loss: 0.510368
# NFL direct model 75/200 completed
# Range [0.375, 0.380): 2330 train, 259 validation
# Starting training on device: cpu
# Early stopping at epoch 24
# Best epoch: 14, Train Acc: 0.7519, Train Loss: 0.4968, Val Acc: 0.7452, Val Loss: 0.5704
# Restored model from best epoch 14 with val_loss: 0.570415
# NFL direct model 76/200 completed
# Range [0.380, 0.385): 2268 train, 252 validation
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 8, Train Acc: 0.7496, Train Loss: 0.5151, Val Acc: 0.7659, Val Loss: 0.4661
# Restored model from best epoch 8 with val_loss: 0.466137
# NFL direct model 77/200 completed
# Range [0.385, 0.390): 2271 train, 253 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.7384, Train Loss: 0.5219, Val Acc: 0.7470, Val Loss: 0.5174
# Restored model from best epoch 7 with val_loss: 0.517450
# NFL direct model 78/200 completed
# Range [0.390, 0.395): 2249 train, 250 validation
# Starting training on device: cpu
# Early stopping at epoch 39
# Best epoch: 29, Train Acc: 0.7763, Train Loss: 0.4461, Val Acc: 0.7240, Val Loss: 0.4922
# Restored model from best epoch 29 with val_loss: 0.492239
# NFL direct model 79/200 completed
# Range [0.395, 0.400): 2289 train, 255 validation
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 9, Train Acc: 0.7492, Train Loss: 0.5125, Val Acc: 0.7059, Val Loss: 0.5569
# Restored model from best epoch 9 with val_loss: 0.556940
# NFL direct model 80/200 completed
# Range [0.400, 0.405): 2264 train, 252 validation
# Starting training on device: cpu
# Early stopping at epoch 28
# Best epoch: 18, Train Acc: 0.7694, Train Loss: 0.4807, Val Acc: 0.7698, Val Loss: 0.4958
# Restored model from best epoch 18 with val_loss: 0.495779
# NFL direct model 81/200 completed
# Range [0.405, 0.410): 2164 train, 241 validation
# Starting training on device: cpu
# Early stopping at epoch 29
# Best epoch: 19, Train Acc: 0.7768, Train Loss: 0.4572, Val Acc: 0.7718, Val Loss: 0.4954
# Restored model from best epoch 19 with val_loss: 0.495450
# NFL direct model 82/200 completed
# Range [0.410, 0.415): 2355 train, 262 validation
# Starting training on device: cpu
# Early stopping at epoch 31
# Best epoch: 21, Train Acc: 0.7715, Train Loss: 0.4730, Val Acc: 0.7634, Val Loss: 0.4813
# Restored model from best epoch 21 with val_loss: 0.481284
# NFL direct model 83/200 completed
# Range [0.415, 0.420): 2241 train, 250 validation
# Starting training on device: cpu
# Early stopping at epoch 21
# Best epoch: 11, Train Acc: 0.7599, Train Loss: 0.5269, Val Acc: 0.7000, Val Loss: 0.5565
# Restored model from best epoch 11 with val_loss: 0.556535
# NFL direct model 84/200 completed
# Range [0.420, 0.425): 2340 train, 261 validation
# Starting training on device: cpu
# Early stopping at epoch 23
# Best epoch: 13, Train Acc: 0.7573, Train Loss: 0.4955, Val Acc: 0.7931, Val Loss: 0.4657
# Restored model from best epoch 13 with val_loss: 0.465682
# NFL direct model 85/200 completed
# Range [0.425, 0.430): 2313 train, 258 validation
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 5, Train Acc: 0.7648, Train Loss: 0.4949, Val Acc: 0.7326, Val Loss: 0.5016
# Restored model from best epoch 5 with val_loss: 0.501647
# NFL direct model 86/200 completed
# Range [0.430, 0.435): 2240 train, 249 validation
# Starting training on device: cpu
# Early stopping at epoch 23
# Best epoch: 13, Train Acc: 0.7674, Train Loss: 0.4794, Val Acc: 0.7349, Val Loss: 0.4985
# Restored model from best epoch 13 with val_loss: 0.498501
# NFL direct model 87/200 completed
# Range [0.435, 0.440): 2331 train, 259 validation
# Starting training on device: cpu
# Early stopping at epoch 32
# Best epoch: 22, Train Acc: 0.7906, Train Loss: 0.4664, Val Acc: 0.7375, Val Loss: 0.4980
# Restored model from best epoch 22 with val_loss: 0.497953
# NFL direct model 88/200 completed
# Range [0.440, 0.445): 2250 train, 250 validation
# Starting training on device: cpu
# Early stopping at epoch 11
# Best epoch: 1, Train Acc: 0.6671, Train Loss: 0.6055, Val Acc: 0.7640, Val Loss: 0.5036
# Restored model from best epoch 1 with val_loss: 0.503574
# NFL direct model 89/200 completed
# Range [0.445, 0.450): 2328 train, 259 validation
# Starting training on device: cpu
# Early stopping at epoch 29
# Best epoch: 19, Train Acc: 0.7736, Train Loss: 0.4637, Val Acc: 0.7838, Val Loss: 0.4789
# Restored model from best epoch 19 with val_loss: 0.478858
# NFL direct model 90/200 completed
# Range [0.450, 0.455): 2286 train, 255 validation
# Starting training on device: cpu
# Early stopping at epoch 30
# Best epoch: 20, Train Acc: 0.7835, Train Loss: 0.4614, Val Acc: 0.7569, Val Loss: 0.4857
# Restored model from best epoch 20 with val_loss: 0.485711
# NFL direct model 91/200 completed
# Range [0.455, 0.460): 2288 train, 255 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.7513, Train Loss: 0.5106, Val Acc: 0.7490, Val Loss: 0.5076
# Restored model from best epoch 4 with val_loss: 0.507636
# NFL direct model 92/200 completed
# Range [0.460, 0.465): 2358 train, 263 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.7549, Train Loss: 0.5107, Val Acc: 0.7567, Val Loss: 0.5389
# Restored model from best epoch 2 with val_loss: 0.538864
# NFL direct model 93/200 completed
# Range [0.465, 0.470): 2157 train, 240 validation
# Starting training on device: cpu
# Early stopping at epoch 25
# Best epoch: 15, Train Acc: 0.7928, Train Loss: 0.4416, Val Acc: 0.7292, Val Loss: 0.5002
# Restored model from best epoch 15 with val_loss: 0.500156
# NFL direct model 94/200 completed
# Range [0.470, 0.475): 6358 train, 707 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.7675, Train Loss: 0.4939, Val Acc: 0.7694, Val Loss: 0.5047
# Restored model from best epoch 3 with val_loss: 0.504655
# NFL direct model 95/200 completed
# Range [0.475, 0.480): 3238 train, 360 validation
# Starting training on device: cpu
# Early stopping at epoch 22
# Best epoch: 12, Train Acc: 0.7832, Train Loss: 0.4468, Val Acc: 0.7556, Val Loss: 0.4593
# Restored model from best epoch 12 with val_loss: 0.459277
# NFL direct model 96/200 completed
# Range [0.480, 0.485): 3429 train, 381 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.7792, Train Loss: 0.4658, Val Acc: 0.7585, Val Loss: 0.4992
# Restored model from best epoch 6 with val_loss: 0.499201
# NFL direct model 97/200 completed
# Range [0.485, 0.490): 3904 train, 434 validation
# Starting training on device: cpu
# Early stopping at epoch 43
# Best epoch: 33, Train Acc: 0.8097, Train Loss: 0.3846, Val Acc: 0.7719, Val Loss: 0.4666
# Restored model from best epoch 33 with val_loss: 0.466554
# NFL direct model 98/200 completed
# Range [0.490, 0.495): 4725 train, 525 validation
# Starting training on device: cpu
# Early stopping at epoch 30
# Best epoch: 20, Train Acc: 0.8002, Train Loss: 0.4160, Val Acc: 0.8152, Val Loss: 0.4356
# Restored model from best epoch 20 with val_loss: 0.435624
# NFL direct model 99/200 completed
# Range [0.495, 0.500): 5760 train, 641 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.7825, Train Loss: 0.4674, Val Acc: 0.7894, Val Loss: 0.5468
# Restored model from best epoch 6 with val_loss: 0.546764
# NFL direct model 100/200 completed
# Range [0.500, 0.505): 10401 train, 1156 validation
# Starting training on device: cpu
# Early stopping at epoch 22
# Best epoch: 12, Train Acc: 0.7861, Train Loss: 0.4521, Val Acc: 0.7907, Val Loss: 0.4475
# Restored model from best epoch 12 with val_loss: 0.447468
# NFL direct model 101/200 completed
# Range [0.505, 0.510): 1260 train, 140 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.7968, Train Loss: 0.4372, Val Acc: 0.8000, Val Loss: 0.3740
# Restored model from best epoch 6 with val_loss: 0.373954
# NFL direct model 102/200 completed
# Range [0.510, 0.515): 2133 train, 238 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.7937, Train Loss: 0.4492, Val Acc: 0.7857, Val Loss: 0.4597
# Restored model from best epoch 6 with val_loss: 0.459658
# NFL direct model 103/200 completed
# Range [0.515, 0.520): 1874 train, 209 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.7844, Train Loss: 0.4716, Val Acc: 0.8038, Val Loss: 0.4194
# Restored model from best epoch 4 with val_loss: 0.419409
# NFL direct model 104/200 completed
# Range [0.520, 0.525): 2118 train, 236 validation
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 10, Train Acc: 0.7809, Train Loss: 0.4609, Val Acc: 0.7881, Val Loss: 0.4579
# Restored model from best epoch 10 with val_loss: 0.457862
# NFL direct model 105/200 completed
# Range [0.525, 0.530): 2259 train, 251 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.7840, Train Loss: 0.4614, Val Acc: 0.8127, Val Loss: 0.4305
# Restored model from best epoch 3 with val_loss: 0.430482
# NFL direct model 106/200 completed
# Range [0.530, 0.535): 2111 train, 235 validation
# Starting training on device: cpu
# Early stopping at epoch 34
# Best epoch: 24, Train Acc: 0.8072, Train Loss: 0.4246, Val Acc: 0.8043, Val Loss: 0.4146
# Restored model from best epoch 24 with val_loss: 0.414617
# NFL direct model 107/200 completed
# Range [0.535, 0.540): 2259 train, 251 validation
# Starting training on device: cpu
# Early stopping at epoch 28
# Best epoch: 18, Train Acc: 0.8092, Train Loss: 0.4056, Val Acc: 0.8287, Val Loss: 0.3841
# Restored model from best epoch 18 with val_loss: 0.384055
# NFL direct model 108/200 completed
# Range [0.540, 0.545): 2178 train, 242 validation
# Starting training on device: cpu
# Early stopping at epoch 23
# Best epoch: 13, Train Acc: 0.7920, Train Loss: 0.4355, Val Acc: 0.8058, Val Loss: 0.4375
# Restored model from best epoch 13 with val_loss: 0.437525
# NFL direct model 109/200 completed
# Range [0.545, 0.550): 2151 train, 239 validation
# Starting training on device: cpu
# Early stopping at epoch 43
# Best epoch: 33, Train Acc: 0.8187, Train Loss: 0.4011, Val Acc: 0.7908, Val Loss: 0.4213
# Restored model from best epoch 33 with val_loss: 0.421347
# NFL direct model 110/200 completed
# Range [0.550, 0.555): 2219 train, 247 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.7796, Train Loss: 0.4617, Val Acc: 0.8259, Val Loss: 0.3897
# Restored model from best epoch 3 with val_loss: 0.389715
# NFL direct model 111/200 completed
# Range [0.555, 0.560): 2216 train, 247 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.7951, Train Loss: 0.4566, Val Acc: 0.7652, Val Loss: 0.4612
# Restored model from best epoch 3 with val_loss: 0.461215
# NFL direct model 112/200 completed
# Range [0.560, 0.565): 2277 train, 253 validation
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 10, Train Acc: 0.8006, Train Loss: 0.4286, Val Acc: 0.8063, Val Loss: 0.4443
# Restored model from best epoch 10 with val_loss: 0.444270
# NFL direct model 113/200 completed
# Range [0.565, 0.570): 2237 train, 249 validation
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 9, Train Acc: 0.7908, Train Loss: 0.4289, Val Acc: 0.8153, Val Loss: 0.4078
# Restored model from best epoch 9 with val_loss: 0.407782
# NFL direct model 114/200 completed
# Range [0.570, 0.575): 2301 train, 256 validation
# Starting training on device: cpu
# Early stopping at epoch 28
# Best epoch: 18, Train Acc: 0.8140, Train Loss: 0.3992, Val Acc: 0.7891, Val Loss: 0.4214
# Restored model from best epoch 18 with val_loss: 0.421438
# NFL direct model 115/200 completed
# Range [0.575, 0.580): 2301 train, 256 validation
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 10, Train Acc: 0.7905, Train Loss: 0.4362, Val Acc: 0.7617, Val Loss: 0.4544
# Restored model from best epoch 10 with val_loss: 0.454411
# NFL direct model 116/200 completed
# Range [0.580, 0.585): 2237 train, 249 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.7725, Train Loss: 0.4647, Val Acc: 0.7952, Val Loss: 0.4450
# Restored model from best epoch 3 with val_loss: 0.445031
# NFL direct model 117/200 completed
# Range [0.585, 0.590): 2281 train, 254 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.8053, Train Loss: 0.4274, Val Acc: 0.7953, Val Loss: 0.4253
# Restored model from best epoch 7 with val_loss: 0.425263
# NFL direct model 118/200 completed
# Range [0.590, 0.595): 2366 train, 263 validation
# Starting training on device: cpu
# Early stopping at epoch 38
# Best epoch: 28, Train Acc: 0.8191, Train Loss: 0.3870, Val Acc: 0.7871, Val Loss: 0.4736
# Restored model from best epoch 28 with val_loss: 0.473577
# NFL direct model 119/200 completed
# Range [0.595, 0.600): 2289 train, 255 validation
# Starting training on device: cpu
# Early stopping at epoch 25
# Best epoch: 15, Train Acc: 0.8196, Train Loss: 0.3981, Val Acc: 0.7490, Val Loss: 0.4422
# Restored model from best epoch 15 with val_loss: 0.442206
# NFL direct model 120/200 completed
# Range [0.600, 0.605): 2282 train, 254 validation
# Starting training on device: cpu
# Early stopping at epoch 31
# Best epoch: 21, Train Acc: 0.8089, Train Loss: 0.4041, Val Acc: 0.7992, Val Loss: 0.3956
# Restored model from best epoch 21 with val_loss: 0.395604
# NFL direct model 121/200 completed
# Range [0.605, 0.610): 2314 train, 258 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.7921, Train Loss: 0.4421, Val Acc: 0.7946, Val Loss: 0.4806
# Restored model from best epoch 3 with val_loss: 0.480631
# NFL direct model 122/200 completed
# Range [0.610, 0.615): 2331 train, 260 validation
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 9, Train Acc: 0.8061, Train Loss: 0.4199, Val Acc: 0.7923, Val Loss: 0.4921
# Restored model from best epoch 9 with val_loss: 0.492147
# NFL direct model 123/200 completed
# Range [0.615, 0.620): 2274 train, 253 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.8034, Train Loss: 0.4267, Val Acc: 0.7945, Val Loss: 0.4644
# Restored model from best epoch 4 with val_loss: 0.464374
# NFL direct model 124/200 completed
# Range [0.620, 0.625): 2240 train, 249 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.7826, Train Loss: 0.4654, Val Acc: 0.7711, Val Loss: 0.4794
# Restored model from best epoch 2 with val_loss: 0.479386
# NFL direct model 125/200 completed
# Range [0.625, 0.630): 2330 train, 259 validation
# Starting training on device: cpu
# Early stopping at epoch 27
# Best epoch: 17, Train Acc: 0.8210, Train Loss: 0.3957, Val Acc: 0.7954, Val Loss: 0.3780
# Restored model from best epoch 17 with val_loss: 0.378014
# NFL direct model 126/200 completed
# Range [0.630, 0.635): 2313 train, 257 validation
# Starting training on device: cpu
# Early stopping at epoch 34
# Best epoch: 24, Train Acc: 0.8340, Train Loss: 0.3681, Val Acc: 0.8054, Val Loss: 0.3505
# Restored model from best epoch 24 with val_loss: 0.350539
# NFL direct model 127/200 completed
# Range [0.635, 0.640): 2301 train, 256 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.7983, Train Loss: 0.4374, Val Acc: 0.8203, Val Loss: 0.4245
# Restored model from best epoch 4 with val_loss: 0.424456
# NFL direct model 128/200 completed
# Range [0.640, 0.645): 2157 train, 240 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.8062, Train Loss: 0.4230, Val Acc: 0.7708, Val Loss: 0.4331
# Restored model from best epoch 6 with val_loss: 0.433070
# NFL direct model 129/200 completed
# Range [0.645, 0.650): 2348 train, 261 validation
# Starting training on device: cpu
# Early stopping at epoch 29
# Best epoch: 19, Train Acc: 0.8207, Train Loss: 0.3841, Val Acc: 0.8161, Val Loss: 0.4331
# Restored model from best epoch 19 with val_loss: 0.433072
# NFL direct model 130/200 completed
# Range [0.650, 0.655): 2275 train, 253 validation
# Starting training on device: cpu
# Early stopping at epoch 37
# Best epoch: 27, Train Acc: 0.8303, Train Loss: 0.3656, Val Acc: 0.8458, Val Loss: 0.3564
# Restored model from best epoch 27 with val_loss: 0.356413
# NFL direct model 131/200 completed
# Range [0.655, 0.660): 2324 train, 259 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.7930, Train Loss: 0.4434, Val Acc: 0.8340, Val Loss: 0.3302
# Restored model from best epoch 2 with val_loss: 0.330158
# NFL direct model 132/200 completed
# Range [0.660, 0.665): 2313 train, 258 validation
# Starting training on device: cpu
# Early stopping at epoch 22
# Best epoch: 12, Train Acc: 0.8188, Train Loss: 0.3885, Val Acc: 0.8023, Val Loss: 0.3355
# Restored model from best epoch 12 with val_loss: 0.335482
# NFL direct model 133/200 completed
# Range [0.665, 0.670): 2284 train, 254 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.7942, Train Loss: 0.4337, Val Acc: 0.8189, Val Loss: 0.3827
# Restored model from best epoch 2 with val_loss: 0.382664
# NFL direct model 134/200 completed
# Range [0.670, 0.675): 2227 train, 248 validation
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 5, Train Acc: 0.8307, Train Loss: 0.3973, Val Acc: 0.7621, Val Loss: 0.4876
# Restored model from best epoch 5 with val_loss: 0.487615
# NFL direct model 135/200 completed
# Range [0.675, 0.680): 2290 train, 255 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.8131, Train Loss: 0.4093, Val Acc: 0.8275, Val Loss: 0.3768
# Restored model from best epoch 7 with val_loss: 0.376826
# NFL direct model 136/200 completed
# Range [0.680, 0.685): 2250 train, 250 validation
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 8, Train Acc: 0.8084, Train Loss: 0.4112, Val Acc: 0.8240, Val Loss: 0.3945
# Restored model from best epoch 8 with val_loss: 0.394543
# NFL direct model 137/200 completed
# Range [0.685, 0.690): 2367 train, 263 validation
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 5, Train Acc: 0.8179, Train Loss: 0.3911, Val Acc: 0.8251, Val Loss: 0.3640
# Restored model from best epoch 5 with val_loss: 0.363994
# NFL direct model 138/200 completed
# Range [0.690, 0.695): 2286 train, 254 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.8224, Train Loss: 0.4028, Val Acc: 0.7913, Val Loss: 0.4242
# Restored model from best epoch 4 with val_loss: 0.424165
# NFL direct model 139/200 completed
# Range [0.695, 0.700): 2281 train, 254 validation
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 5, Train Acc: 0.8242, Train Loss: 0.3882, Val Acc: 0.8661, Val Loss: 0.3293
# Restored model from best epoch 5 with val_loss: 0.329314
# NFL direct model 140/200 completed
# Range [0.700, 0.705): 2325 train, 259 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.8168, Train Loss: 0.4107, Val Acc: 0.8185, Val Loss: 0.3503
# Restored model from best epoch 3 with val_loss: 0.350304
# NFL direct model 141/200 completed
# Range [0.705, 0.710): 2234 train, 249 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.8214, Train Loss: 0.3973, Val Acc: 0.8394, Val Loss: 0.3840
# Restored model from best epoch 4 with val_loss: 0.384047
# NFL direct model 142/200 completed
# Range [0.710, 0.715): 2225 train, 248 validation
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 5, Train Acc: 0.8198, Train Loss: 0.3963, Val Acc: 0.8347, Val Loss: 0.3540
# Restored model from best epoch 5 with val_loss: 0.353994
# NFL direct model 143/200 completed
# Range [0.715, 0.720): 2320 train, 258 validation
# Starting training on device: cpu
# Early stopping at epoch 27
# Best epoch: 17, Train Acc: 0.8250, Train Loss: 0.3718, Val Acc: 0.8488, Val Loss: 0.2903
# Restored model from best epoch 17 with val_loss: 0.290252
# NFL direct model 144/200 completed
# Range [0.720, 0.725): 2279 train, 254 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.8302, Train Loss: 0.3807, Val Acc: 0.8622, Val Loss: 0.2899
# Restored model from best epoch 6 with val_loss: 0.289941
# NFL direct model 145/200 completed
# Range [0.725, 0.730): 2308 train, 257 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.8094, Train Loss: 0.4231, Val Acc: 0.8327, Val Loss: 0.7045
# Restored model from best epoch 2 with val_loss: 0.704503
# NFL direct model 146/200 completed
# Range [0.730, 0.735): 2313 train, 258 validation
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 9, Train Acc: 0.8245, Train Loss: 0.3675, Val Acc: 0.8101, Val Loss: 0.4528
# Restored model from best epoch 9 with val_loss: 0.452802
# NFL direct model 147/200 completed
# Range [0.735, 0.740): 2269 train, 253 validation
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 10, Train Acc: 0.8233, Train Loss: 0.3615, Val Acc: 0.8221, Val Loss: 0.3859
# Restored model from best epoch 10 with val_loss: 0.385916
# NFL direct model 148/200 completed
# Range [0.740, 0.745): 2125 train, 237 validation
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 9, Train Acc: 0.8362, Train Loss: 0.3554, Val Acc: 0.8523, Val Loss: 0.3288
# Restored model from best epoch 9 with val_loss: 0.328843
# NFL direct model 149/200 completed
# Range [0.745, 0.750): 2034 train, 226 validation
# Starting training on device: cpu
# Early stopping at epoch 24
# Best epoch: 14, Train Acc: 0.8446, Train Loss: 0.3479, Val Acc: 0.7876, Val Loss: 0.4448
# Restored model from best epoch 14 with val_loss: 0.444768
# NFL direct model 150/200 completed
# Range [0.750, 0.755): 6573 train, 731 validation
# Starting training on device: cpu
# Early stopping at epoch 36
# Best epoch: 26, Train Acc: 0.8587, Train Loss: 0.3153, Val Acc: 0.8317, Val Loss: 0.3419
# Restored model from best epoch 26 with val_loss: 0.341903
# NFL direct model 151/200 completed
# Range [0.755, 0.760): 1322 train, 147 validation
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 8, Train Acc: 0.8616, Train Loss: 0.3300, Val Acc: 0.8299, Val Loss: 0.3319
# Restored model from best epoch 8 with val_loss: 0.331949
# NFL direct model 152/200 completed
# Range [0.760, 0.765): 1754 train, 195 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.8170, Train Loss: 0.4146, Val Acc: 0.8615, Val Loss: 0.4910
# Restored model from best epoch 2 with val_loss: 0.490984
# NFL direct model 153/200 completed
# Range [0.765, 0.770): 2401 train, 267 validation
# Starting training on device: cpu
# Early stopping at epoch 35
# Best epoch: 25, Train Acc: 0.8755, Train Loss: 0.2921, Val Acc: 0.8165, Val Loss: 0.4178
# Restored model from best epoch 25 with val_loss: 0.417807
# NFL direct model 154/200 completed
# Range [0.770, 0.775): 2061 train, 229 validation
# Starting training on device: cpu
# Early stopping at epoch 23
# Best epoch: 13, Train Acc: 0.8389, Train Loss: 0.3538, Val Acc: 0.8472, Val Loss: 0.3050
# Restored model from best epoch 13 with val_loss: 0.305041
# NFL direct model 155/200 completed
# Range [0.775, 0.780): 2549 train, 284 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.8215, Train Loss: 0.4022, Val Acc: 0.8627, Val Loss: 0.3568
# Restored model from best epoch 2 with val_loss: 0.356760
# NFL direct model 156/200 completed
# Range [0.780, 0.785): 2151 train, 239 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.8377, Train Loss: 0.3520, Val Acc: 0.8410, Val Loss: 0.3178
# Restored model from best epoch 7 with val_loss: 0.317821
# NFL direct model 157/200 completed
# Range [0.785, 0.790): 2360 train, 263 validation
# Starting training on device: cpu
# Early stopping at epoch 11
# Best epoch: 1, Train Acc: 0.7449, Train Loss: 0.5272, Val Acc: 0.8175, Val Loss: 0.3635
# Restored model from best epoch 1 with val_loss: 0.363488
# NFL direct model 158/200 completed
# Range [0.790, 0.795): 2230 train, 248 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.8641, Train Loss: 0.3214, Val Acc: 0.8871, Val Loss: 0.2990
# Restored model from best epoch 6 with val_loss: 0.299043
# NFL direct model 159/200 completed
# Range [0.795, 0.800): 2209 train, 246 validation
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 9, Train Acc: 0.8438, Train Loss: 0.3494, Val Acc: 0.8252, Val Loss: 0.3522
# Restored model from best epoch 9 with val_loss: 0.352156
# NFL direct model 160/200 completed
# Range [0.800, 0.805): 2426 train, 270 validation
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 9, Train Acc: 0.8681, Train Loss: 0.3173, Val Acc: 0.8667, Val Loss: 0.3583
# Restored model from best epoch 9 with val_loss: 0.358330
# NFL direct model 161/200 completed
# Range [0.805, 0.810): 2327 train, 259 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.8479, Train Loss: 0.3409, Val Acc: 0.8610, Val Loss: 0.3251
# Restored model from best epoch 6 with val_loss: 0.325135
# NFL direct model 162/200 completed
# Range [0.810, 0.815): 2333 train, 260 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.8393, Train Loss: 0.3699, Val Acc: 0.8538, Val Loss: 0.3391
# Restored model from best epoch 3 with val_loss: 0.339065
# NFL direct model 163/200 completed
# Range [0.815, 0.820): 2313 train, 258 validation
# Starting training on device: cpu
# Early stopping at epoch 29
# Best epoch: 19, Train Acc: 0.8569, Train Loss: 0.2944, Val Acc: 0.8605, Val Loss: 0.2691
# Restored model from best epoch 19 with val_loss: 0.269139
# NFL direct model 164/200 completed
# Range [0.820, 0.825): 2359 train, 263 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.8326, Train Loss: 0.3647, Val Acc: 0.7985, Val Loss: 0.5026
# Restored model from best epoch 3 with val_loss: 0.502559
# NFL direct model 165/200 completed
# Range [0.825, 0.830): 2249 train, 250 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.8426, Train Loss: 0.3876, Val Acc: 0.7960, Val Loss: 0.4530
# Restored model from best epoch 2 with val_loss: 0.452965
# NFL direct model 166/200 completed
# Range [0.830, 0.835): 2259 train, 251 validation
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 5, Train Acc: 0.8544, Train Loss: 0.3342, Val Acc: 0.8765, Val Loss: 0.2894
# Restored model from best epoch 5 with val_loss: 0.289404
# NFL direct model 167/200 completed
# Range [0.835, 0.840): 2285 train, 254 validation
# Starting training on device: cpu
# Early stopping at epoch 22
# Best epoch: 12, Train Acc: 0.8801, Train Loss: 0.2891, Val Acc: 0.8937, Val Loss: 0.2766
# Restored model from best epoch 12 with val_loss: 0.276569
# NFL direct model 168/200 completed
# Range [0.840, 0.845): 2312 train, 257 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.8728, Train Loss: 0.3020, Val Acc: 0.8405, Val Loss: 0.3066
# Restored model from best epoch 7 with val_loss: 0.306609
# NFL direct model 169/200 completed
# Range [0.845, 0.850): 2316 train, 258 validation
# Starting training on device: cpu
# Early stopping at epoch 28
# Best epoch: 18, Train Acc: 0.8679, Train Loss: 0.2929, Val Acc: 0.8488, Val Loss: 0.3402
# Restored model from best epoch 18 with val_loss: 0.340181
# NFL direct model 170/200 completed
# Range [0.850, 0.855): 2299 train, 256 validation
# Starting training on device: cpu
# Early stopping at epoch 25
# Best epoch: 15, Train Acc: 0.8630, Train Loss: 0.2913, Val Acc: 0.8867, Val Loss: 0.2664
# Restored model from best epoch 15 with val_loss: 0.266398
# NFL direct model 171/200 completed
# Range [0.855, 0.860): 2289 train, 255 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.8493, Train Loss: 0.3374, Val Acc: 0.8627, Val Loss: 0.3280
# Restored model from best epoch 4 with val_loss: 0.328030
# NFL direct model 172/200 completed
# Range [0.860, 0.865): 2304 train, 257 validation
# Starting training on device: cpu
# Early stopping at epoch 11
# Best epoch: 1, Train Acc: 0.7839, Train Loss: 0.4960, Val Acc: 0.8599, Val Loss: 0.3384
# Restored model from best epoch 1 with val_loss: 0.338379
# NFL direct model 173/200 completed
# Range [0.865, 0.870): 2313 train, 258 validation
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 10, Train Acc: 0.8677, Train Loss: 0.2893, Val Acc: 0.8605, Val Loss: 0.2553
# Restored model from best epoch 10 with val_loss: 0.255310
# NFL direct model 174/200 completed
# Range [0.870, 0.875): 2283 train, 254 validation
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 9, Train Acc: 0.8620, Train Loss: 0.3070, Val Acc: 0.8228, Val Loss: 0.3608
# Restored model from best epoch 9 with val_loss: 0.360756
# NFL direct model 175/200 completed
# Range [0.875, 0.880): 2358 train, 262 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.8626, Train Loss: 0.3222, Val Acc: 0.8473, Val Loss: 0.3962
# Restored model from best epoch 4 with val_loss: 0.396160
# NFL direct model 176/200 completed
# Range [0.880, 0.885): 2326 train, 259 validation
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 5, Train Acc: 0.8667, Train Loss: 0.3004, Val Acc: 0.8340, Val Loss: 0.3444
# Restored model from best epoch 5 with val_loss: 0.344402
# NFL direct model 177/200 completed
# Range [0.885, 0.890): 2346 train, 261 validation
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 9, Train Acc: 0.8674, Train Loss: 0.3053, Val Acc: 0.8352, Val Loss: 0.2622
# Restored model from best epoch 9 with val_loss: 0.262236
# NFL direct model 178/200 completed
# Range [0.890, 0.895): 2318 train, 258 validation
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 9, Train Acc: 0.8844, Train Loss: 0.2852, Val Acc: 0.8372, Val Loss: 0.3204
# Restored model from best epoch 9 with val_loss: 0.320405
# NFL direct model 179/200 completed
# Range [0.895, 0.900): 2385 train, 266 validation
# Starting training on device: cpu
# Early stopping at epoch 25
# Best epoch: 15, Train Acc: 0.9006, Train Loss: 0.2412, Val Acc: 0.8684, Val Loss: 0.2927
# Restored model from best epoch 15 with val_loss: 0.292666
# NFL direct model 180/200 completed
# Range [0.900, 0.905): 2343 train, 261 validation
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 10, Train Acc: 0.8707, Train Loss: 0.2934, Val Acc: 0.8659, Val Loss: 0.3141
# Restored model from best epoch 10 with val_loss: 0.314107
# NFL direct model 181/200 completed
# Range [0.905, 0.910): 2337 train, 260 validation
# Starting training on device: cpu
# Early stopping at epoch 22
# Best epoch: 12, Train Acc: 0.8892, Train Loss: 0.2544, Val Acc: 0.8654, Val Loss: 0.2665
# Restored model from best epoch 12 with val_loss: 0.266512
# NFL direct model 182/200 completed
# Range [0.910, 0.915): 2422 train, 270 validation
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 10, Train Acc: 0.8865, Train Loss: 0.2627, Val Acc: 0.8444, Val Loss: 0.3441
# Restored model from best epoch 10 with val_loss: 0.344060
# NFL direct model 183/200 completed
# Range [0.915, 0.920): 2387 train, 266 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.8630, Train Loss: 0.3100, Val Acc: 0.8947, Val Loss: 0.2402
# Restored model from best epoch 2 with val_loss: 0.240216
# NFL direct model 184/200 completed
# Range [0.920, 0.925): 2553 train, 284 validation
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 9, Train Acc: 0.8821, Train Loss: 0.2554, Val Acc: 0.8768, Val Loss: 0.2731
# Restored model from best epoch 9 with val_loss: 0.273101
# NFL direct model 185/200 completed
# Range [0.925, 0.930): 2664 train, 297 validation
# Starting training on device: cpu
# Early stopping at epoch 11
# Best epoch: 1, Train Acc: 0.7733, Train Loss: 0.4702, Val Acc: 0.8855, Val Loss: 0.2604
# Restored model from best epoch 1 with val_loss: 0.260381
# NFL direct model 186/200 completed
# Range [0.930, 0.935): 2603 train, 290 validation
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 9, Train Acc: 0.8993, Train Loss: 0.2312, Val Acc: 0.8517, Val Loss: 0.2951
# Restored model from best epoch 9 with val_loss: 0.295066
# NFL direct model 187/200 completed
# Range [0.935, 0.940): 2712 train, 302 validation
# Starting training on device: cpu
# Early stopping at epoch 28
# Best epoch: 18, Train Acc: 0.9015, Train Loss: 0.2248, Val Acc: 0.8841, Val Loss: 0.2112
# Restored model from best epoch 18 with val_loss: 0.211166
# NFL direct model 188/200 completed
# Range [0.940, 0.945): 2912 train, 324 validation
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 5, Train Acc: 0.8997, Train Loss: 0.2396, Val Acc: 0.9043, Val Loss: 0.1821
# Restored model from best epoch 5 with val_loss: 0.182104
# NFL direct model 189/200 completed
# Range [0.945, 0.950): 2937 train, 327 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.8924, Train Loss: 0.2529, Val Acc: 0.9052, Val Loss: 0.2281
# Restored model from best epoch 4 with val_loss: 0.228065
# NFL direct model 190/200 completed
# Range [0.950, 0.955): 3038 train, 338 validation
# Starting training on device: cpu
# Early stopping at epoch 40
# Best epoch: 30, Train Acc: 0.9098, Train Loss: 0.1989, Val Acc: 0.8609, Val Loss: 0.2422
# Restored model from best epoch 30 with val_loss: 0.242204
# NFL direct model 191/200 completed
# Range [0.955, 0.960): 2907 train, 324 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.8827, Train Loss: 0.2889, Val Acc: 0.8858, Val Loss: 0.2193
# Restored model from best epoch 2 with val_loss: 0.219302
# NFL direct model 192/200 completed
# Range [0.960, 0.965): 3057 train, 340 validation
# Starting training on device: cpu
# Early stopping at epoch 45
# Best epoch: 35, Train Acc: 0.9127, Train Loss: 0.1844, Val Acc: 0.9235, Val Loss: 0.1944
# Restored model from best epoch 35 with val_loss: 0.194448
# NFL direct model 193/200 completed
# Range [0.965, 0.970): 2797 train, 311 validation
# Starting training on device: cpu
# Early stopping at epoch 25
# Best epoch: 15, Train Acc: 0.9110, Train Loss: 0.2134, Val Acc: 0.8746, Val Loss: 0.2292
# Restored model from best epoch 15 with val_loss: 0.229240
# NFL direct model 194/200 completed
# Range [0.970, 0.975): 6484 train, 721 validation
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 8, Train Acc: 0.8945, Train Loss: 0.2303, Val Acc: 0.9098, Val Loss: 0.2287
# Restored model from best epoch 8 with val_loss: 0.228660
# NFL direct model 195/200 completed
# Range [0.975, 0.980): 2968 train, 330 validation
# Starting training on device: cpu
# Early stopping at epoch 27
# Best epoch: 17, Train Acc: 0.9080, Train Loss: 0.1997, Val Acc: 0.8879, Val Loss: 0.2096
# Restored model from best epoch 17 with val_loss: 0.209640
# NFL direct model 196/200 completed
# Range [0.980, 0.985): 3126 train, 348 validation
# Starting training on device: cpu
# Early stopping at epoch 23
# Best epoch: 13, Train Acc: 0.9171, Train Loss: 0.1773, Val Acc: 0.9080, Val Loss: 0.1826
# Restored model from best epoch 13 with val_loss: 0.182553
# NFL direct model 197/200 completed
# Range [0.985, 0.990): 3119 train, 347 validation
# Starting training on device: cpu
# Early stopping at epoch 27
# Best epoch: 17, Train Acc: 0.9324, Train Loss: 0.1644, Val Acc: 0.9193, Val Loss: 0.1861
# Restored model from best epoch 17 with val_loss: 0.186128
# NFL direct model 198/200 completed
# Range [0.990, 0.995): 3122 train, 347 validation
# Starting training on device: cpu
# Early stopping at epoch 31
# Best epoch: 21, Train Acc: 0.9270, Train Loss: 0.1568, Val Acc: 0.9107, Val Loss: 0.2301
# Restored model from best epoch 21 with val_loss: 0.230080
# NFL direct model 199/200 completed
# Range [0.995, 1.000): 6875 train, 764 validation
# Starting training on device: cpu
# Early stopping at epoch 32
# Best epoch: 22, Train Acc: 0.9433, Train Loss: 0.1294, Val Acc: 0.9463, Val Loss: 0.1193
# Restored model from best epoch 22 with val_loss: 0.119267
# NFL direct model 200/200 completed

# %%
models.keys()
# Out:
# dict_keys([0.0, 0.005, 0.01, 0.015, 0.02, 0.025, 0.03, 0.035, 0.04, 0.045, 0.05, 0.055, 0.06, 0.065, 0.07, 0.075, 0.08, 0.085, 0.09, 0.095, 0.1, 0.105, 0.11, 0.115, 0.12, 0.125, 0.13, 0.135, 0.14, 0.145, 0.15, 0.155, 0.16, 0.165, 0.17, 0.175, 0.18, 0.185, 0.19, 0.195, 0.2, 0.205, 0.21, 0.215, 0.22, 0.225, 0.23, 0.235, 0.24, 0.245, 0.25, 0.255, 0.26, 0.265, 0.27, 0.275, 0.28, 0.285, 0.29, 0.295, 0.3, 0.305, 0.31, 0.315, 0.32, 0.325, 0.33, 0.335, 0.34, 0.345, 0.35, 0.355, 0.36, 0.365, 0.37, 0.375, 0.38, 0.385, 0.39, 0.395, 0.4, 0.405, 0.41, 0.415, 0.42, 0.425, 0.43, 0.435, 0.44, 0.445, 0.45, 0.455, 0.46, 0.465, 0.47, 0.475, 0.48, 0.485, 0.49, 0.495, 0.5, 0.505, 0.51, 0.515, 0.52, 0.525, 0.53, 0.535, 0.54, 0.545, 0.55, 0.555, 0.56, 0.565, 0.57, 0.575, 0.58, 0.585, 0.59, 0.595, 0.6, 0.605, 0.61, 0.615, 0.62, 0.625, 0.63, 0.635, 0.64, 0.645, 0.65, 0.655, 0.66, 0.665, 0.67, 0.675, 0.68, 0.685, 0.69, 0.695, 0.7, 0.705, 0.71, 0.715, 0.72, 0.725, 0.73, 0.735, 0.74, 0.745, 0.75, 0.755, 0.76, 0.765, 0.77, 0.775, 0.78, 0.785, 0.79, 0.795, 0.8, 0.805, 0.81, 0.815, 0.82, 0.825, 0.83, 0.835, 0.84, 0.845, 0.85, 0.855, 0.86, 0.865, 0.87, 0.875, 0.88, 0.885, 0.89, 0.895, 0.9, 0.905, 0.91, 0.915, 0.92, 0.925, 0.93, 0.935, 0.94, 0.945, 0.95, 0.955, 0.96, 0.965, 0.97, 0.975, 0.98, 0.985, 0.99, 0.995, 1.0])

# %%
models[1] = models[0.995]

# %%
model = models[0.99]
data_point = [0.99, 0.5, -5, 1, 1, 1, 1, 1, 1]
model.predict_proba(np.array([data_point]))

# %%
import process_data
modules_to_reload = [
    'process_data',
]

for module_name in modules_to_reload:
    if module_name in sys.modules:
        del sys.modules[module_name]

x = process_data.plot_loss(models, test_data, "NN")

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %reload_ext autoreload

# %%
modules_to_reload = [
    'models.direct_prediction_network',
    'models.direct_prediction_network_transformer',
    'models.utils'
]
from models.utils import SHAP_analysis

SHAP_analysis(models, training_data, test_data, "NN", "shap_values/NN", num_threads = 1)
# Out:
# PermutationExplainer explainer: 365it [00:13,  6.95it/s]
# .values =
# array([[-5.22444304e-01, -1.75063103e-03,  3.57689166e-03, ...,
#         -8.23456611e-03,  1.70319158e-03,  2.02856011e-03],
#        [-5.26710978e-01, -9.79733649e-04,  1.93670555e-03, ...,
#         -3.83939714e-03,  9.37581235e-04,  1.58019682e-03],
#        [-4.83338309e-01, -8.45959098e-04, -3.30062502e-04, ...,
#         -8.01757826e-03, -9.87743796e-04,  2.55215049e-03],
#        ...,
#        [ 2.53334097e-01, -5.68626230e-03, -2.58235223e-02, ...,
#         -2.59786324e-02, -3.19025597e-03, -5.29306458e-02],
#        [ 2.77540613e-01,  2.48721609e-04, -1.46657779e-02, ...,
#         -3.31360355e-02, -1.49815454e-02,  2.71557215e-03],
#        [ 2.03108740e-01, -9.69217704e-04,  1.02640502e-02, ...,
#         -9.90007754e-04,  4.29256542e-04,  5.13956415e-03]])
#
# .base_values =
# array([0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061, 0.54075061,
#        0.54075061, 0.54075061, 0.54075061, 0.54075061])
#
# .data =
# array([[-30. ,   0.9,   3. , ...,   0. ,   3. ,   3. ],
#        [-30. ,   0.9,   5. , ...,  -4. ,   3. ,   3. ],
#        [-11. ,   0.9,   3. , ...,   0. ,   3. ,   3. ],
#        ...,
#        [  8. ,   0.9,  24. , ..., -25. ,   3. ,   2. ],
#        [  7. ,   0.9,  24. , ..., -23. ,   3. ,   3. ],
#        [  5. ,   0.9,   5. , ...,  -6. ,   3. ,   3. ]], dtype=float32)

# %%
from process_data import write_predictions
from sklearn.preprocessing import StandardScaler
# Reload the modules
modules_to_reload = [
    'process_data',
]

for module_name in modules_to_reload:
    if module_name in sys.modules:
        del sys.modules[module_name]


write_predictions(models, interpolated_dir, [2024, 2025], 0, features, replace_nan_val = 0, phat_b = "NN_phat_b")
# Out:
# Loading data for 2025
# Processed file:  game_401772888.csv
# Processed file:  game_401772863.csv
# Processed file:  game_401772877.csv
# Processed file:  game_401772730.csv
# Processed file:  game_401772724.csv
# Processed file:  game_401772718.csv
# Processed file:  game_401772917.csv
# Processed file:  game_401772903.csv
# Processed file:  game_401772902.csv
# Processed file:  game_401772916.csv
# Processed file:  game_401772719.csv
# Processed file:  game_401772725.csv
# Processed file:  game_401772731.csv
# Processed file:  game_401772876.csv
# Processed file:  game_401772862.csv
# Processed file:  game_401772889.csv
# Processed file:  game_401772848.csv
# Processed file:  game_401772874.csv
# Processed file:  game_401772860.csv
# Processed file:  game_401772727.csv
# Processed file:  game_401772733.csv
# Processed file:  game_401772928.csv
# Processed file:  game_401772900.csv
# Processed file:  game_401772914.csv
# Processed file:  game_401772915.csv
# Processed file:  game_401772901.csv
# Processed file:  game_401772929.csv
# Processed file:  game_401772732.csv
# Processed file:  game_401772726.csv
# Processed file:  game_401772861.csv
# Processed file:  game_401772875.csv
# Processed file:  game_401772849.csv
# Processed file:  game_401772871.csv
# Processed file:  game_401772865.csv
# Processed file:  game_401772859.csv
# Processed file:  game_401772722.csv
# Processed file:  game_401772736.csv
# Processed file:  game_401772905.csv
# Processed file:  game_401772911.csv
# Processed file:  game_401772939.csv
# Processed file:  game_401772938.csv
# Processed file:  game_401772910.csv
# Processed file:  game_401772904.csv
# Processed file:  game_401772737.csv
# Processed file:  game_401772723.csv
# Processed file:  game_401772858.csv
# Processed file:  game_401772694.csv
# Processed file:  game_401772864.csv
# Processed file:  game_401772870.csv
# Processed file:  game_401772899.csv
# Processed file:  game_401772866.csv
# Processed file:  game_401772872.csv
# Processed file:  game_401772735.csv
# Processed file:  game_401772721.csv
# Processed file:  game_401772912.csv
# Processed file:  game_401772906.csv
# Processed file:  game_401772907.csv
# Processed file:  game_401772913.csv
# Processed file:  game_401772720.csv
# Processed file:  game_401772734.csv
# Processed file:  game_401772873.csv
# Processed file:  game_401772867.csv
# Processed file:  game_401772898.csv
# Processed file:  game_401772633.csv
# Processed file:  game_401772828.csv
# Processed file:  game_401772800.csv
# Processed file:  game_401772814.csv
# Processed file:  game_401772753.csv
# Processed file:  game_401772747.csv
# Processed file:  game_401772948.csv
# Processed file:  game_401772790.csv
# Processed file:  game_401772784.csv
# Processed file:  game_401772960.csv
# Processed file:  game_401772961.csv
# Processed file:  game_401772785.csv
# Processed file:  game_401772791.csv
# Processed file:  game_401772949.csv
# Processed file:  game_401772746.csv
# Processed file:  game_401772752.csv
# Processed file:  game_401772815.csv
# Processed file:  game_401772801.csv
# Processed file:  game_401772829.csv
# Processed file:  game_401772632.csv
# Processed file:  game_401772630.csv
# Processed file:  game_401772817.csv
# Processed file:  game_401772803.csv
# Processed file:  game_401772744.csv
# Processed file:  game_401772750.csv
# Processed file:  game_401772778.csv
# Processed file:  game_401772787.csv
# Processed file:  game_401772793.csv
# Processed file:  game_401772963.csv
# Processed file:  game_401772962.csv
# Processed file:  game_401772792.csv
# Processed file:  game_401772786.csv
# Processed file:  game_401772779.csv
# Processed file:  game_401772751.csv
# Processed file:  game_401772745.csv
# Processed file:  game_401772802.csv
# Processed file:  game_401772816.csv
# Processed file:  game_401772631.csv
# Processed file:  game_401772635.csv
# Processed file:  game_401772621.csv
# Processed file:  game_401772812.csv
# Processed file:  game_401772806.csv
# Processed file:  game_401772769.csv
# Processed file:  game_401772741.csv
# Processed file:  game_401772755.csv
# Processed file:  game_401772966.csv
# Processed file:  game_401772782.csv
# Processed file:  game_401772796.csv
# Processed file:  game_401772797.csv
# Processed file:  game_401772783.csv
# Processed file:  game_401772967.csv
# Processed file:  game_401772754.csv
# Processed file:  game_401772740.csv
# Processed file:  game_401772768.csv
# Processed file:  game_401772807.csv
# Processed file:  game_401772813.csv
# Processed file:  game_401772634.csv
# Processed file:  game_401772622.csv
# Processed file:  game_401772636.csv
# Processed file:  game_401772805.csv
# Processed file:  game_401772811.csv
# Processed file:  game_401772839.csv
# Processed file:  game_401772756.csv
# Processed file:  game_401772742.csv
# Processed file:  game_401772965.csv
# Processed file:  game_401772795.csv
# Processed file:  game_401772959.csv
# Processed file:  game_401772781.csv
# Processed file:  game_401772780.csv
# Processed file:  game_401772958.csv
# Processed file:  game_401772794.csv
# Processed file:  game_401772964.csv
# Processed file:  game_401772970.csv
# Processed file:  game_401772743.csv
# Processed file:  game_401772757.csv
# Processed file:  game_401772838.csv
# Processed file:  game_401772810.csv
# Processed file:  game_401772804.csv
# Processed file:  game_401772612.csv
# Processed file:  game_401772809.csv
# Processed file:  game_401772821.csv
# Processed file:  game_401772835.csv
# Processed file:  game_401772772.csv
# Processed file:  game_401772766.csv
# Processed file:  game_401772969.csv
# Processed file:  game_401772955.csv
# Processed file:  game_401772941.csv
# Processed file:  game_401772799.csv
# Processed file:  game_401772798.csv
# Processed file:  game_401772940.csv
# Processed file:  game_401772954.csv
# Processed file:  game_401772968.csv
# Processed file:  game_401772767.csv
# Processed file:  game_401772773.csv
# Processed file:  game_401772834.csv
# Processed file:  game_401772820.csv
# Processed file:  game_401772808.csv
# Processed file:  game_401772613.csv
# Processed file:  game_401772836.csv
# Processed file:  game_401772822.csv
# Processed file:  game_401772765.csv
# Processed file:  game_401772771.csv
# Processed file:  game_401772759.csv
# Processed file:  game_401772942.csv
# Processed file:  game_401772956.csv
# Processed file:  game_401772957.csv
# Processed file:  game_401772943.csv
# Processed file:  game_401772758.csv
# Processed file:  game_401772770.csv
# Processed file:  game_401772764.csv
# Processed file:  game_401772823.csv
# Processed file:  game_401772837.csv
# Processed file:  game_401772833.csv
# Processed file:  game_401772827.csv
# Processed file:  game_401772748.csv
# Processed file:  game_401772760.csv
# Processed file:  game_401772774.csv
# Processed file:  game_401772947.csv
# Processed file:  game_401772953.csv
# Processed file:  game_401772952.csv
# Processed file:  game_401772946.csv
# Processed file:  game_401772775.csv
# Processed file:  game_401772761.csv
# Processed file:  game_401772749.csv
# Processed file:  game_401772826.csv
# Processed file:  game_401772832.csv
# Processed file:  game_401772824.csv
# Processed file:  game_401772830.csv
# Processed file:  game_401772818.csv
# Processed file:  game_401772777.csv
# Processed file:  game_401772763.csv
# Processed file:  game_401772950.csv
# Processed file:  game_401772788.csv
# Processed file:  game_401772944.csv
# Processed file:  game_401772945.csv
# Processed file:  game_401772789.csv
# Processed file:  game_401772951.csv
# Processed file:  game_401772762.csv
# Processed file:  game_401772776.csv
# Processed file:  game_401772819.csv
# Processed file:  game_401772831.csv
# Processed file:  game_401772825.csv
# Processed file:  game_401772881.csv
# Processed file:  game_401772895.csv
# Processed file:  game_401772842.csv
# Processed file:  game_401772856.csv
# Processed file:  game_401772711.csv
# Processed file:  game_401772739.csv
# Processed file:  game_401772936.csv
# Processed file:  game_401772922.csv
# Processed file:  game_401772923.csv
# Processed file:  game_401772937.csv
# Processed file:  game_401772738.csv
# Processed file:  game_401772710.csv
# Processed file:  game_401772857.csv
# Processed file:  game_401772843.csv
# Processed file:  game_401772894.csv
# Processed file:  game_401772880.csv
# Processed file:  game_401772896.csv
# Processed file:  game_401772882.csv
# Processed file:  game_401772869.csv
# Processed file:  game_401772855.csv
# Processed file:  game_401772841.csv
# Processed file:  game_401772909.csv
# Processed file:  game_401772921.csv
# Processed file:  game_401772935.csv
# Processed file:  game_401772510.csv
# Processed file:  game_401772934.csv
# Processed file:  game_401772920.csv
# Processed file:  game_401772908.csv
# Processed file:  game_401772840.csv
# Processed file:  game_401772854.csv
# Processed file:  game_401772868.csv
# Processed file:  game_401772883.csv
# Processed file:  game_401772897.csv
# Processed file:  game_401772893.csv
# Processed file:  game_401772887.csv
# Processed file:  game_401772850.csv
# Processed file:  game_401772844.csv
# Processed file:  game_401772878.csv
# Processed file:  game_401772717.csv
# Processed file:  game_401772924.csv
# Processed file:  game_401772930.csv
# Processed file:  game_401772918.csv
# Processed file:  game_401772919.csv
# Processed file:  game_401772931.csv
# Processed file:  game_401772925.csv
# Processed file:  game_401772716.csv
# Processed file:  game_401772879.csv
# Processed file:  game_401772845.csv
# Processed file:  game_401772851.csv
# Processed file:  game_401772886.csv
# Processed file:  game_401772892.csv
# Processed file:  game_401772884.csv
# Processed file:  game_401772890.csv
# Processed file:  game_401772847.csv
# Processed file:  game_401772853.csv
# Processed file:  game_401772728.csv
# Processed file:  game_401772714.csv
# Processed file:  game_401772933.csv
# Processed file:  game_401772927.csv
# Processed file:  game_401772926.csv
# Processed file:  game_401772932.csv
# Processed file:  game_401772715.csv
# Processed file:  game_401772729.csv
# Processed file:  game_401772852.csv
# Processed file:  game_401772846.csv
# Processed file:  game_401772891.csv
# Processed file:  game_401772885.csv
# Loading data for 2024
# Processed file:  game_401671629.csv
# Processed file:  game_401671601.csv
# Processed file:  game_401671826.csv
# Processed file:  game_401671832.csv
# Processed file:  game_401671749.csv
# Processed file:  game_401671775.csv
# Processed file:  game_401671761.csv
# Processed file:  game_401671760.csv
# Processed file:  game_401671774.csv
# Processed file:  game_401671748.csv
# Processed file:  game_401671833.csv
# Processed file:  game_401671827.csv
# Processed file:  game_401671600.csv
# Processed file:  game_401671628.csv
# Processed file:  game_401671616.csv
# Processed file:  game_401671831.csv
# Processed file:  game_401671825.csv
# Processed file:  game_401671819.csv
# Processed file:  game_401671762.csv
# Processed file:  game_401671776.csv
# Processed file:  game_401671789.csv
# Processed file:  game_401671788.csv
# Processed file:  game_401671777.csv
# Processed file:  game_401671763.csv
# Processed file:  game_401671818.csv
# Processed file:  game_401671824.csv
# Processed file:  game_401671830.csv
# Processed file:  game_401671617.csv
# Processed file:  game_401671808.csv
# Processed file:  game_401671834.csv
# Processed file:  game_401671820.csv
# Processed file:  game_401671767.csv
# Processed file:  game_401671773.csv
# Processed file:  game_401671798.csv
# Processed file:  game_401671799.csv
# Processed file:  game_401671772.csv
# Processed file:  game_401671766.csv
# Processed file:  game_401671821.csv
# Processed file:  game_401671835.csv
# Processed file:  game_401671809.csv
# Processed file:  game_401671638.csv
# Processed file:  game_401671823.csv
# Processed file:  game_401671837.csv
# Processed file:  game_401671599.csv
# Processed file:  game_401671770.csv
# Processed file:  game_401671764.csv
# Processed file:  game_401671758.csv
# Processed file:  game_401671759.csv
# Processed file:  game_401671765.csv
# Processed file:  game_401671771.csv
# Processed file:  game_401671836.csv
# Processed file:  game_401671822.csv
# Processed file:  game_401671639.csv
# Processed file:  game_401671662.csv
# Processed file:  game_401671676.csv
# Processed file:  game_401671845.csv
# Processed file:  game_401671851.csv
# Processed file:  game_401671689.csv
# Processed file:  game_401671716.csv
# Processed file:  game_401671702.csv
# Processed file:  game_401671703.csv
# Processed file:  game_401671717.csv
# Processed file:  game_401671688.csv
# Processed file:  game_401671850.csv
# Processed file:  game_401671844.csv
# Processed file:  game_401671677.csv
# Processed file:  game_401671663.csv
# Processed file:  game_401671649.csv
# Processed file:  game_401671675.csv
# Processed file:  game_401671661.csv
# Processed file:  game_401671852.csv
# Processed file:  game_401671846.csv
# Processed file:  game_401671729.csv
# Processed file:  game_401671701.csv
# Processed file:  game_401671715.csv
# Processed file:  game_401671714.csv
# Processed file:  game_401671700.csv
# Processed file:  game_401671728.csv
# Processed file:  game_401671489.csv
# Processed file:  game_401671847.csv
# Processed file:  game_401671853.csv
# Processed file:  game_401671660.csv
# Processed file:  game_401671674.csv
# Processed file:  game_401671648.csv
# Processed file:  game_401671670.csv
# Processed file:  game_401671664.csv
# Processed file:  game_401671658.csv
# Processed file:  game_401671857.csv
# Processed file:  game_401671843.csv
# Processed file:  game_401671704.csv
# Processed file:  game_401671710.csv
# Processed file:  game_401671738.csv
# Processed file:  game_401671739.csv
# Processed file:  game_401671711.csv
# Processed file:  game_401671705.csv
# Processed file:  game_401671842.csv
# Processed file:  game_401671856.csv
# Processed file:  game_401671659.csv
# Processed file:  game_401671665.csv
# Processed file:  game_401671671.csv
# Processed file:  game_401671667.csv
# Processed file:  game_401671673.csv
# Processed file:  game_401671868.csv
# Processed file:  game_401671840.csv
# Processed file:  game_401671698.csv
# Processed file:  game_401671854.csv
# Processed file:  game_401671713.csv
# Processed file:  game_401671707.csv
# Processed file:  game_401671706.csv
# Processed file:  game_401671712.csv
# Processed file:  game_401671855.csv
# Processed file:  game_401671699.csv
# Processed file:  game_401671841.csv
# Processed file:  game_401671869.csv
# Processed file:  game_401671672.csv
# Processed file:  game_401671666.csv
# Processed file:  game_401671643.csv
# Processed file:  game_401671657.csv
# Processed file:  game_401671864.csv
# Processed file:  game_401671870.csv
# Processed file:  game_401671858.csv
# Processed file:  game_401671680.csv
# Processed file:  game_401671694.csv
# Processed file:  game_401671737.csv
# Processed file:  game_401671723.csv
# Processed file:  game_401671722.csv
# Processed file:  game_401671736.csv
# Processed file:  game_401671695.csv
# Processed file:  game_401671681.csv
# Processed file:  game_401671859.csv
# Processed file:  game_401671871.csv
# Processed file:  game_401671865.csv
# Processed file:  game_401671656.csv
# Processed file:  game_401671642.csv
# Processed file:  game_401671668.csv
# Processed file:  game_401671654.csv
# Processed file:  game_401671640.csv
# Processed file:  game_401671873.csv
# Processed file:  game_401671867.csv
# Processed file:  game_401671697.csv
# Processed file:  game_401671683.csv
# Processed file:  game_401671495.csv
# Processed file:  game_401671708.csv
# Processed file:  game_401671720.csv
# Processed file:  game_401671734.csv
# Processed file:  game_401671735.csv
# Processed file:  game_401671721.csv
# Processed file:  game_401671709.csv
# Processed file:  game_401671494.csv
# Processed file:  game_401671682.csv
# Processed file:  game_401671696.csv
# Processed file:  game_401671866.csv
# Processed file:  game_401671872.csv
# Processed file:  game_401671641.csv
# Processed file:  game_401671655.csv
# Processed file:  game_401671669.csv
# Processed file:  game_401671651.csv
# Processed file:  game_401671645.csv
# Processed file:  game_401671679.csv
# Processed file:  game_401671692.csv
# Processed file:  game_401671686.csv
# Processed file:  game_401671876.csv
# Processed file:  game_401671862.csv
# Processed file:  game_401671490.csv
# Processed file:  game_401671725.csv
# Processed file:  game_401671731.csv
# Processed file:  game_401671719.csv
# Processed file:  game_401671718.csv
# Processed file:  game_401671730.csv
# Processed file:  game_401671724.csv
# Processed file:  game_401671491.csv
# Processed file:  game_401671863.csv
# Processed file:  game_401671877.csv
# Processed file:  game_401671687.csv
# Processed file:  game_401671693.csv
# Processed file:  game_401671678.csv
# Processed file:  game_401671644.csv
# Processed file:  game_401671650.csv
# Processed file:  game_401671646.csv
# Processed file:  game_401671652.csv
# Processed file:  game_401671685.csv
# Processed file:  game_401671849.csv
# Processed file:  game_401671691.csv
# Processed file:  game_401671861.csv
# Processed file:  game_401671875.csv
# Processed file:  game_401671493.csv
# Processed file:  game_401671732.csv
# Processed file:  game_401671726.csv
# Processed file:  game_401671727.csv
# Processed file:  game_401671733.csv
# Processed file:  game_401671492.csv
# Processed file:  game_401671874.csv
# Processed file:  game_401671860.csv
# Processed file:  game_401671690.csv
# Processed file:  game_401671848.csv
# Processed file:  game_401671684.csv
# Processed file:  game_401671653.csv
# Processed file:  game_401671647.csv
# Processed file:  game_401671620.csv
# Processed file:  game_401671634.csv
# Processed file:  game_401671807.csv
# Processed file:  game_401671813.csv
# Processed file:  game_401671768.csv
# Processed file:  game_401671754.csv
# Processed file:  game_401671740.csv
# Processed file:  game_401671797.csv
# Processed file:  game_401671783.csv
# Processed file:  game_401671782.csv
# Processed file:  game_401671796.csv
# Processed file:  game_401671741.csv
# Processed file:  game_401671755.csv
# Processed file:  game_401671769.csv
# Processed file:  game_401671812.csv
# Processed file:  game_401671806.csv
# Processed file:  game_401671635.csv
# Processed file:  game_401671621.csv
# Processed file:  game_401671637.csv
# Processed file:  game_401671623.csv
# Processed file:  game_401671810.csv
# Processed file:  game_401671804.csv
# Processed file:  game_401671838.csv
# Processed file:  game_401671743.csv
# Processed file:  game_401671757.csv
# Processed file:  game_401671780.csv
# Processed file:  game_401671794.csv
# Processed file:  game_401671795.csv
# Processed file:  game_401671781.csv
# Processed file:  game_401671756.csv
# Processed file:  game_401671742.csv
# Processed file:  game_401671839.csv
# Processed file:  game_401671805.csv
# Processed file:  game_401671811.csv
# Processed file:  game_401671622.csv
# Processed file:  game_401671636.csv
# Processed file:  game_401671632.csv
# Processed file:  game_401671626.csv
# Processed file:  game_401671829.csv
# Processed file:  game_401671815.csv
# Processed file:  game_401671801.csv
# Processed file:  game_401671746.csv
# Processed file:  game_401671752.csv
# Processed file:  game_401671785.csv
# Processed file:  game_401671791.csv
# Processed file:  game_401671790.csv
# Processed file:  game_401671784.csv
# Processed file:  game_401671753.csv
# Processed file:  game_401671747.csv
# Processed file:  game_401671800.csv
# Processed file:  game_401671814.csv
# Processed file:  game_401671828.csv
# Processed file:  game_401671627.csv
# Processed file:  game_401671633.csv
# Processed file:  game_401671625.csv
# Processed file:  game_401671631.csv
# Processed file:  game_401671619.csv
# Processed file:  game_401671802.csv
# Processed file:  game_401671816.csv
# Processed file:  game_401671751.csv
# Processed file:  game_401671745.csv
# Processed file:  game_401671779.csv
# Processed file:  game_401671792.csv
# Processed file:  game_401671786.csv
# Processed file:  game_401671787.csv
# Processed file:  game_401671793.csv
# Processed file:  game_401671778.csv
# Processed file:  game_401671744.csv
# Processed file:  game_401671750.csv
# Processed file:  game_401671817.csv
# Processed file:  game_401671803.csv
# Processed file:  game_401671618.csv
# Processed file:  game_401671630.csv
# Processed file:  game_401671624.csv

# %%
import os
import shutil

# Define the ancestor directory and the parent directory
src_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
dest_dir = os.path.abspath(os.path.join(os.getcwd(), "../../"))

# Specify a list of directories to copy
sources = [
    os.path.join(src_dir, "dataset_interpolated_fixed", "2024"),
    os.path.join(src_dir, "dataset_interpolated_fixed", "2025")
]

destination = os.path.join(dest_dir, "test_9", "NN_model")

# Iterate through each source and copy
for source in sources:
    if os.path.exists(source):
        # Extract the year/folder name from source
        if os.path.isdir(source):
            shutil.copytree(source, destination, dirs_exist_ok=True)
        else:
            shutil.copy2(source, destination)
        print(f"Copied '{source}' to '{destination}'")
    else:
        print(f"Source '{source}' does not exist")
# Out:
# Copied '/Users/aly/Documents/University_of_Waterloo/Winter 2025/Research/code/NFL/ML/dataset_interpolated_fixed/2024' to '/Users/aly/Documents/University_of_Waterloo/Winter 2025/Research/code/NFL/test_9/NN_model'
# Copied '/Users/aly/Documents/University_of_Waterloo/Winter 2025/Research/code/NFL/ML/dataset_interpolated_fixed/2025' to '/Users/aly/Documents/University_of_Waterloo/Winter 2025/Research/code/NFL/test_9/NN_model'
