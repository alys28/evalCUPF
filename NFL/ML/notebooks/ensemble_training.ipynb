# %%
# Ensemble training (1 year of testing, 2 years of validation, the rest is training)
    # Learned weights on validation data (Constrained optimization)
    # Meta-learning using an other ML model

# Models used:
# - XGBoost
# - Neural Network
# - Logistic Regression
# - LSTM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
import os

# %%
# Set up paths and load data
parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(parent_dir)
print(parent_dir)

interpolated_dir = os.path.join(parent_dir, "dataset_interpolated_fixed")
# features = ["game_completed", "relative_strength", "score_difference", "type.id", "home_has_possession", "end.down", "end.yardsToEndzone", "end.distance", "field_position_shift", "home_timeouts_left", "away_timeouts_left"]
features = ["game_completed", "relative_strength", "score_difference", "home_has_possession", "end.down", "end.distance", "end.yardsToEndzone", "home_timeouts_left", "away_timeouts_left", "predicted_drive_points_prob_0_2pts", "predicted_drive_points_prob_3_6pts", "predicted_drive_points_prob_7plus_pts"]# Import necessary modules
from sklearn.metrics import brier_score_loss, accuracy_score, log_loss
from sklearn.linear_model import LogisticRegression
from scipy.optimize import minimize
import pickle
# Out:
# /Users/aly/Documents/University_of_Waterloo/Winter 2025/Research/code/NFL/ML

# %%
# Load data for ensemble training
import process_data
training_data = process_data.load_data(interpolated_dir, 
                                       years = [2016, 2017, 2018, 2019, 2020, 2021], 
                                       history_length = 0, 
                                       features = features, 
                                       label_feature = "home_win")

ensemble_data = process_data.load_data(interpolated_dir, 
                                         years = [2022, 2023], 
                                         history_length = 0, 
                                         features = features, 
                                         label_feature = "home_win",
                                         train = True
                                         )

test_data = process_data.load_data(interpolated_dir, 
                                   years = [2024, 2025],
                                   history_length = 0, 
                                   features = features, 
                                   label_feature = "home_win",
                                   train = False
                                   )

# %%
training_data_seq = process_data.load_data(interpolated_dir, 
                                       years = [2016, 2017, 2018, 2019, 2020, 2021], 
                                       history_length = 4, 
                                       features = features, 
                                       label_feature = "home_win",
                                       train = True
                                       )

ensemble_data_seq = process_data.load_data(interpolated_dir, 
                                         years = [2022, 2023], 
                                         history_length = 4, 
                                         features = features, 
                                         label_feature = "home_win",
                                         train = True
                                         )

test_data_seq = process_data.load_data(interpolated_dir, 
                                   years = [2024, 2025],
                                   history_length = 4, 
                                   features = features, 
                                   label_feature = "home_win",
                                   train = False
                                   )
# Out:
# Loading data for 2022
# skipping  2022
# Loading data for 2025
# skipping  2025
# Loading data for 2024
# skipping  2024
# Loading data for 2023
# skipping  2023
# Loading data for .DS_Store
# Loading data for 2017
#   Processing 254 CSV files in parallel with 8 workers...
#   Completed processing 2017
# Loading data for 2019
#   Processing 256 CSV files in parallel with 8 workers...
#   Completed processing 2019
# Loading data for 2021
#   Processing 272 CSV files in parallel with 8 workers...
#   Completed processing 2021
# Loading data for 2020
#   Processing 255 CSV files in parallel with 8 workers...
#   Completed processing 2020
# Loading data for 2018
#   Processing 255 CSV files in parallel with 8 workers...
#   Completed processing 2018
# Loading data for 2016
#   Processing 254 CSV files in parallel with 8 workers...
#   Completed processing 2016
# Loading data for 2022
#   Processing 271 CSV files in parallel with 8 workers...
#   Completed processing 2022
# Loading data for 2025
# skipping  2025
# Loading data for 2024
# skipping  2024
# Loading data for 2023
#   Processing 272 CSV files in parallel with 8 workers...
#   Completed processing 2023
# Loading data for .DS_Store
# Loading data for 2017
# skipping  2017
# Loading data for 2019
# skipping  2019
# Loading data for 2021
# skipping  2021
# Loading data for 2020
# skipping  2020
# Loading data for 2018
# skipping  2018
# Loading data for 2016
# skipping  2016
# Loading data for 2022
# skipping  2022
# Loading data for 2025
#   Processing 272 CSV files in parallel with 8 workers...
#   Completed processing 2025
# Loading data for 2024
#   Processing 272 CSV files in parallel with 8 workers...
#   Completed processing 2024
# Loading data for 2023
# skipping  2023
# Loading data for .DS_Store
# Loading data for 2017
# skipping  2017
# Loading data for 2019
# skipping  2019
# Loading data for 2021
# skipping  2021
# Loading data for 2020
# skipping  2020
# Loading data for 2018
# skipping  2018
# Loading data for 2016
# skipping  2016

# %%
from sklearn.model_selection import train_test_split
import shap
class EnsemblePredictor:
    """
    Ensemble predictor class, one per timestep
    """
    def __init__(self, all_models, all_models_order, all_features, strategy='meta_model', meta_model=None):
        self.all_models = all_models
        self.all_models_order = all_models_order
        self.strategy = strategy
        self.all_features = all_features
        if self.strategy != 'meta_model' and self.strategy != 'weighted_average':
            raise ValueError("Invalid strategy")
        if meta_model is None and self.strategy == 'meta_model':
            raise ValueError("Meta model is required for meta_model strategy")
        self.meta_model = meta_model
        self.ensemble_weights = None # Will be a 1D array of shape (n_models,) once trained
 
    def train_ensemble(self, x_train, y_train, objective='brier'):
        """
        Train the ensemble for a single timestep using validation data.
        """
        print(f"Training ensemble for this timestep...")
        if self.strategy == 'weighted_average':
            self.optimize_ensemble_weights(x_train, y_train, objective)
        elif self.strategy == 'meta_model':
            self.train_meta_model(x_train, y_train)

    def optimize_ensemble_weights(self, x_train, y_train, objective='brier'):
        """
        Optimize ensemble weights for a single timestep using validation data.
        """
        print(f"Optimizing ensemble weights for this timestep...")

        n_models = x_train.shape[1]

        def objective_function(weights):
            weights = weights / np.sum(weights)  # Normalize weights
            ensemble_preds = np.dot(x_train, weights)

            if objective == 'brier':
                ensemble_preds = np.clip(ensemble_preds, 1e-15, 1-1e-15)
                return brier_score_loss(y_train, ensemble_preds)
            elif objective == 'logloss':
                # Clip predictions to avoid log(0)
                ensemble_preds = np.clip(ensemble_preds, 1e-15, 1-1e-15)
                return log_loss(y_train, ensemble_preds)
            elif objective == 'accuracy':
                return -accuracy_score(y_train, ensemble_preds > 0.5)  # Negative for minimization

        # Constraints: weights sum to 1 and are non-negative
        constraints = ({'type': 'eq', 'fun': lambda w: np.sum(w) - 1})
        bounds = [(0, 1) for _ in range(n_models)]

        # Initialize with equal weights
        initial_weights = np.ones(n_models) / n_models

        result = minimize(objective_function, initial_weights,
                          method='SLSQP', bounds=bounds, constraints=constraints)

        if result.success:
            self.ensemble_weights = result.x
            print(f"  Optimized weights: {dict(zip(self.all_models_order, result.x.round(4)))} (score: {result.fun:.6f})")
        else:
            print(f"  Optimization failed, using equal weights")
            self.ensemble_weights = initial_weights

        return self.ensemble_weights

    def train_meta_model(self, x_train, y_train):
        """
        Train a meta-model for a single timestep to predict based on base model outputs.
        """
        X_train, X_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)
        # Train meta-model: input=base_model_predictions, output=final_prediction
        self.meta_model.fit(X_train, y_train.reshape(-1, 1))

        # Test the meta-model's prediction capability
        meta_predictions = self.meta_model.predict_proba(X_val)[:, 1]
        meta_accuracy = accuracy_score(y_val, meta_predictions > 0.5)
        meta_brier = brier_score_loss(y_val, meta_predictions)

        print(f"  Meta-model trained on {len(X_train)} samples")
        print(f"    Validation Meta-model accuracy: {meta_accuracy:.4f}, Validation Brier score: {meta_brier:.4f}")

        return self.meta_model
    
    def predict(self, X):
        """
        Predict the probability of the positive class for a given input
        """
        # Generate predictions from each individual model
        # Convert X to a 3D array of shape (n_samples, n_history, n_features)
        predictions = [] # Will be a 2D array of shape (n_samples, n_models)
        for i, model_name in enumerate(self.all_models_order):
            model = self.all_models[model_name]
            # print("Model name: ", model_name)
            if model_name == "lstm":
                # print(X.shape)
                pred = model.predict_proba(X)
                # print(pred)
                predictions.append(pred[:, 1])
            else:
                # print(X.shape)
                x = np.array([X[i][-1] for i in range(X.shape[0])]) if len(X.shape) == 3 else np.array([X[-1]])
                # print(x.shape)
                pred = model.predict_proba(x)
                # print(pred)
                predictions.append(pred[:, 1]) # Will be a 1D array of shape (n_samples,) for each model
        predictions = np.array(predictions) # Will be a 2D array of shape (n_models, n_samples)
        predictions = predictions.T # Reshape to be a 2D array of shape (n_samples, n_models)
        if self.strategy == 'weighted_average':
            return np.dot(predictions, self.ensemble_weights)
        elif self.strategy == 'meta_model':
            return self.meta_model.predict_proba(predictions)[:, 1]
    
    def predict_proba(self, X):
        """
        Predict the probability of the positive class for a given input
        """
        pred = self.predict(X).flatten()
        return np.column_stack([1 - pred, pred])

    def predict_proba_single(self, X):
        preds = self.predict_proba(X)
        return preds[:, 1]

    def score(self, X, y):
        """
        Score the ensemble for a given input
        """
        y_pred = self.predict(X)
        y_pred_labels = (y_pred > 0.5).astype(int)
        return np.mean(y_pred_labels == y)
    
    def SHAP_analysis(self, X_test, X_train, plot = True):
        """
        Model interpretability with SHAP values
        """
        feature_names = self.all_features
        masker = shap.maskers.Independent(X_train[:10])
        explainer = shap.Explainer(self.predict_proba_single, masker, feature_names=self.all_features)
        shap_values = explainer(X_test)
        if plot:
            shap.plots.bar(shap_values)
        return shap_values

# %%
# Reload modules
modules_to_reload = [
    'models.xg_boost',
    'models.direct_prediction_network_lstm',
    'models.direct_prediction_network',
    'models.logistic_regression',
    'models.Model'
    'models.DL_Model'
]

for module_name in modules_to_reload:
    if module_name in sys.modules:
        del sys.modules[module_name]
from models.xg_boost import setup_xgboost_models
from models.direct_prediction_network_lstm import setup_direct_lstm_models
from models.direct_prediction_network import setup_direct_models
from models.logistic_regression import setup_logistic_regression_models

# %%
all_models = {}

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %reload_ext autoreload

# %%
all_models["lstm"] = setup_direct_lstm_models(training_data_seq, None, num_models=201)
# Out:
# Split training data: 2484 train, 277 validation
#
# Training direct prediction LSTM model for timestep range [0.0, 0.005]
# Starting training on device: cpu
# NFL LSTM model 1/201 completed
# Split training data: 881 train, 98 validation
#
# Training direct prediction LSTM model for timestep range [0.005, 0.01]
# Starting training on device: cpu
# NFL LSTM model 2/201 completed
# Split training data: 1634 train, 182 validation
#
# Training direct prediction LSTM model for timestep range [0.01, 0.015]
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 10, Train Acc: 0.6536, Train Loss: 0.6165, Val Acc: 0.6978, Val Loss: 0.5863
# Restored model from best epoch 10 with val_loss: 0.586339
# NFL LSTM model 3/201 completed
# Split training data: 1382 train, 154 validation
#
# Training direct prediction LSTM model for timestep range [0.015, 0.02]
# Starting training on device: cpu
# Early stopping at epoch 26
# Best epoch: 21, Train Acc: 0.6541, Train Loss: 0.6230, Val Acc: 0.7208, Val Loss: 0.5628
# Restored model from best epoch 21 with val_loss: 0.562778
# NFL LSTM model 4/201 completed
# Split training data: 1546 train, 172 validation
#
# Training direct prediction LSTM model for timestep range [0.02, 0.025]
# Starting training on device: cpu
# Early stopping at epoch 9
# Best epoch: 4, Train Acc: 0.6539, Train Loss: 0.6350, Val Acc: 0.6047, Val Loss: 0.6538
# Restored model from best epoch 4 with val_loss: 0.653842
# NFL LSTM model 5/201 completed
# Split training data: 1594 train, 178 validation
#
# Training direct prediction LSTM model for timestep range [0.025, 0.03]
# Starting training on device: cpu
# NFL LSTM model 6/201 completed
# Split training data: 1516 train, 169 validation
#
# Training direct prediction LSTM model for timestep range [0.03, 0.035]
# Starting training on device: cpu
# NFL LSTM model 7/201 completed
# Split training data: 1646 train, 183 validation
#
# Training direct prediction LSTM model for timestep range [0.035, 0.04]
# Starting training on device: cpu
# NFL LSTM model 8/201 completed
# Split training data: 1568 train, 175 validation
#
# Training direct prediction LSTM model for timestep range [0.04, 0.045]
# Starting training on device: cpu
# Early stopping at epoch 24
# Best epoch: 19, Train Acc: 0.6722, Train Loss: 0.6135, Val Acc: 0.7029, Val Loss: 0.5708
# Restored model from best epoch 19 with val_loss: 0.570836
# NFL LSTM model 9/201 completed
# Split training data: 1678 train, 187 validation
#
# Training direct prediction LSTM model for timestep range [0.045, 0.05]
# Starting training on device: cpu
# Early stopping at epoch 24
# Best epoch: 19, Train Acc: 0.6770, Train Loss: 0.6181, Val Acc: 0.7166, Val Loss: 0.5763
# Restored model from best epoch 19 with val_loss: 0.576270
# NFL LSTM model 10/201 completed
# Split training data: 1630 train, 182 validation
#
# Training direct prediction LSTM model for timestep range [0.05, 0.055]
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 12, Train Acc: 0.6577, Train Loss: 0.6123, Val Acc: 0.6374, Val Loss: 0.6318
# Restored model from best epoch 12 with val_loss: 0.631769
# NFL LSTM model 11/201 completed
# Split training data: 1573 train, 175 validation
#
# Training direct prediction LSTM model for timestep range [0.055, 0.06]
# Starting training on device: cpu
# Early stopping at epoch 11
# Best epoch: 6, Train Acc: 0.6535, Train Loss: 0.6318, Val Acc: 0.6686, Val Loss: 0.6408
# Restored model from best epoch 6 with val_loss: 0.640835
# NFL LSTM model 12/201 completed
# Split training data: 1708 train, 190 validation
#
# Training direct prediction LSTM model for timestep range [0.06, 0.065]
# Starting training on device: cpu
# Early stopping at epoch 7
# Best epoch: 2, Train Acc: 0.6335, Train Loss: 0.6498, Val Acc: 0.5789, Val Loss: 0.6649
# Restored model from best epoch 2 with val_loss: 0.664942
# NFL LSTM model 13/201 completed
# Split training data: 1642 train, 183 validation
#
# Training direct prediction LSTM model for timestep range [0.065, 0.07]
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 10, Train Acc: 0.6657, Train Loss: 0.6214, Val Acc: 0.6612, Val Loss: 0.6037
# Restored model from best epoch 10 with val_loss: 0.603718
# NFL LSTM model 14/201 completed
# Split training data: 1677 train, 187 validation
#
# Training direct prediction LSTM model for timestep range [0.07, 0.075]
# Starting training on device: cpu
# Early stopping at epoch 22
# Best epoch: 17, Train Acc: 0.6959, Train Loss: 0.5952, Val Acc: 0.6791, Val Loss: 0.5958
# Restored model from best epoch 17 with val_loss: 0.595779
# NFL LSTM model 15/201 completed
# Split training data: 1629 train, 181 validation
#
# Training direct prediction LSTM model for timestep range [0.075, 0.08]
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 12, Train Acc: 0.6820, Train Loss: 0.6122, Val Acc: 0.6630, Val Loss: 0.6186
# Restored model from best epoch 12 with val_loss: 0.618561
# NFL LSTM model 16/201 completed
# Split training data: 1692 train, 188 validation
#
# Training direct prediction LSTM model for timestep range [0.08, 0.085]
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 8, Train Acc: 0.6761, Train Loss: 0.6120, Val Acc: 0.7234, Val Loss: 0.5487
# Restored model from best epoch 8 with val_loss: 0.548652
# NFL LSTM model 17/201 completed
# Split training data: 1711 train, 191 validation
#
# Training direct prediction LSTM model for timestep range [0.085, 0.09]
# Starting training on device: cpu
# Early stopping at epoch 9
# Best epoch: 4, Train Acc: 0.6569, Train Loss: 0.6205, Val Acc: 0.6387, Val Loss: 0.6365
# Restored model from best epoch 4 with val_loss: 0.636503
# NFL LSTM model 18/201 completed
# Split training data: 1618 train, 180 validation
#
# Training direct prediction LSTM model for timestep range [0.09, 0.095]
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 9, Train Acc: 0.6632, Train Loss: 0.6124, Val Acc: 0.6722, Val Loss: 0.6229
# Restored model from best epoch 9 with val_loss: 0.622872
# NFL LSTM model 19/201 completed
# Split training data: 1692 train, 189 validation
#
# Training direct prediction LSTM model for timestep range [0.095, 0.1]
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 10, Train Acc: 0.6673, Train Loss: 0.6150, Val Acc: 0.6190, Val Loss: 0.6470
# Restored model from best epoch 10 with val_loss: 0.647019
# NFL LSTM model 20/201 completed
# Split training data: 1663 train, 185 validation
#
# Training direct prediction LSTM model for timestep range [0.1, 0.105]
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 11, Train Acc: 0.6843, Train Loss: 0.5968, Val Acc: 0.7081, Val Loss: 0.5573
# Restored model from best epoch 11 with val_loss: 0.557346
# NFL LSTM model 21/201 completed
# Split training data: 1647 train, 184 validation
#
# Training direct prediction LSTM model for timestep range [0.105, 0.11]
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 15, Train Acc: 0.6788, Train Loss: 0.5943, Val Acc: 0.7065, Val Loss: 0.5760
# Restored model from best epoch 15 with val_loss: 0.575969
# NFL LSTM model 22/201 completed
# Split training data: 1702 train, 190 validation
#
# Training direct prediction LSTM model for timestep range [0.11, 0.115]
# Starting training on device: cpu
# Early stopping at epoch 24
# Best epoch: 19, Train Acc: 0.6786, Train Loss: 0.5960, Val Acc: 0.6579, Val Loss: 0.6107
# Restored model from best epoch 19 with val_loss: 0.610749
# NFL LSTM model 23/201 completed
# Split training data: 1637 train, 182 validation
#
# Training direct prediction LSTM model for timestep range [0.115, 0.12]
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 14, Train Acc: 0.6952, Train Loss: 0.5816, Val Acc: 0.7088, Val Loss: 0.5597
# Restored model from best epoch 14 with val_loss: 0.559704
# NFL LSTM model 24/201 completed
# Split training data: 1696 train, 189 validation
#
# Training direct prediction LSTM model for timestep range [0.12, 0.125]
# Starting training on device: cpu
# Early stopping at epoch 11
# Best epoch: 6, Train Acc: 0.6733, Train Loss: 0.6138, Val Acc: 0.6931, Val Loss: 0.5957
# Restored model from best epoch 6 with val_loss: 0.595739
# NFL LSTM model 25/201 completed
# Split training data: 1709 train, 190 validation
#
# Training direct prediction LSTM model for timestep range [0.125, 0.13]
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 8, Train Acc: 0.6905, Train Loss: 0.5807, Val Acc: 0.7105, Val Loss: 0.5884
# Restored model from best epoch 8 with val_loss: 0.588432
# NFL LSTM model 26/201 completed
# Split training data: 1688 train, 188 validation
#
# Training direct prediction LSTM model for timestep range [0.13, 0.135]
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 9, Train Acc: 0.6884, Train Loss: 0.5897, Val Acc: 0.6543, Val Loss: 0.5993
# Restored model from best epoch 9 with val_loss: 0.599263
# NFL LSTM model 27/201 completed
# Split training data: 1660 train, 185 validation
#
# Training direct prediction LSTM model for timestep range [0.135, 0.14]
# Starting training on device: cpu
# NFL LSTM model 28/201 completed
# Split training data: 1610 train, 179 validation
#
# Training direct prediction LSTM model for timestep range [0.14, 0.145]
# Starting training on device: cpu
# Early stopping at epoch 24
# Best epoch: 19, Train Acc: 0.7180, Train Loss: 0.5687, Val Acc: 0.6592, Val Loss: 0.6167
# Restored model from best epoch 19 with val_loss: 0.616744
# NFL LSTM model 29/201 completed
# Split training data: 1654 train, 184 validation
#
# Training direct prediction LSTM model for timestep range [0.145, 0.15]
# Starting training on device: cpu
# Early stopping at epoch 27
# Best epoch: 22, Train Acc: 0.7031, Train Loss: 0.5738, Val Acc: 0.7446, Val Loss: 0.5364
# Restored model from best epoch 22 with val_loss: 0.536355
# NFL LSTM model 30/201 completed
# Split training data: 1715 train, 191 validation
#
# Training direct prediction LSTM model for timestep range [0.15, 0.155]
# Starting training on device: cpu
# NFL LSTM model 31/201 completed
# Split training data: 1576 train, 176 validation
#
# Training direct prediction LSTM model for timestep range [0.155, 0.16]
# Starting training on device: cpu
# Early stopping at epoch 21
# Best epoch: 16, Train Acc: 0.7030, Train Loss: 0.5754, Val Acc: 0.6875, Val Loss: 0.5925
# Restored model from best epoch 16 with val_loss: 0.592536
# NFL LSTM model 32/201 completed
# Split training data: 1760 train, 196 validation
#
# Training direct prediction LSTM model for timestep range [0.16, 0.165]
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 15, Train Acc: 0.6994, Train Loss: 0.5759, Val Acc: 0.7245, Val Loss: 0.5478
# Restored model from best epoch 15 with val_loss: 0.547814
# NFL LSTM model 33/201 completed
# Split training data: 1605 train, 179 validation
#
# Training direct prediction LSTM model for timestep range [0.165, 0.17]
# Starting training on device: cpu
# Early stopping at epoch 29
# Best epoch: 24, Train Acc: 0.6947, Train Loss: 0.5761, Val Acc: 0.7207, Val Loss: 0.5667
# Restored model from best epoch 24 with val_loss: 0.566674
# NFL LSTM model 34/201 completed
# Split training data: 1659 train, 185 validation
#
# Training direct prediction LSTM model for timestep range [0.17, 0.175]
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 7, Train Acc: 0.7034, Train Loss: 0.5812, Val Acc: 0.7405, Val Loss: 0.5588
# Restored model from best epoch 7 with val_loss: 0.558816
# NFL LSTM model 35/201 completed
# Split training data: 1723 train, 192 validation
#
# Training direct prediction LSTM model for timestep range [0.175, 0.18]
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 14, Train Acc: 0.6866, Train Loss: 0.5972, Val Acc: 0.7083, Val Loss: 0.5565
# Restored model from best epoch 14 with val_loss: 0.556523
# NFL LSTM model 36/201 completed
# Split training data: 1614 train, 180 validation
#
# Training direct prediction LSTM model for timestep range [0.18, 0.185]
# Starting training on device: cpu
# Early stopping at epoch 26
# Best epoch: 21, Train Acc: 0.7038, Train Loss: 0.5570, Val Acc: 0.8000, Val Loss: 0.4833
# Restored model from best epoch 21 with val_loss: 0.483282
# NFL LSTM model 37/201 completed
# Split training data: 1669 train, 186 validation
#
# Training direct prediction LSTM model for timestep range [0.185, 0.19]
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 13, Train Acc: 0.7166, Train Loss: 0.5718, Val Acc: 0.7312, Val Loss: 0.5425
# Restored model from best epoch 13 with val_loss: 0.542486
# NFL LSTM model 38/201 completed
# Split training data: 1615 train, 180 validation
#
# Training direct prediction LSTM model for timestep range [0.19, 0.195]
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 10, Train Acc: 0.7276, Train Loss: 0.5617, Val Acc: 0.6833, Val Loss: 0.5846
# Restored model from best epoch 10 with val_loss: 0.584611
# NFL LSTM model 39/201 completed
# Split training data: 1681 train, 187 validation
#
# Training direct prediction LSTM model for timestep range [0.195, 0.2]
# Starting training on device: cpu
# NFL LSTM model 40/201 completed
# Split training data: 1637 train, 182 validation
#
# Training direct prediction LSTM model for timestep range [0.2, 0.205]
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 8, Train Acc: 0.6854, Train Loss: 0.5884, Val Acc: 0.6813, Val Loss: 0.5673
# Restored model from best epoch 8 with val_loss: 0.567291
# NFL LSTM model 41/201 completed
# Split training data: 1653 train, 184 validation
#
# Training direct prediction LSTM model for timestep range [0.205, 0.21]
# Starting training on device: cpu
# Early stopping at epoch 8
# Best epoch: 3, Train Acc: 0.6884, Train Loss: 0.5943, Val Acc: 0.6413, Val Loss: 0.6091
# Restored model from best epoch 3 with val_loss: 0.609075
# NFL LSTM model 42/201 completed
# Split training data: 1749 train, 195 validation
#
# Training direct prediction LSTM model for timestep range [0.21, 0.215]
# Starting training on device: cpu
# Early stopping at epoch 10
# Best epoch: 5, Train Acc: 0.6993, Train Loss: 0.5827, Val Acc: 0.7077, Val Loss: 0.5413
# Restored model from best epoch 5 with val_loss: 0.541322
# NFL LSTM model 43/201 completed
# Split training data: 1578 train, 176 validation
#
# Training direct prediction LSTM model for timestep range [0.215, 0.22]
# Starting training on device: cpu
# Early stopping at epoch 9
# Best epoch: 4, Train Acc: 0.6850, Train Loss: 0.5848, Val Acc: 0.6875, Val Loss: 0.5921
# Restored model from best epoch 4 with val_loss: 0.592060
# NFL LSTM model 44/201 completed
# Split training data: 1689 train, 188 validation
#
# Training direct prediction LSTM model for timestep range [0.22, 0.225]
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 8, Train Acc: 0.7075, Train Loss: 0.5641, Val Acc: 0.6755, Val Loss: 0.5550
# Restored model from best epoch 8 with val_loss: 0.554996
# NFL LSTM model 45/201 completed
# Split training data: 1708 train, 190 validation
#
# Training direct prediction LSTM model for timestep range [0.225, 0.23]
# Starting training on device: cpu
# NFL LSTM model 46/201 completed
# Split training data: 1597 train, 178 validation
#
# Training direct prediction LSTM model for timestep range [0.23, 0.235]
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 9, Train Acc: 0.7214, Train Loss: 0.5498, Val Acc: 0.7472, Val Loss: 0.5222
# Restored model from best epoch 9 with val_loss: 0.522201
# NFL LSTM model 47/201 completed
# Split training data: 1715 train, 191 validation
#
# Training direct prediction LSTM model for timestep range [0.235, 0.24]
# Starting training on device: cpu
# Early stopping at epoch 11
# Best epoch: 6, Train Acc: 0.7224, Train Loss: 0.5651, Val Acc: 0.6649, Val Loss: 0.5678
# Restored model from best epoch 6 with val_loss: 0.567774
# NFL LSTM model 48/201 completed
# Split training data: 1620 train, 180 validation
#
# Training direct prediction LSTM model for timestep range [0.24, 0.245]
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 11, Train Acc: 0.6957, Train Loss: 0.5713, Val Acc: 0.6833, Val Loss: 0.5993
# Restored model from best epoch 11 with val_loss: 0.599314
# NFL LSTM model 49/201 completed
# Split training data: 1519 train, 169 validation
#
# Training direct prediction LSTM model for timestep range [0.245, 0.25]
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 12, Train Acc: 0.7156, Train Loss: 0.5642, Val Acc: 0.6982, Val Loss: 0.5623
# Restored model from best epoch 12 with val_loss: 0.562282
# NFL LSTM model 50/201 completed
# Split training data: 4953 train, 551 validation
#
# Training direct prediction LSTM model for timestep range [0.25, 0.255]
# Starting training on device: cpu
# NFL LSTM model 51/201 completed
# Split training data: 983 train, 110 validation
#
# Training direct prediction LSTM model for timestep range [0.255, 0.26]
# Starting training on device: cpu
# NFL LSTM model 52/201 completed
# Split training data: 1296 train, 144 validation
#
# Training direct prediction LSTM model for timestep range [0.26, 0.265]
# Starting training on device: cpu
# NFL LSTM model 53/201 completed
# Split training data: 1745 train, 194 validation
#
# Training direct prediction LSTM model for timestep range [0.265, 0.27]
# Starting training on device: cpu
# NFL LSTM model 54/201 completed
# Split training data: 1559 train, 174 validation
#
# Training direct prediction LSTM model for timestep range [0.27, 0.275]
# Starting training on device: cpu
# NFL LSTM model 55/201 completed
# Split training data: 1774 train, 198 validation
#
# Training direct prediction LSTM model for timestep range [0.275, 0.28]
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 9, Train Acc: 0.7091, Train Loss: 0.5674, Val Acc: 0.6566, Val Loss: 0.5985
# Restored model from best epoch 9 with val_loss: 0.598546
# NFL LSTM model 56/201 completed
# Split training data: 1539 train, 171 validation
#
# Training direct prediction LSTM model for timestep range [0.28, 0.285]
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 13, Train Acc: 0.7186, Train Loss: 0.5501, Val Acc: 0.7719, Val Loss: 0.4913
# Restored model from best epoch 13 with val_loss: 0.491269
# NFL LSTM model 57/201 completed
# Split training data: 1782 train, 199 validation
#
# Training direct prediction LSTM model for timestep range [0.285, 0.29]
# Starting training on device: cpu
# Early stopping at epoch 23
# Best epoch: 18, Train Acc: 0.7441, Train Loss: 0.5265, Val Acc: 0.7387, Val Loss: 0.5343
# Restored model from best epoch 18 with val_loss: 0.534283
# NFL LSTM model 58/201 completed
# Split training data: 1626 train, 181 validation
#
# Training direct prediction LSTM model for timestep range [0.29, 0.295]
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 9, Train Acc: 0.7220, Train Loss: 0.5523, Val Acc: 0.6740, Val Loss: 0.5479
# Restored model from best epoch 9 with val_loss: 0.547939
# NFL LSTM model 59/201 completed
# Split training data: 1681 train, 187 validation
#
# Training direct prediction LSTM model for timestep range [0.295, 0.3]
# Starting training on device: cpu
# Early stopping at epoch 28
# Best epoch: 23, Train Acc: 0.7424, Train Loss: 0.5225, Val Acc: 0.6952, Val Loss: 0.5515
# Restored model from best epoch 23 with val_loss: 0.551499
# NFL LSTM model 60/201 completed
# Split training data: 1700 train, 189 validation
#
# Training direct prediction LSTM model for timestep range [0.3, 0.305]
# Starting training on device: cpu
# NFL LSTM model 61/201 completed
# Split training data: 1585 train, 177 validation
#
# Training direct prediction LSTM model for timestep range [0.305, 0.31]
# Starting training on device: cpu
# NFL LSTM model 62/201 completed
# Split training data: 1708 train, 190 validation
#
# Training direct prediction LSTM model for timestep range [0.31, 0.315]
# Starting training on device: cpu
# NFL LSTM model 63/201 completed
# Split training data: 1676 train, 187 validation
#
# Training direct prediction LSTM model for timestep range [0.315, 0.32]
# Starting training on device: cpu
# NFL LSTM model 64/201 completed
# Split training data: 1692 train, 189 validation
#
# Training direct prediction LSTM model for timestep range [0.32, 0.325]
# Starting training on device: cpu
# Early stopping at epoch 22
# Best epoch: 17, Train Acc: 0.7494, Train Loss: 0.5138, Val Acc: 0.7619, Val Loss: 0.4728
# Restored model from best epoch 17 with val_loss: 0.472809
# NFL LSTM model 65/201 completed
# Split training data: 1621 train, 181 validation
#
# Training direct prediction LSTM model for timestep range [0.325, 0.33]
# Starting training on device: cpu
# Early stopping at epoch 29
# Best epoch: 24, Train Acc: 0.7662, Train Loss: 0.5079, Val Acc: 0.7569, Val Loss: 0.5224
# Restored model from best epoch 24 with val_loss: 0.522364
# NFL LSTM model 66/201 completed
# Split training data: 1678 train, 187 validation
#
# Training direct prediction LSTM model for timestep range [0.33, 0.335]
# Starting training on device: cpu
# Early stopping at epoch 25
# Best epoch: 20, Train Acc: 0.7509, Train Loss: 0.5146, Val Acc: 0.7326, Val Loss: 0.5341
# Restored model from best epoch 20 with val_loss: 0.534058
# NFL LSTM model 67/201 completed
# Split training data: 1708 train, 190 validation
#
# Training direct prediction LSTM model for timestep range [0.335, 0.34]
# Starting training on device: cpu
# NFL LSTM model 68/201 completed
# Split training data: 1650 train, 184 validation
#
# Training direct prediction LSTM model for timestep range [0.34, 0.345]
# Starting training on device: cpu
# Early stopping at epoch 26
# Best epoch: 21, Train Acc: 0.7509, Train Loss: 0.5038, Val Acc: 0.7391, Val Loss: 0.5143
# Restored model from best epoch 21 with val_loss: 0.514303
# NFL LSTM model 69/201 completed
# Split training data: 1734 train, 193 validation
#
# Training direct prediction LSTM model for timestep range [0.345, 0.35]
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 14, Train Acc: 0.7549, Train Loss: 0.4885, Val Acc: 0.7409, Val Loss: 0.4952
# Restored model from best epoch 14 with val_loss: 0.495239
# NFL LSTM model 70/201 completed
# Split training data: 1699 train, 189 validation
#
# Training direct prediction LSTM model for timestep range [0.35, 0.355]
# Starting training on device: cpu
# NFL LSTM model 71/201 completed
# Split training data: 1688 train, 188 validation
#
# Training direct prediction LSTM model for timestep range [0.355, 0.36]
# Starting training on device: cpu
# Early stopping at epoch 25
# Best epoch: 20, Train Acc: 0.7512, Train Loss: 0.5228, Val Acc: 0.7713, Val Loss: 0.4743
# Restored model from best epoch 20 with val_loss: 0.474324
# NFL LSTM model 72/201 completed
# Split training data: 1653 train, 184 validation
#
# Training direct prediction LSTM model for timestep range [0.36, 0.365]
# Starting training on device: cpu
# Early stopping at epoch 11
# Best epoch: 6, Train Acc: 0.7145, Train Loss: 0.5493, Val Acc: 0.7500, Val Loss: 0.5102
# Restored model from best epoch 6 with val_loss: 0.510177
# NFL LSTM model 73/201 completed
# Split training data: 1719 train, 191 validation
#
# Training direct prediction LSTM model for timestep range [0.365, 0.37]
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 10, Train Acc: 0.7568, Train Loss: 0.5037, Val Acc: 0.7068, Val Loss: 0.5749
# Restored model from best epoch 10 with val_loss: 0.574897
# NFL LSTM model 74/201 completed
# Split training data: 1631 train, 182 validation
#
# Training direct prediction LSTM model for timestep range [0.37, 0.375]
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 10, Train Acc: 0.7505, Train Loss: 0.5275, Val Acc: 0.7473, Val Loss: 0.5155
# Restored model from best epoch 10 with val_loss: 0.515451
# NFL LSTM model 75/201 completed
# Split training data: 1696 train, 189 validation
#
# Training direct prediction LSTM model for timestep range [0.375, 0.38]
# Starting training on device: cpu
# Early stopping at epoch 28
# Best epoch: 23, Train Acc: 0.7712, Train Loss: 0.4951, Val Acc: 0.7196, Val Loss: 0.5313
# Restored model from best epoch 23 with val_loss: 0.531302
# NFL LSTM model 76/201 completed
# Split training data: 1652 train, 184 validation
#
# Training direct prediction LSTM model for timestep range [0.38, 0.385]
# Starting training on device: cpu
# NFL LSTM model 77/201 completed
# Split training data: 1660 train, 185 validation
#
# Training direct prediction LSTM model for timestep range [0.385, 0.39]
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 15, Train Acc: 0.7440, Train Loss: 0.5013, Val Acc: 0.7730, Val Loss: 0.4881
# Restored model from best epoch 15 with val_loss: 0.488135
# NFL LSTM model 78/201 completed
# Split training data: 1664 train, 185 validation
#
# Training direct prediction LSTM model for timestep range [0.39, 0.395]
# Starting training on device: cpu
# NFL LSTM model 79/201 completed
# Split training data: 1710 train, 190 validation
#
# Training direct prediction LSTM model for timestep range [0.395, 0.4]
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 11, Train Acc: 0.7480, Train Loss: 0.5153, Val Acc: 0.7368, Val Loss: 0.4909
# Restored model from best epoch 11 with val_loss: 0.490915
# NFL LSTM model 80/201 completed
# Split training data: 1670 train, 186 validation
#
# Training direct prediction LSTM model for timestep range [0.4, 0.405]
# Starting training on device: cpu
# Early stopping at epoch 8
# Best epoch: 3, Train Acc: 0.7096, Train Loss: 0.5580, Val Acc: 0.6667, Val Loss: 0.5869
# Restored model from best epoch 3 with val_loss: 0.586929
# NFL LSTM model 81/201 completed
# Split training data: 1587 train, 177 validation
#
# Training direct prediction LSTM model for timestep range [0.405, 0.41]
# Starting training on device: cpu
# Early stopping at epoch 9
# Best epoch: 4, Train Acc: 0.7511, Train Loss: 0.5133, Val Acc: 0.7458, Val Loss: 0.5076
# Restored model from best epoch 4 with val_loss: 0.507550
# NFL LSTM model 82/201 completed
# Split training data: 1732 train, 193 validation
#
# Training direct prediction LSTM model for timestep range [0.41, 0.415]
# Starting training on device: cpu
# Early stopping at epoch 27
# Best epoch: 22, Train Acc: 0.7598, Train Loss: 0.4905, Val Acc: 0.7617, Val Loss: 0.4262
# Restored model from best epoch 22 with val_loss: 0.426236
# NFL LSTM model 83/201 completed
# Split training data: 1669 train, 186 validation
#
# Training direct prediction LSTM model for timestep range [0.415, 0.42]
# Starting training on device: cpu
# Early stopping at epoch 27
# Best epoch: 22, Train Acc: 0.7543, Train Loss: 0.4932, Val Acc: 0.7849, Val Loss: 0.5025
# Restored model from best epoch 22 with val_loss: 0.502467
# NFL LSTM model 84/201 completed
# Split training data: 1720 train, 192 validation
#
# Training direct prediction LSTM model for timestep range [0.42, 0.425]
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 13, Train Acc: 0.7512, Train Loss: 0.5114, Val Acc: 0.7188, Val Loss: 0.5099
# Restored model from best epoch 13 with val_loss: 0.509857
# NFL LSTM model 85/201 completed
# Split training data: 1678 train, 187 validation
#
# Training direct prediction LSTM model for timestep range [0.425, 0.43]
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 14, Train Acc: 0.7652, Train Loss: 0.4916, Val Acc: 0.7380, Val Loss: 0.5213
# Restored model from best epoch 14 with val_loss: 0.521337
# NFL LSTM model 86/201 completed
# Split training data: 1671 train, 186 validation
#
# Training direct prediction LSTM model for timestep range [0.43, 0.435]
# Starting training on device: cpu
# Early stopping at epoch 8
# Best epoch: 3, Train Acc: 0.7445, Train Loss: 0.5394, Val Acc: 0.7043, Val Loss: 0.5653
# Restored model from best epoch 3 with val_loss: 0.565332
# NFL LSTM model 87/201 completed
# Split training data: 1731 train, 193 validation
#
# Training direct prediction LSTM model for timestep range [0.435, 0.44]
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 14, Train Acc: 0.7701, Train Loss: 0.4909, Val Acc: 0.7513, Val Loss: 0.5927
# Restored model from best epoch 14 with val_loss: 0.592706
# NFL LSTM model 88/201 completed
# Split training data: 1637 train, 182 validation
#
# Training direct prediction LSTM model for timestep range [0.44, 0.445]
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 10, Train Acc: 0.7495, Train Loss: 0.5164, Val Acc: 0.7363, Val Loss: 0.4468
# Restored model from best epoch 10 with val_loss: 0.446764
# NFL LSTM model 89/201 completed
# Split training data: 1709 train, 190 validation
#
# Training direct prediction LSTM model for timestep range [0.445, 0.45]
# Starting training on device: cpu
# Early stopping at epoch 23
# Best epoch: 18, Train Acc: 0.7765, Train Loss: 0.4625, Val Acc: 0.7474, Val Loss: 0.5083
# Restored model from best epoch 18 with val_loss: 0.508283
# NFL LSTM model 90/201 completed
# Split training data: 1690 train, 188 validation
#
# Training direct prediction LSTM model for timestep range [0.45, 0.455]
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 13, Train Acc: 0.7609, Train Loss: 0.4949, Val Acc: 0.7447, Val Loss: 0.5103
# Restored model from best epoch 13 with val_loss: 0.510333
# NFL LSTM model 91/201 completed
# Split training data: 1691 train, 188 validation
#
# Training direct prediction LSTM model for timestep range [0.455, 0.46]
# Starting training on device: cpu
# NFL LSTM model 92/201 completed
# Split training data: 1723 train, 192 validation
#
# Training direct prediction LSTM model for timestep range [0.46, 0.465]
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 13, Train Acc: 0.7864, Train Loss: 0.4653, Val Acc: 0.7448, Val Loss: 0.5127
# Restored model from best epoch 13 with val_loss: 0.512672
# NFL LSTM model 93/201 completed
# Split training data: 1616 train, 180 validation
#
# Training direct prediction LSTM model for timestep range [0.465, 0.47]
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 11, Train Acc: 0.7871, Train Loss: 0.4726, Val Acc: 0.7611, Val Loss: 0.4676
# Restored model from best epoch 11 with val_loss: 0.467605
# NFL LSTM model 94/201 completed
# Split training data: 4663 train, 519 validation
#
# Training direct prediction LSTM model for timestep range [0.47, 0.475]
# Starting training on device: cpu
# Early stopping at epoch 24
# Best epoch: 19, Train Acc: 0.7918, Train Loss: 0.4501, Val Acc: 0.7707, Val Loss: 0.4960
# Restored model from best epoch 19 with val_loss: 0.495965
# NFL LSTM model 95/201 completed
# Split training data: 2369 train, 264 validation
#
# Training direct prediction LSTM model for timestep range [0.475, 0.48]
# Starting training on device: cpu
# NFL LSTM model 96/201 completed
# Split training data: 2547 train, 284 validation
#
# Training direct prediction LSTM model for timestep range [0.48, 0.485]
# Starting training on device: cpu
# Early stopping at epoch 22
# Best epoch: 17, Train Acc: 0.7856, Train Loss: 0.4486, Val Acc: 0.8063, Val Loss: 0.4378
# Restored model from best epoch 17 with val_loss: 0.437762
# NFL LSTM model 97/201 completed
# Split training data: 2877 train, 320 validation
#
# Training direct prediction LSTM model for timestep range [0.485, 0.49]
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 15, Train Acc: 0.7842, Train Loss: 0.4530, Val Acc: 0.7937, Val Loss: 0.4498
# Restored model from best epoch 15 with val_loss: 0.449849
# NFL LSTM model 98/201 completed
# Split training data: 3471 train, 386 validation
#
# Training direct prediction LSTM model for timestep range [0.49, 0.495]
# Starting training on device: cpu
# Early stopping at epoch 28
# Best epoch: 23, Train Acc: 0.7949, Train Loss: 0.4483, Val Acc: 0.8057, Val Loss: 0.4241
# Restored model from best epoch 23 with val_loss: 0.424122
# NFL LSTM model 99/201 completed
# Split training data: 4170 train, 464 validation
#
# Training direct prediction LSTM model for timestep range [0.495, 0.5]
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 13, Train Acc: 0.7976, Train Loss: 0.4527, Val Acc: 0.7866, Val Loss: 0.4436
# Restored model from best epoch 13 with val_loss: 0.443565
# NFL LSTM model 100/201 completed
# Split training data: 7587 train, 843 validation
#
# Training direct prediction LSTM model for timestep range [0.5, 0.505]
# Starting training on device: cpu
# NFL LSTM model 101/201 completed
# Split training data: 983 train, 110 validation
#
# Training direct prediction LSTM model for timestep range [0.505, 0.51]
# Starting training on device: cpu
# Early stopping at epoch 24
# Best epoch: 19, Train Acc: 0.8189, Train Loss: 0.4179, Val Acc: 0.7909, Val Loss: 0.4188
# Restored model from best epoch 19 with val_loss: 0.418816
# NFL LSTM model 102/201 completed
# Split training data: 1591 train, 177 validation
#
# Training direct prediction LSTM model for timestep range [0.51, 0.515]
# Starting training on device: cpu
# Early stopping at epoch 21
# Best epoch: 16, Train Acc: 0.8014, Train Loss: 0.4434, Val Acc: 0.7910, Val Loss: 0.4777
# Restored model from best epoch 16 with val_loss: 0.477731
# NFL LSTM model 103/201 completed
# Split training data: 1379 train, 154 validation
#
# Training direct prediction LSTM model for timestep range [0.515, 0.52]
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 7, Train Acc: 0.8151, Train Loss: 0.4398, Val Acc: 0.7922, Val Loss: 0.4560
# Restored model from best epoch 7 with val_loss: 0.455968
# NFL LSTM model 104/201 completed
# Split training data: 1559 train, 174 validation
#
# Training direct prediction LSTM model for timestep range [0.52, 0.525]
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 7, Train Acc: 0.7960, Train Loss: 0.4498, Val Acc: 0.8103, Val Loss: 0.4201
# Restored model from best epoch 7 with val_loss: 0.420103
# NFL LSTM model 105/201 completed
# Split training data: 1647 train, 184 validation
#
# Training direct prediction LSTM model for timestep range [0.525, 0.53]
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 7, Train Acc: 0.8033, Train Loss: 0.4442, Val Acc: 0.8207, Val Loss: 0.4159
# Restored model from best epoch 7 with val_loss: 0.415880
# NFL LSTM model 106/201 completed
# Split training data: 1584 train, 177 validation
#
# Training direct prediction LSTM model for timestep range [0.53, 0.535]
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 11, Train Acc: 0.7866, Train Loss: 0.4551, Val Acc: 0.8362, Val Loss: 0.4216
# Restored model from best epoch 11 with val_loss: 0.421587
# NFL LSTM model 107/201 completed
# Split training data: 1665 train, 186 validation
#
# Training direct prediction LSTM model for timestep range [0.535, 0.54]
# Starting training on device: cpu
# Early stopping at epoch 10
# Best epoch: 5, Train Acc: 0.8108, Train Loss: 0.4408, Val Acc: 0.7957, Val Loss: 0.4364
# Restored model from best epoch 5 with val_loss: 0.436376
# NFL LSTM model 108/201 completed
# Split training data: 1599 train, 178 validation
#
# Training direct prediction LSTM model for timestep range [0.54, 0.545]
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 11, Train Acc: 0.7924, Train Loss: 0.4572, Val Acc: 0.8371, Val Loss: 0.4180
# Restored model from best epoch 11 with val_loss: 0.418003
# NFL LSTM model 109/201 completed
# Split training data: 1595 train, 178 validation
#
# Training direct prediction LSTM model for timestep range [0.545, 0.55]
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 12, Train Acc: 0.8169, Train Loss: 0.4298, Val Acc: 0.7584, Val Loss: 0.5241
# Restored model from best epoch 12 with val_loss: 0.524091
# NFL LSTM model 110/201 completed
# Split training data: 1640 train, 183 validation
#
# Training direct prediction LSTM model for timestep range [0.55, 0.555]
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 15, Train Acc: 0.8128, Train Loss: 0.4065, Val Acc: 0.7978, Val Loss: 0.4475
# Restored model from best epoch 15 with val_loss: 0.447540
# NFL LSTM model 111/201 completed
# Split training data: 1621 train, 181 validation
#
# Training direct prediction LSTM model for timestep range [0.555, 0.56]
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 15, Train Acc: 0.8069, Train Loss: 0.4287, Val Acc: 0.7956, Val Loss: 0.4283
# Restored model from best epoch 15 with val_loss: 0.428275
# NFL LSTM model 112/201 completed
# Split training data: 1639 train, 183 validation
#
# Training direct prediction LSTM model for timestep range [0.56, 0.565]
# Starting training on device: cpu
# Early stopping at epoch 21
# Best epoch: 16, Train Acc: 0.8176, Train Loss: 0.4192, Val Acc: 0.8306, Val Loss: 0.3914
# Restored model from best epoch 16 with val_loss: 0.391383
# NFL LSTM model 113/201 completed
# Split training data: 1677 train, 187 validation
#
# Training direct prediction LSTM model for timestep range [0.565, 0.57]
# Starting training on device: cpu
# Early stopping at epoch 25
# Best epoch: 20, Train Acc: 0.8312, Train Loss: 0.4064, Val Acc: 0.7861, Val Loss: 0.4154
# Restored model from best epoch 20 with val_loss: 0.415360
# NFL LSTM model 114/201 completed
# Split training data: 1705 train, 190 validation
#
# Training direct prediction LSTM model for timestep range [0.57, 0.575]
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 8, Train Acc: 0.8129, Train Loss: 0.4320, Val Acc: 0.7789, Val Loss: 0.4551
# Restored model from best epoch 8 with val_loss: 0.455098
# NFL LSTM model 115/201 completed
# Split training data: 1701 train, 190 validation
#
# Training direct prediction LSTM model for timestep range [0.575, 0.58]
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 11, Train Acc: 0.7960, Train Loss: 0.4308, Val Acc: 0.8105, Val Loss: 0.3978
# Restored model from best epoch 11 with val_loss: 0.397846
# NFL LSTM model 116/201 completed
# Split training data: 1615 train, 180 validation
#
# Training direct prediction LSTM model for timestep range [0.58, 0.585]
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 9, Train Acc: 0.7926, Train Loss: 0.4492, Val Acc: 0.8278, Val Loss: 0.3813
# Restored model from best epoch 9 with val_loss: 0.381329
# NFL LSTM model 117/201 completed
# Split training data: 1638 train, 182 validation
#
# Training direct prediction LSTM model for timestep range [0.585, 0.59]
# Starting training on device: cpu
# Early stopping at epoch 11
# Best epoch: 6, Train Acc: 0.8089, Train Loss: 0.4408, Val Acc: 0.8077, Val Loss: 0.4340
# Restored model from best epoch 6 with val_loss: 0.434018
# NFL LSTM model 118/201 completed
# Split training data: 1734 train, 193 validation
#
# Training direct prediction LSTM model for timestep range [0.59, 0.595]
# Starting training on device: cpu
# NFL LSTM model 119/201 completed
# Split training data: 1705 train, 190 validation
#
# Training direct prediction LSTM model for timestep range [0.595, 0.6]
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 8, Train Acc: 0.8088, Train Loss: 0.4309, Val Acc: 0.7526, Val Loss: 0.4880
# Restored model from best epoch 8 with val_loss: 0.488004
# NFL LSTM model 120/201 completed
# Split training data: 1667 train, 186 validation
#
# Training direct prediction LSTM model for timestep range [0.6, 0.605]
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 15, Train Acc: 0.8182, Train Loss: 0.4150, Val Acc: 0.8333, Val Loss: 0.3808
# Restored model from best epoch 15 with val_loss: 0.380751
# NFL LSTM model 121/201 completed
# Split training data: 1710 train, 191 validation
#
# Training direct prediction LSTM model for timestep range [0.605, 0.61]
# Starting training on device: cpu
# Early stopping at epoch 11
# Best epoch: 6, Train Acc: 0.8140, Train Loss: 0.4425, Val Acc: 0.8063, Val Loss: 0.4450
# Restored model from best epoch 6 with val_loss: 0.444960
# NFL LSTM model 122/201 completed
# Split training data: 1722 train, 192 validation
#
# Training direct prediction LSTM model for timestep range [0.61, 0.615]
# Starting training on device: cpu
# Early stopping at epoch 23
# Best epoch: 18, Train Acc: 0.8211, Train Loss: 0.4169, Val Acc: 0.8021, Val Loss: 0.3892
# Restored model from best epoch 18 with val_loss: 0.389246
# NFL LSTM model 123/201 completed
# Split training data: 1683 train, 187 validation
#
# Training direct prediction LSTM model for timestep range [0.615, 0.62]
# Starting training on device: cpu
# Early stopping at epoch 25
# Best epoch: 20, Train Acc: 0.8271, Train Loss: 0.3886, Val Acc: 0.7914, Val Loss: 0.4044
# Restored model from best epoch 20 with val_loss: 0.404371
# NFL LSTM model 124/201 completed
# Split training data: 1670 train, 186 validation
#
# Training direct prediction LSTM model for timestep range [0.62, 0.625]
# Starting training on device: cpu
# Early stopping at epoch 22
# Best epoch: 17, Train Acc: 0.8174, Train Loss: 0.4054, Val Acc: 0.8118, Val Loss: 0.3790
# Restored model from best epoch 17 with val_loss: 0.379023
# NFL LSTM model 125/201 completed
# Split training data: 1734 train, 193 validation
#
# Training direct prediction LSTM model for timestep range [0.625, 0.63]
# Starting training on device: cpu
# Early stopping at epoch 9
# Best epoch: 4, Train Acc: 0.7987, Train Loss: 0.4485, Val Acc: 0.7358, Val Loss: 0.4634
# Restored model from best epoch 4 with val_loss: 0.463370
# NFL LSTM model 126/201 completed
# Split training data: 1679 train, 187 validation
#
# Training direct prediction LSTM model for timestep range [0.63, 0.635]
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 9, Train Acc: 0.8273, Train Loss: 0.4010, Val Acc: 0.7914, Val Loss: 0.4769
# Restored model from best epoch 9 with val_loss: 0.476883
# NFL LSTM model 127/201 completed
# Split training data: 1671 train, 186 validation
#
# Training direct prediction LSTM model for timestep range [0.635, 0.64]
# Starting training on device: cpu
# Early stopping at epoch 27
# Best epoch: 22, Train Acc: 0.8265, Train Loss: 0.3922, Val Acc: 0.8011, Val Loss: 0.4361
# Restored model from best epoch 22 with val_loss: 0.436147
# NFL LSTM model 128/201 completed
# Split training data: 1600 train, 178 validation
#
# Training direct prediction LSTM model for timestep range [0.64, 0.645]
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 11, Train Acc: 0.8225, Train Loss: 0.4153, Val Acc: 0.8258, Val Loss: 0.3879
# Restored model from best epoch 11 with val_loss: 0.387918
# NFL LSTM model 129/201 completed
# Split training data: 1738 train, 194 validation
#
# Training direct prediction LSTM model for timestep range [0.645, 0.65]
# Starting training on device: cpu
# Early stopping at epoch 22
# Best epoch: 17, Train Acc: 0.8280, Train Loss: 0.4038, Val Acc: 0.8144, Val Loss: 0.3972
# Restored model from best epoch 17 with val_loss: 0.397153
# NFL LSTM model 130/201 completed
# Split training data: 1681 train, 187 validation
#
# Training direct prediction LSTM model for timestep range [0.65, 0.655]
# Starting training on device: cpu
# NFL LSTM model 131/201 completed
# Split training data: 1713 train, 191 validation
#
# Training direct prediction LSTM model for timestep range [0.655, 0.66]
# Starting training on device: cpu
# NFL LSTM model 132/201 completed
# Split training data: 1717 train, 191 validation
#
# Training direct prediction LSTM model for timestep range [0.66, 0.665]
# Starting training on device: cpu
# NFL LSTM model 133/201 completed
# Split training data: 1679 train, 187 validation
#
# Training direct prediction LSTM model for timestep range [0.665, 0.67]
# Starting training on device: cpu
# NFL LSTM model 134/201 completed
# Split training data: 1689 train, 188 validation
#
# Training direct prediction LSTM model for timestep range [0.67, 0.675]
# Starting training on device: cpu
# Early stopping at epoch 23
# Best epoch: 18, Train Acc: 0.8396, Train Loss: 0.3776, Val Acc: 0.8457, Val Loss: 0.3588
# Restored model from best epoch 18 with val_loss: 0.358764
# NFL LSTM model 135/201 completed
# Split training data: 1639 train, 183 validation
#
# Training direct prediction LSTM model for timestep range [0.675, 0.68]
# Starting training on device: cpu
# Early stopping at epoch 25
# Best epoch: 20, Train Acc: 0.8353, Train Loss: 0.3934, Val Acc: 0.8306, Val Loss: 0.3512
# Restored model from best epoch 20 with val_loss: 0.351240
# NFL LSTM model 136/201 completed
# Split training data: 1665 train, 185 validation
#
# Training direct prediction LSTM model for timestep range [0.68, 0.685]
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 12, Train Acc: 0.8252, Train Loss: 0.3947, Val Acc: 0.8270, Val Loss: 0.3858
# Restored model from best epoch 12 with val_loss: 0.385819
# NFL LSTM model 137/201 completed
# Split training data: 1733 train, 193 validation
#
# Training direct prediction LSTM model for timestep range [0.685, 0.69]
# Starting training on device: cpu
# NFL LSTM model 138/201 completed
# Split training data: 1687 train, 188 validation
#
# Training direct prediction LSTM model for timestep range [0.69, 0.695]
# Starting training on device: cpu
# Early stopping at epoch 11
# Best epoch: 6, Train Acc: 0.8263, Train Loss: 0.4023, Val Acc: 0.8191, Val Loss: 0.4098
# Restored model from best epoch 6 with val_loss: 0.409785
# NFL LSTM model 139/201 completed
# Split training data: 1664 train, 185 validation
#
# Training direct prediction LSTM model for timestep range [0.695, 0.7]
# Starting training on device: cpu
# Early stopping at epoch 24
# Best epoch: 19, Train Acc: 0.8401, Train Loss: 0.3570, Val Acc: 0.8378, Val Loss: 0.3635
# Restored model from best epoch 19 with val_loss: 0.363503
# NFL LSTM model 140/201 completed
# Split training data: 1711 train, 191 validation
#
# Training direct prediction LSTM model for timestep range [0.7, 0.705]
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 7, Train Acc: 0.8334, Train Loss: 0.3951, Val Acc: 0.8115, Val Loss: 0.4383
# Restored model from best epoch 7 with val_loss: 0.438324
# NFL LSTM model 141/201 completed
# Split training data: 1638 train, 182 validation
#
# Training direct prediction LSTM model for timestep range [0.705, 0.71]
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 11, Train Acc: 0.8413, Train Loss: 0.3760, Val Acc: 0.8516, Val Loss: 0.3519
# Restored model from best epoch 11 with val_loss: 0.351929
# NFL LSTM model 142/201 completed
# Split training data: 1639 train, 183 validation
#
# Training direct prediction LSTM model for timestep range [0.71, 0.715]
# Starting training on device: cpu
# Early stopping at epoch 27
# Best epoch: 22, Train Acc: 0.8469, Train Loss: 0.3541, Val Acc: 0.7596, Val Loss: 0.4416
# Restored model from best epoch 22 with val_loss: 0.441597
# NFL LSTM model 143/201 completed
# Split training data: 1706 train, 190 validation
#
# Training direct prediction LSTM model for timestep range [0.715, 0.72]
# Starting training on device: cpu
# NFL LSTM model 144/201 completed
# Split training data: 1688 train, 188 validation
#
# Training direct prediction LSTM model for timestep range [0.72, 0.725]
# Starting training on device: cpu
# Early stopping at epoch 28
# Best epoch: 23, Train Acc: 0.8531, Train Loss: 0.3464, Val Acc: 0.8564, Val Loss: 0.3312
# Restored model from best epoch 23 with val_loss: 0.331199
# NFL LSTM model 145/201 completed
# Split training data: 1735 train, 193 validation
#
# Training direct prediction LSTM model for timestep range [0.725, 0.73]
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 9, Train Acc: 0.8334, Train Loss: 0.3914, Val Acc: 0.8290, Val Loss: 0.3724
# Restored model from best epoch 9 with val_loss: 0.372429
# NFL LSTM model 146/201 completed
# Split training data: 1721 train, 192 validation
#
# Training direct prediction LSTM model for timestep range [0.73, 0.735]
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 13, Train Acc: 0.8530, Train Loss: 0.3537, Val Acc: 0.7604, Val Loss: 0.4664
# Restored model from best epoch 13 with val_loss: 0.466438
# NFL LSTM model 147/201 completed
# Split training data: 1666 train, 186 validation
#
# Training direct prediction LSTM model for timestep range [0.735, 0.74]
# Starting training on device: cpu
# Early stopping at epoch 25
# Best epoch: 20, Train Acc: 0.8523, Train Loss: 0.3557, Val Acc: 0.8656, Val Loss: 0.3105
# Restored model from best epoch 20 with val_loss: 0.310476
# NFL LSTM model 148/201 completed
# Split training data: 1551 train, 173 validation
#
# Training direct prediction LSTM model for timestep range [0.74, 0.745]
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 13, Train Acc: 0.8517, Train Loss: 0.3663, Val Acc: 0.8324, Val Loss: 0.3394
# Restored model from best epoch 13 with val_loss: 0.339377
# NFL LSTM model 149/201 completed
# Split training data: 1493 train, 166 validation
#
# Training direct prediction LSTM model for timestep range [0.745, 0.75]
# ...
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 8, Train Acc: 0.8626, Train Loss: 0.3553, Val Acc: 0.8514, Val Loss: 0.3583
# Restored model from best epoch 8 with val_loss: 0.358283
# NFL LSTM model 153/201 completed
# Split training data: 1746 train, 194 validation
#
# Training direct prediction LSTM model for timestep range [0.765, 0.77]
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 15, Train Acc: 0.8625, Train Loss: 0.3298, Val Acc: 0.8505, Val Loss: 0.3090
# Restored model from best epoch 15 with val_loss: 0.309044
# NFL LSTM model 154/201 completed
# Split training data: 1511 train, 168 validation
#
# Training direct prediction LSTM model for timestep range [0.77, 0.775]
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 15, Train Acc: 0.8412, Train Loss: 0.3562, Val Acc: 0.8571, Val Loss: 0.3244
# Restored model from best epoch 15 with val_loss: 0.324449
# NFL LSTM model 155/201 completed
# Split training data: 1859 train, 207 validation
#
# Training direct prediction LSTM model for timestep range [0.775, 0.78]
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 14, Train Acc: 0.8580, Train Loss: 0.3304, Val Acc: 0.8647, Val Loss: 0.3447
# Restored model from best epoch 14 with val_loss: 0.344675
# NFL LSTM model 156/201 completed
# Split training data: 1592 train, 177 validation
#
# Training direct prediction LSTM model for timestep range [0.78, 0.785]
# Starting training on device: cpu
# Early stopping at epoch 26
# Best epoch: 21, Train Acc: 0.8649, Train Loss: 0.3231, Val Acc: 0.8362, Val Loss: 0.3737
# Restored model from best epoch 21 with val_loss: 0.373689
# NFL LSTM model 157/201 completed
# Split training data: 1737 train, 193 validation
#
# Training direct prediction LSTM model for timestep range [0.785, 0.79]
# Starting training on device: cpu
# NFL LSTM model 158/201 completed
# Split training data: 1630 train, 182 validation
#
# Training direct prediction LSTM model for timestep range [0.79, 0.795]
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 14, Train Acc: 0.8791, Train Loss: 0.3044, Val Acc: 0.8297, Val Loss: 0.3696
# Restored model from best epoch 14 with val_loss: 0.369632
# NFL LSTM model 159/201 completed
# Split training data: 1611 train, 179 validation
#
# Training direct prediction LSTM model for timestep range [0.795, 0.8]
# Starting training on device: cpu
# NFL LSTM model 160/201 completed
# Split training data: 1800 train, 200 validation
#
# Training direct prediction LSTM model for timestep range [0.8, 0.805]
# Starting training on device: cpu
# NFL LSTM model 161/201 completed
# Split training data: 1728 train, 193 validation
#
# Training direct prediction LSTM model for timestep range [0.805, 0.81]
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 15, Train Acc: 0.8675, Train Loss: 0.3258, Val Acc: 0.8705, Val Loss: 0.2683
# Restored model from best epoch 15 with val_loss: 0.268264
# NFL LSTM model 162/201 completed
# Split training data: 1706 train, 190 validation
#
# Training direct prediction LSTM model for timestep range [0.81, 0.815]
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 11, Train Acc: 0.8734, Train Loss: 0.3232, Val Acc: 0.8526, Val Loss: 0.3521
# Restored model from best epoch 11 with val_loss: 0.352134
# NFL LSTM model 163/201 completed
# Split training data: 1681 train, 187 validation
#
# Training direct prediction LSTM model for timestep range [0.815, 0.82]
# Starting training on device: cpu
# NFL LSTM model 164/201 completed
# Split training data: 1755 train, 195 validation
#
# Training direct prediction LSTM model for timestep range [0.82, 0.825]
# Starting training on device: cpu
# Early stopping at epoch 25
# Best epoch: 20, Train Acc: 0.8735, Train Loss: 0.3070, Val Acc: 0.8974, Val Loss: 0.2329
# Restored model from best epoch 20 with val_loss: 0.232881
# NFL LSTM model 165/201 completed
# Split training data: 1619 train, 180 validation
#
# Training direct prediction LSTM model for timestep range [0.825, 0.83]
# Starting training on device: cpu
# Early stopping at epoch 22
# Best epoch: 17, Train Acc: 0.8771, Train Loss: 0.3069, Val Acc: 0.8222, Val Loss: 0.3359
# Restored model from best epoch 17 with val_loss: 0.335870
# NFL LSTM model 166/201 completed
# Split training data: 1687 train, 188 validation
#
# Training direct prediction LSTM model for timestep range [0.83, 0.835]
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 8, Train Acc: 0.8601, Train Loss: 0.3458, Val Acc: 0.8777, Val Loss: 0.3131
# Restored model from best epoch 8 with val_loss: 0.313104
# NFL LSTM model 167/201 completed
# Split training data: 1695 train, 189 validation
#
# Training direct prediction LSTM model for timestep range [0.835, 0.84]
# Starting training on device: cpu
# Early stopping at epoch 11
# Best epoch: 6, Train Acc: 0.8926, Train Loss: 0.3037, Val Acc: 0.8519, Val Loss: 0.3222
# Restored model from best epoch 6 with val_loss: 0.322235
# NFL LSTM model 168/201 completed
# Split training data: 1687 train, 188 validation
#
# Training direct prediction LSTM model for timestep range [0.84, 0.845]
# Starting training on device: cpu
# Early stopping at epoch 11
# Best epoch: 6, Train Acc: 0.8702, Train Loss: 0.3193, Val Acc: 0.8245, Val Loss: 0.3478
# Restored model from best epoch 6 with val_loss: 0.347776
# NFL LSTM model 169/201 completed
# Split training data: 1717 train, 191 validation
#
# Training direct prediction LSTM model for timestep range [0.845, 0.85]
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 10, Train Acc: 0.8643, Train Loss: 0.3262, Val Acc: 0.8377, Val Loss: 0.3268
# Restored model from best epoch 10 with val_loss: 0.326782
# NFL LSTM model 170/201 completed
# Split training data: 1709 train, 190 validation
#
# Training direct prediction LSTM model for timestep range [0.85, 0.855]
# Starting training on device: cpu
# NFL LSTM model 171/201 completed
# Split training data: 1665 train, 186 validation
#
# Training direct prediction LSTM model for timestep range [0.855, 0.86]
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 12, Train Acc: 0.8769, Train Loss: 0.2966, Val Acc: 0.8763, Val Loss: 0.2956
# Restored model from best epoch 12 with val_loss: 0.295633
# NFL LSTM model 172/201 completed
# Split training data: 1709 train, 190 validation
#
# Training direct prediction LSTM model for timestep range [0.86, 0.865]
# Starting training on device: cpu
# Early stopping at epoch 10
# Best epoch: 5, Train Acc: 0.8719, Train Loss: 0.3183, Val Acc: 0.8579, Val Loss: 0.3333
# Restored model from best epoch 5 with val_loss: 0.333294
# NFL LSTM model 173/201 completed
# Split training data: 1679 train, 187 validation
#
# Training direct prediction LSTM model for timestep range [0.865, 0.87]
# Starting training on device: cpu
# Early stopping at epoch 30
# Best epoch: 25, Train Acc: 0.8773, Train Loss: 0.2939, Val Acc: 0.8984, Val Loss: 0.2050
# Restored model from best epoch 25 with val_loss: 0.204974
# NFL LSTM model 174/201 completed
# Split training data: 1686 train, 188 validation
#
# Training direct prediction LSTM model for timestep range [0.87, 0.875]
# Starting training on device: cpu
# NFL LSTM model 175/201 completed
# Split training data: 1739 train, 194 validation
#
# Training direct prediction LSTM model for timestep range [0.875, 0.88]
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 7, Train Acc: 0.8850, Train Loss: 0.3068, Val Acc: 0.9021, Val Loss: 0.2637
# Restored model from best epoch 7 with val_loss: 0.263749
# NFL LSTM model 176/201 completed
# Split training data: 1704 train, 190 validation
#
# Training direct prediction LSTM model for timestep range [0.88, 0.885]
# Starting training on device: cpu
# Early stopping at epoch 24
# Best epoch: 19, Train Acc: 0.8826, Train Loss: 0.2833, Val Acc: 0.8684, Val Loss: 0.2790
# Restored model from best epoch 19 with val_loss: 0.278965
# NFL LSTM model 177/201 completed
# Split training data: 1711 train, 191 validation
#
# Training direct prediction LSTM model for timestep range [0.885, 0.89]
# Starting training on device: cpu
# Early stopping at epoch 29
# Best epoch: 24, Train Acc: 0.8814, Train Loss: 0.2731, Val Acc: 0.8691, Val Loss: 0.3127
# Restored model from best epoch 24 with val_loss: 0.312706
# NFL LSTM model 178/201 completed
# Split training data: 1736 train, 193 validation
#
# Training direct prediction LSTM model for timestep range [0.89, 0.895]
# Starting training on device: cpu
# Early stopping at epoch 11
# Best epoch: 6, Train Acc: 0.8635, Train Loss: 0.3365, Val Acc: 0.8964, Val Loss: 0.2725
# Restored model from best epoch 6 with val_loss: 0.272488
# NFL LSTM model 179/201 completed
# Split training data: 1753 train, 195 validation
#
# Training direct prediction LSTM model for timestep range [0.895, 0.9]
# Starting training on device: cpu
# Early stopping at epoch 11
# Best epoch: 6, Train Acc: 0.8916, Train Loss: 0.2844, Val Acc: 0.8718, Val Loss: 0.2785
# Restored model from best epoch 6 with val_loss: 0.278515
# NFL LSTM model 180/201 completed
# Split training data: 1698 train, 189 validation
#
# Training direct prediction LSTM model for timestep range [0.9, 0.905]
# Starting training on device: cpu
# Early stopping at epoch 29
# Best epoch: 24, Train Acc: 0.8746, Train Loss: 0.2788, Val Acc: 0.8254, Val Loss: 0.3636
# Restored model from best epoch 24 with val_loss: 0.363606
# NFL LSTM model 181/201 completed
# Split training data: 1741 train, 194 validation
#
# Training direct prediction LSTM model for timestep range [0.905, 0.91]
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 13, Train Acc: 0.8834, Train Loss: 0.2740, Val Acc: 0.8608, Val Loss: 0.3806
# Restored model from best epoch 13 with val_loss: 0.380573
# NFL LSTM model 182/201 completed
# Split training data: 1769 train, 197 validation
#
# Training direct prediction LSTM model for timestep range [0.91, 0.915]
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 12, Train Acc: 0.8898, Train Loss: 0.2762, Val Acc: 0.8883, Val Loss: 0.2455
# Restored model from best epoch 12 with val_loss: 0.245515
# NFL LSTM model 183/201 completed
# Split training data: 1763 train, 196 validation
#
# Training direct prediction LSTM model for timestep range [0.915, 0.92]
# Starting training on device: cpu
# Early stopping at epoch 30
# Best epoch: 25, Train Acc: 0.9030, Train Loss: 0.2490, Val Acc: 0.9184, Val Loss: 0.1847
# Restored model from best epoch 25 with val_loss: 0.184651
# NFL LSTM model 184/201 completed
# Split training data: 1872 train, 208 validation
#
# Training direct prediction LSTM model for timestep range [0.92, 0.925]
# Starting training on device: cpu
# Early stopping at epoch 29
# Best epoch: 24, Train Acc: 0.9012, Train Loss: 0.2540, Val Acc: 0.8702, Val Loss: 0.2406
# Restored model from best epoch 24 with val_loss: 0.240562
# NFL LSTM model 185/201 completed
# Split training data: 1945 train, 217 validation
#
# Training direct prediction LSTM model for timestep range [0.925, 0.93]
# Starting training on device: cpu
# Early stopping at epoch 21
# Best epoch: 16, Train Acc: 0.8936, Train Loss: 0.2607, Val Acc: 0.9078, Val Loss: 0.2352
# Restored model from best epoch 16 with val_loss: 0.235200
# NFL LSTM model 186/201 completed
# Split training data: 1921 train, 214 validation
#
# Training direct prediction LSTM model for timestep range [0.93, 0.935]
# Starting training on device: cpu
# Early stopping at epoch 27
# Best epoch: 22, Train Acc: 0.9063, Train Loss: 0.2348, Val Acc: 0.8692, Val Loss: 0.2413
# Restored model from best epoch 22 with val_loss: 0.241343
# NFL LSTM model 187/201 completed
# Split training data: 2052 train, 228 validation
#
# Training direct prediction LSTM model for timestep range [0.935, 0.94]
# Starting training on device: cpu
# NFL LSTM model 188/201 completed
# Split training data: 2202 train, 245 validation
#
# Training direct prediction LSTM model for timestep range [0.94, 0.945]
# Starting training on device: cpu
# Early stopping at epoch 27
# Best epoch: 22, Train Acc: 0.9196, Train Loss: 0.1989, Val Acc: 0.9143, Val Loss: 0.2090
# Restored model from best epoch 22 with val_loss: 0.208994
# NFL LSTM model 189/201 completed
# Split training data: 2198 train, 245 validation
#
# Training direct prediction LSTM model for timestep range [0.945, 0.95]
# Starting training on device: cpu
# Early stopping at epoch 30
# Best epoch: 25, Train Acc: 0.9140, Train Loss: 0.2123, Val Acc: 0.9347, Val Loss: 0.1791
# Restored model from best epoch 25 with val_loss: 0.179063
# NFL LSTM model 190/201 completed
# Split training data: 2246 train, 250 validation
#
# Training direct prediction LSTM model for timestep range [0.95, 0.955]
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 10, Train Acc: 0.8905, Train Loss: 0.2643, Val Acc: 0.9200, Val Loss: 0.1883
# Restored model from best epoch 10 with val_loss: 0.188280
# NFL LSTM model 191/201 completed
# Split training data: 2124 train, 236 validation
#
# Training direct prediction LSTM model for timestep range [0.955, 0.96]
# Starting training on device: cpu
# Early stopping at epoch 26
# Best epoch: 21, Train Acc: 0.9025, Train Loss: 0.2270, Val Acc: 0.9110, Val Loss: 0.2113
# Restored model from best epoch 21 with val_loss: 0.211295
# NFL LSTM model 192/201 completed
# Split training data: 2258 train, 251 validation
#
# Training direct prediction LSTM model for timestep range [0.96, 0.965]
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 10, Train Acc: 0.9012, Train Loss: 0.2578, Val Acc: 0.8924, Val Loss: 0.2506
# Restored model from best epoch 10 with val_loss: 0.250590
# NFL LSTM model 193/201 completed
# Split training data: 2055 train, 229 validation
#
# Training direct prediction LSTM model for timestep range [0.965, 0.97]
# Starting training on device: cpu
# Early stopping at epoch 24
# Best epoch: 19, Train Acc: 0.9139, Train Loss: 0.2073, Val Acc: 0.9170, Val Loss: 0.1962
# Restored model from best epoch 19 with val_loss: 0.196194
# NFL LSTM model 194/201 completed
# Split training data: 4770 train, 531 validation
#
# Training direct prediction LSTM model for timestep range [0.97, 0.975]
# Starting training on device: cpu
# Early stopping at epoch 25
# Best epoch: 20, Train Acc: 0.9132, Train Loss: 0.2188, Val Acc: 0.9021, Val Loss: 0.2344
# Restored model from best epoch 20 with val_loss: 0.234449
# NFL LSTM model 195/201 completed
# Split training data: 2214 train, 247 validation
#
# Training direct prediction LSTM model for timestep range [0.975, 0.98]
# Starting training on device: cpu
# Early stopping at epoch 23
# Best epoch: 18, Train Acc: 0.9065, Train Loss: 0.2260, Val Acc: 0.9231, Val Loss: 0.2081
# Restored model from best epoch 18 with val_loss: 0.208144
# NFL LSTM model 196/201 completed
# Split training data: 2312 train, 257 validation
#
# Training direct prediction LSTM model for timestep range [0.98, 0.985]
# Starting training on device: cpu
# NFL LSTM model 197/201 completed
# Split training data: 2234 train, 249 validation
#
# Training direct prediction LSTM model for timestep range [0.985, 0.99]
# Starting training on device: cpu
# Early stopping at epoch 10
# Best epoch: 5, Train Acc: 0.9127, Train Loss: 0.2343, Val Acc: 0.9157, Val Loss: 0.2368
# Restored model from best epoch 5 with val_loss: 0.236829
# NFL LSTM model 198/201 completed
# Split training data: 2293 train, 255 validation
#
# Training direct prediction LSTM model for timestep range [0.99, 0.995]
# Starting training on device: cpu
# Early stopping at epoch 30
# Best epoch: 25, Train Acc: 0.9228, Train Loss: 0.1910, Val Acc: 0.9020, Val Loss: 0.2354
# Restored model from best epoch 25 with val_loss: 0.235398
# NFL LSTM model 199/201 completed
# Split training data: 2268 train, 252 validation
#
# Training direct prediction LSTM model for timestep range [0.995, 1.0]
# Starting training on device: cpu
# NFL LSTM model 200/201 completed
# Split training data: 2799 train, 312 validation
#
# Training direct prediction LSTM model for timestep range [1.0, 1.005]
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 15, Train Acc: 0.9568, Train Loss: 0.1251, Val Acc: 0.9679, Val Loss: 0.0935
# Restored model from best epoch 15 with val_loss: 0.093499
# NFL LSTM model 201/201 completed

# %%
# %reload_ext autoreload

# %%
all_models["nn"] = setup_direct_models(training_data, None, num_models=200)
# Out:
# Range [0.000, 0.005): 2484 train, 277 validation
# Starting training on device: cpu
# Early stopping at epoch 73
# Best epoch: 63, Train Acc: 0.7472, Train Loss: 0.4989, Val Acc: 0.6931, Val Loss: 0.5646
# Restored model from best epoch 63 with val_loss: 0.564636
# NFL direct model 1/200 completed
# Range [0.005, 0.010): 881 train, 98 validation
# Starting training on device: cpu
# Early stopping at epoch 31
# Best epoch: 21, Train Acc: 0.7083, Train Loss: 0.5706, Val Acc: 0.6327, Val Loss: 0.5942
# Restored model from best epoch 21 with val_loss: 0.594240
# NFL direct model 2/200 completed
# Range [0.010, 0.015): 1634 train, 182 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.6683, Train Loss: 0.6105, Val Acc: 0.6703, Val Loss: 0.5806
# Restored model from best epoch 3 with val_loss: 0.580556
# NFL direct model 3/200 completed
# Range [0.015, 0.020): 1382 train, 154 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.6577, Train Loss: 0.6154, Val Acc: 0.6948, Val Loss: 0.5897
# Restored model from best epoch 6 with val_loss: 0.589682
# NFL direct model 4/200 completed
# Range [0.020, 0.025): 1546 train, 172 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.6624, Train Loss: 0.6326, Val Acc: 0.6395, Val Loss: 0.6336
# Restored model from best epoch 4 with val_loss: 0.633638
# NFL direct model 5/200 completed
# Range [0.025, 0.030): 1594 train, 178 validation
# Starting training on device: cpu
# Early stopping at epoch 39
# Best epoch: 29, Train Acc: 0.6951, Train Loss: 0.5893, Val Acc: 0.6966, Val Loss: 0.5665
# Restored model from best epoch 29 with val_loss: 0.566524
# NFL direct model 6/200 completed
# Range [0.030, 0.035): 1516 train, 169 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.6497, Train Loss: 0.6338, Val Acc: 0.7101, Val Loss: 0.5978
# Restored model from best epoch 2 with val_loss: 0.597782
# NFL direct model 7/200 completed
# Range [0.035, 0.040): 1646 train, 183 validation
# Starting training on device: cpu
# Early stopping at epoch 24
# Best epoch: 14, Train Acc: 0.6823, Train Loss: 0.6034, Val Acc: 0.6284, Val Loss: 0.6223
# Restored model from best epoch 14 with val_loss: 0.622326
# NFL direct model 8/200 completed
# Range [0.040, 0.045): 1568 train, 175 validation
# Starting training on device: cpu
# Early stopping at epoch 22
# Best epoch: 12, Train Acc: 0.6677, Train Loss: 0.6050, Val Acc: 0.6800, Val Loss: 0.5861
# Restored model from best epoch 12 with val_loss: 0.586095
# NFL direct model 9/200 completed
# Range [0.045, 0.050): 1678 train, 187 validation
# Starting training on device: cpu
# Early stopping at epoch 23
# Best epoch: 13, Train Acc: 0.6818, Train Loss: 0.6047, Val Acc: 0.7273, Val Loss: 0.5560
# Restored model from best epoch 13 with val_loss: 0.556025
# NFL direct model 10/200 completed
# Range [0.050, 0.055): 1630 train, 182 validation
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 9, Train Acc: 0.6693, Train Loss: 0.6030, Val Acc: 0.6593, Val Loss: 0.6276
# Restored model from best epoch 9 with val_loss: 0.627646
# NFL direct model 11/200 completed
# Range [0.055, 0.060): 1573 train, 175 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.6745, Train Loss: 0.6123, Val Acc: 0.6057, Val Loss: 0.6613
# Restored model from best epoch 3 with val_loss: 0.661339
# NFL direct model 12/200 completed
# Range [0.060, 0.065): 1708 train, 190 validation
# Starting training on device: cpu
# Early stopping at epoch 11
# Best epoch: 1, Train Acc: 0.6306, Train Loss: 0.6527, Val Acc: 0.6053, Val Loss: 0.6615
# Restored model from best epoch 1 with val_loss: 0.661542
# NFL direct model 13/200 completed
# Range [0.065, 0.070): 1642 train, 183 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.6790, Train Loss: 0.5968, Val Acc: 0.6339, Val Loss: 0.6189
# Restored model from best epoch 7 with val_loss: 0.618886
# NFL direct model 14/200 completed
# Range [0.070, 0.075): 1677 train, 187 validation
# Starting training on device: cpu
# Early stopping at epoch 32
# Best epoch: 22, Train Acc: 0.7072, Train Loss: 0.5671, Val Acc: 0.7273, Val Loss: 0.5419
# Restored model from best epoch 22 with val_loss: 0.541945
# NFL direct model 15/200 completed
# Range [0.075, 0.080): 1629 train, 181 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.6691, Train Loss: 0.6045, Val Acc: 0.7017, Val Loss: 0.5910
# Restored model from best epoch 7 with val_loss: 0.590982
# NFL direct model 16/200 completed
# Range [0.080, 0.085): 1692 train, 188 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.6944, Train Loss: 0.5806, Val Acc: 0.6809, Val Loss: 0.5771
# Restored model from best epoch 7 with val_loss: 0.577118
# NFL direct model 17/200 completed
# Range [0.085, 0.090): 1711 train, 191 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.6920, Train Loss: 0.5930, Val Acc: 0.6178, Val Loss: 0.6413
# Restored model from best epoch 7 with val_loss: 0.641257
# NFL direct model 18/200 completed
# Range [0.090, 0.095): 1618 train, 180 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.6904, Train Loss: 0.5972, Val Acc: 0.6444, Val Loss: 0.6389
# Restored model from best epoch 4 with val_loss: 0.638929
# NFL direct model 19/200 completed
# Range [0.095, 0.100): 1692 train, 189 validation
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 9, Train Acc: 0.6714, Train Loss: 0.5885, Val Acc: 0.6720, Val Loss: 0.6045
# Restored model from best epoch 9 with val_loss: 0.604487
# NFL direct model 20/200 completed
# Range [0.100, 0.105): 1663 train, 185 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.6825, Train Loss: 0.5907, Val Acc: 0.6919, Val Loss: 0.5828
# Restored model from best epoch 4 with val_loss: 0.582793
# NFL direct model 21/200 completed
# Range [0.105, 0.110): 1647 train, 184 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.6782, Train Loss: 0.5983, Val Acc: 0.6685, Val Loss: 0.6034
# Restored model from best epoch 3 with val_loss: 0.603385
# NFL direct model 22/200 completed
# Range [0.110, 0.115): 1702 train, 190 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.6839, Train Loss: 0.5902, Val Acc: 0.6632, Val Loss: 0.5804
# Restored model from best epoch 7 with val_loss: 0.580413
# NFL direct model 23/200 completed
# Range [0.115, 0.120): 1637 train, 182 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.7104, Train Loss: 0.5689, Val Acc: 0.7033, Val Loss: 0.5838
# Restored model from best epoch 7 with val_loss: 0.583771
# NFL direct model 24/200 completed
# Range [0.120, 0.125): 1696 train, 189 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.6893, Train Loss: 0.5931, Val Acc: 0.6508, Val Loss: 0.6071
# Restored model from best epoch 4 with val_loss: 0.607074
# NFL direct model 25/200 completed
# Range [0.125, 0.130): 1709 train, 190 validation
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 9, Train Acc: 0.7086, Train Loss: 0.5508, Val Acc: 0.7368, Val Loss: 0.5381
# Restored model from best epoch 9 with val_loss: 0.538098
# NFL direct model 26/200 completed
# Range [0.130, 0.135): 1688 train, 188 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.7026, Train Loss: 0.5715, Val Acc: 0.6755, Val Loss: 0.5866
# Restored model from best epoch 7 with val_loss: 0.586640
# NFL direct model 27/200 completed
# Range [0.135, 0.140): 1660 train, 185 validation
# Starting training on device: cpu
# Early stopping at epoch 28
# Best epoch: 18, Train Acc: 0.7229, Train Loss: 0.5471, Val Acc: 0.6703, Val Loss: 0.5683
# Restored model from best epoch 18 with val_loss: 0.568330
# NFL direct model 28/200 completed
# Range [0.140, 0.145): 1610 train, 179 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.7161, Train Loss: 0.5865, Val Acc: 0.6927, Val Loss: 0.5855
# Restored model from best epoch 4 with val_loss: 0.585485
# NFL direct model 29/200 completed
# Range [0.145, 0.150): 1654 train, 184 validation
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 8, Train Acc: 0.7201, Train Loss: 0.5582, Val Acc: 0.7391, Val Loss: 0.5208
# Restored model from best epoch 8 with val_loss: 0.520835
# NFL direct model 30/200 completed
# Range [0.150, 0.155): 1715 train, 191 validation
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 5, Train Acc: 0.7190, Train Loss: 0.5667, Val Acc: 0.7068, Val Loss: 0.5733
# Restored model from best epoch 5 with val_loss: 0.573275
# NFL direct model 31/200 completed
# Range [0.155, 0.160): 1576 train, 176 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.6916, Train Loss: 0.5877, Val Acc: 0.7273, Val Loss: 0.5561
# Restored model from best epoch 3 with val_loss: 0.556141
# NFL direct model 32/200 completed
# Range [0.160, 0.165): 1760 train, 196 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.7080, Train Loss: 0.5842, Val Acc: 0.6888, Val Loss: 0.5669
# Restored model from best epoch 3 with val_loss: 0.566899
# NFL direct model 33/200 completed
# Range [0.165, 0.170): 1605 train, 179 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.6879, Train Loss: 0.5893, Val Acc: 0.6816, Val Loss: 0.5806
# Restored model from best epoch 4 with val_loss: 0.580609
# NFL direct model 34/200 completed
# Range [0.170, 0.175): 1659 train, 185 validation
# Starting training on device: cpu
# Early stopping at epoch 21
# Best epoch: 11, Train Acc: 0.7131, Train Loss: 0.5473, Val Acc: 0.6865, Val Loss: 0.5749
# Restored model from best epoch 11 with val_loss: 0.574887
# NFL direct model 35/200 completed
# Range [0.175, 0.180): 1723 train, 192 validation
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 5, Train Acc: 0.6941, Train Loss: 0.5803, Val Acc: 0.7135, Val Loss: 0.5632
# Restored model from best epoch 5 with val_loss: 0.563215
# NFL direct model 36/200 completed
# Range [0.180, 0.185): 1614 train, 180 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.7193, Train Loss: 0.5470, Val Acc: 0.7500, Val Loss: 0.5156
# Restored model from best epoch 7 with val_loss: 0.515620
# NFL direct model 37/200 completed
# Range [0.185, 0.190): 1669 train, 186 validation
# Starting training on device: cpu
# Early stopping at epoch 33
# Best epoch: 23, Train Acc: 0.7244, Train Loss: 0.5358, Val Acc: 0.7473, Val Loss: 0.5050
# Restored model from best epoch 23 with val_loss: 0.504988
# NFL direct model 38/200 completed
# Range [0.190, 0.195): 1615 train, 180 validation
# Starting training on device: cpu
# Early stopping at epoch 25
# Best epoch: 15, Train Acc: 0.7567, Train Loss: 0.5083, Val Acc: 0.7167, Val Loss: 0.5529
# Restored model from best epoch 15 with val_loss: 0.552874
# NFL direct model 39/200 completed
# Range [0.195, 0.200): 1681 train, 187 validation
# Starting training on device: cpu
# Early stopping at epoch 23
# Best epoch: 13, Train Acc: 0.7174, Train Loss: 0.5343, Val Acc: 0.8075, Val Loss: 0.4904
# Restored model from best epoch 13 with val_loss: 0.490398
# NFL direct model 40/200 completed
# Range [0.200, 0.205): 1637 train, 182 validation
# Starting training on device: cpu
# Early stopping at epoch 29
# Best epoch: 19, Train Acc: 0.7398, Train Loss: 0.5234, Val Acc: 0.7033, Val Loss: 0.5549
# Restored model from best epoch 19 with val_loss: 0.554949
# NFL direct model 41/200 completed
# Range [0.205, 0.210): 1653 train, 184 validation
# Starting training on device: cpu
# Early stopping at epoch 31
# Best epoch: 21, Train Acc: 0.7453, Train Loss: 0.5054, Val Acc: 0.7065, Val Loss: 0.5440
# Restored model from best epoch 21 with val_loss: 0.544031
# NFL direct model 42/200 completed
# Range [0.210, 0.215): 1749 train, 195 validation
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 8, Train Acc: 0.7278, Train Loss: 0.5444, Val Acc: 0.6821, Val Loss: 0.4830
# Restored model from best epoch 8 with val_loss: 0.482953
# NFL direct model 43/200 completed
# Range [0.215, 0.220): 1578 train, 176 validation
# Starting training on device: cpu
# Early stopping at epoch 31
# Best epoch: 21, Train Acc: 0.7478, Train Loss: 0.4961, Val Acc: 0.7557, Val Loss: 0.4892
# Restored model from best epoch 21 with val_loss: 0.489213
# NFL direct model 44/200 completed
# Range [0.220, 0.225): 1689 train, 188 validation
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 8, Train Acc: 0.7306, Train Loss: 0.5347, Val Acc: 0.6755, Val Loss: 0.5258
# Restored model from best epoch 8 with val_loss: 0.525825
# NFL direct model 45/200 completed
# Range [0.225, 0.230): 1708 train, 190 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.7237, Train Loss: 0.5468, Val Acc: 0.7316, Val Loss: 0.5313
# Restored model from best epoch 7 with val_loss: 0.531260
# NFL direct model 46/200 completed
# Range [0.230, 0.235): 1597 train, 178 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.6907, Train Loss: 0.5726, Val Acc: 0.7360, Val Loss: 0.5786
# Restored model from best epoch 2 with val_loss: 0.578582
# NFL direct model 47/200 completed
# Range [0.235, 0.240): 1715 train, 191 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.7120, Train Loss: 0.5698, Val Acc: 0.6440, Val Loss: 0.5856
# Restored model from best epoch 2 with val_loss: 0.585607
# NFL direct model 48/200 completed
# Range [0.240, 0.245): 1620 train, 180 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.7049, Train Loss: 0.5634, Val Acc: 0.6944, Val Loss: 0.6001
# Restored model from best epoch 6 with val_loss: 0.600131
# NFL direct model 49/200 completed
# Range [0.245, 0.250): 1519 train, 169 validation
# Starting training on device: cpu
# Early stopping at epoch 22
# Best epoch: 12, Train Acc: 0.7235, Train Loss: 0.5344, Val Acc: 0.7101, Val Loss: 0.5621
# Restored model from best epoch 12 with val_loss: 0.562116
# NFL direct model 50/200 completed
# Range [0.250, 0.255): 4953 train, 551 validation
# Starting training on device: cpu
# Early stopping at epoch 58
# Best epoch: 48, Train Acc: 0.8031, Train Loss: 0.4057, Val Acc: 0.7931, Val Loss: 0.4886
# Restored model from best epoch 48 with val_loss: 0.488579
# NFL direct model 51/200 completed
# Range [0.255, 0.260): 983 train, 110 validation
# Starting training on device: cpu
# Early stopping at epoch 24
# Best epoch: 14, Train Acc: 0.7701, Train Loss: 0.4859, Val Acc: 0.7182, Val Loss: 0.5546
# Restored model from best epoch 14 with val_loss: 0.554595
# NFL direct model 52/200 completed
# Range [0.260, 0.265): 1296 train, 144 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.7106, Train Loss: 0.5612, Val Acc: 0.6875, Val Loss: 0.5962
# Restored model from best epoch 3 with val_loss: 0.596247
# NFL direct model 53/200 completed
# Range [0.265, 0.270): 1745 train, 194 validation
# Starting training on device: cpu
# Early stopping at epoch 11
# Best epoch: 1, Train Acc: 0.6453, Train Loss: 0.6352, Val Acc: 0.7216, Val Loss: 0.5574
# Restored model from best epoch 1 with val_loss: 0.557355
# NFL direct model 54/200 completed
# Range [0.270, 0.275): 1559 train, 174 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.7146, Train Loss: 0.5702, Val Acc: 0.7069, Val Loss: 0.5638
# Restored model from best epoch 2 with val_loss: 0.563837
# NFL direct model 55/200 completed
# Range [0.275, 0.280): 1774 train, 198 validation
# Starting training on device: cpu
# Early stopping at epoch 24
# Best epoch: 14, Train Acc: 0.7294, Train Loss: 0.5147, Val Acc: 0.6768, Val Loss: 0.5656
# Restored model from best epoch 14 with val_loss: 0.565634
# NFL direct model 56/200 completed
# Range [0.280, 0.285): 1539 train, 171 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.6998, Train Loss: 0.5729, Val Acc: 0.7368, Val Loss: 0.5444
# Restored model from best epoch 2 with val_loss: 0.544351
# NFL direct model 57/200 completed
# Range [0.285, 0.290): 1782 train, 199 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.7346, Train Loss: 0.5240, Val Acc: 0.7387, Val Loss: 0.4742
# Restored model from best epoch 6 with val_loss: 0.474152
# NFL direct model 58/200 completed
# Range [0.290, 0.295): 1626 train, 181 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.7097, Train Loss: 0.5529, Val Acc: 0.7238, Val Loss: 0.5212
# Restored model from best epoch 4 with val_loss: 0.521177
# NFL direct model 59/200 completed
# Range [0.295, 0.300): 1681 train, 187 validation
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 8, Train Acc: 0.7400, Train Loss: 0.5184, Val Acc: 0.7754, Val Loss: 0.5056
# Restored model from best epoch 8 with val_loss: 0.505636
# NFL direct model 60/200 completed
# Range [0.300, 0.305): 1700 train, 189 validation
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 5, Train Acc: 0.7294, Train Loss: 0.5306, Val Acc: 0.7196, Val Loss: 0.5402
# Restored model from best epoch 5 with val_loss: 0.540216
# NFL direct model 61/200 completed
# Range [0.305, 0.310): 1585 train, 177 validation
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 8, Train Acc: 0.7369, Train Loss: 0.5134, Val Acc: 0.7175, Val Loss: 0.5258
# Restored model from best epoch 8 with val_loss: 0.525814
# NFL direct model 62/200 completed
# Range [0.310, 0.315): 1708 train, 190 validation
# Starting training on device: cpu
# Early stopping at epoch 44
# Best epoch: 34, Train Acc: 0.8126, Train Loss: 0.4079, Val Acc: 0.7474, Val Loss: 0.5148
# Restored model from best epoch 34 with val_loss: 0.514780
# NFL direct model 63/200 completed
# Range [0.315, 0.320): 1676 train, 187 validation
# Starting training on device: cpu
# Early stopping at epoch 33
# Best epoch: 23, Train Acc: 0.7566, Train Loss: 0.4784, Val Acc: 0.7807, Val Loss: 0.4881
# Restored model from best epoch 23 with val_loss: 0.488068
# NFL direct model 64/200 completed
# Range [0.320, 0.325): 1692 train, 189 validation
# Starting training on device: cpu
# Early stopping at epoch 23
# Best epoch: 13, Train Acc: 0.7648, Train Loss: 0.4754, Val Acc: 0.7249, Val Loss: 0.4837
# Restored model from best epoch 13 with val_loss: 0.483677
# NFL direct model 65/200 completed
# Range [0.325, 0.330): 1621 train, 181 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.7298, Train Loss: 0.5272, Val Acc: 0.7348, Val Loss: 0.5461
# Restored model from best epoch 3 with val_loss: 0.546086
# NFL direct model 66/200 completed
# Range [0.330, 0.335): 1678 train, 187 validation
# Starting training on device: cpu
# Early stopping at epoch 27
# Best epoch: 17, Train Acc: 0.7610, Train Loss: 0.4782, Val Acc: 0.7754, Val Loss: 0.4553
# Restored model from best epoch 17 with val_loss: 0.455339
# NFL direct model 67/200 completed
# Range [0.335, 0.340): 1708 train, 190 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.7406, Train Loss: 0.5199, Val Acc: 0.7211, Val Loss: 0.5293
# Restored model from best epoch 4 with val_loss: 0.529346
# NFL direct model 68/200 completed
# Range [0.340, 0.345): 1650 train, 184 validation
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 9, Train Acc: 0.7539, Train Loss: 0.4966, Val Acc: 0.7174, Val Loss: 0.5292
# Restored model from best epoch 9 with val_loss: 0.529171
# NFL direct model 69/200 completed
# Range [0.345, 0.350): 1734 train, 193 validation
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 9, Train Acc: 0.7595, Train Loss: 0.4738, Val Acc: 0.6788, Val Loss: 0.4634
# Restored model from best epoch 9 with val_loss: 0.463362
# NFL direct model 70/200 completed
# Range [0.350, 0.355): 1699 train, 189 validation
# Starting training on device: cpu
# Early stopping at epoch 45
# Best epoch: 35, Train Acc: 0.8287, Train Loss: 0.3799, Val Acc: 0.7619, Val Loss: 0.4845
# Restored model from best epoch 35 with val_loss: 0.484452
# NFL direct model 71/200 completed
# Range [0.355, 0.360): 1688 train, 188 validation
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 9, Train Acc: 0.7518, Train Loss: 0.5053, Val Acc: 0.7926, Val Loss: 0.4694
# Restored model from best epoch 9 with val_loss: 0.469353
# NFL direct model 72/200 completed
# Range [0.360, 0.365): 1653 train, 184 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.7096, Train Loss: 0.5559, Val Acc: 0.7663, Val Loss: 0.5120
# Restored model from best epoch 2 with val_loss: 0.511966
# NFL direct model 73/200 completed
# Range [0.365, 0.370): 1719 train, 191 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.7691, Train Loss: 0.4940, Val Acc: 0.7435, Val Loss: 0.5362
# Restored model from best epoch 4 with val_loss: 0.536206
# NFL direct model 74/200 completed
# Range [0.370, 0.375): 1631 train, 182 validation
# Starting training on device: cpu
# Early stopping at epoch 33
# Best epoch: 23, Train Acc: 0.7915, Train Loss: 0.4398, Val Acc: 0.7802, Val Loss: 0.4900
# Restored model from best epoch 23 with val_loss: 0.489984
# NFL direct model 75/200 completed
# Range [0.375, 0.380): 1696 train, 189 validation
# Starting training on device: cpu
# Early stopping at epoch 34
# Best epoch: 24, Train Acc: 0.7930, Train Loss: 0.4357, Val Acc: 0.7778, Val Loss: 0.4536
# Restored model from best epoch 24 with val_loss: 0.453585
# NFL direct model 76/200 completed
# Range [0.380, 0.385): 1652 train, 184 validation
# Starting training on device: cpu
# Early stopping at epoch 25
# Best epoch: 15, Train Acc: 0.7893, Train Loss: 0.4434, Val Acc: 0.7609, Val Loss: 0.5110
# Restored model from best epoch 15 with val_loss: 0.510975
# NFL direct model 77/200 completed
# Range [0.385, 0.390): 1660 train, 185 validation
# Starting training on device: cpu
# Early stopping at epoch 21
# Best epoch: 11, Train Acc: 0.7807, Train Loss: 0.4643, Val Acc: 0.7459, Val Loss: 0.4879
# Restored model from best epoch 11 with val_loss: 0.487874
# NFL direct model 78/200 completed
# Range [0.390, 0.395): 1664 train, 185 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.7362, Train Loss: 0.5205, Val Acc: 0.7297, Val Loss: 0.5607
# Restored model from best epoch 3 with val_loss: 0.560708
# NFL direct model 79/200 completed
# Range [0.395, 0.400): 1710 train, 190 validation
# Starting training on device: cpu
# Early stopping at epoch 25
# Best epoch: 15, Train Acc: 0.7661, Train Loss: 0.4764, Val Acc: 0.7263, Val Loss: 0.4711
# Restored model from best epoch 15 with val_loss: 0.471107
# NFL direct model 80/200 completed
# Range [0.400, 0.405): 1670 train, 186 validation
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 5, Train Acc: 0.7491, Train Loss: 0.5027, Val Acc: 0.7312, Val Loss: 0.5090
# Restored model from best epoch 5 with val_loss: 0.509036
# NFL direct model 81/200 completed
# Range [0.405, 0.410): 1587 train, 177 validation
# Starting training on device: cpu
# Early stopping at epoch 11
# Best epoch: 1, Train Acc: 0.6793, Train Loss: 0.6108, Val Acc: 0.7006, Val Loss: 0.5496
# Restored model from best epoch 1 with val_loss: 0.549616
# NFL direct model 82/200 completed
# Range [0.410, 0.415): 1732 train, 193 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.7540, Train Loss: 0.4951, Val Acc: 0.7617, Val Loss: 0.4398
# Restored model from best epoch 4 with val_loss: 0.439791
# NFL direct model 83/200 completed
# Range [0.415, 0.420): 1669 train, 186 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.7657, Train Loss: 0.4978, Val Acc: 0.7366, Val Loss: 0.5009
# Restored model from best epoch 6 with val_loss: 0.500857
# NFL direct model 84/200 completed
# Range [0.420, 0.425): 1720 train, 192 validation
# Starting training on device: cpu
# Early stopping at epoch 27
# Best epoch: 17, Train Acc: 0.7605, Train Loss: 0.4627, Val Acc: 0.7552, Val Loss: 0.4459
# Restored model from best epoch 17 with val_loss: 0.445912
# NFL direct model 85/200 completed
# Range [0.425, 0.430): 1678 train, 187 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.7777, Train Loss: 0.4739, Val Acc: 0.7219, Val Loss: 0.5576
# Restored model from best epoch 6 with val_loss: 0.557609
# NFL direct model 86/200 completed
# Range [0.430, 0.435): 1671 train, 186 validation
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 5, Train Acc: 0.7570, Train Loss: 0.4980, Val Acc: 0.7366, Val Loss: 0.5073
# Restored model from best epoch 5 with val_loss: 0.507283
# NFL direct model 87/200 completed
# Range [0.435, 0.440): 1731 train, 193 validation
# Starting training on device: cpu
# Early stopping at epoch 11
# Best epoch: 1, Train Acc: 0.6412, Train Loss: 0.6453, Val Acc: 0.7409, Val Loss: 0.6867
# Restored model from best epoch 1 with val_loss: 0.686690
# NFL direct model 88/200 completed
# Range [0.440, 0.445): 1637 train, 182 validation
# Starting training on device: cpu
# Early stopping at epoch 28
# Best epoch: 18, Train Acc: 0.7868, Train Loss: 0.4489, Val Acc: 0.8022, Val Loss: 0.4561
# Restored model from best epoch 18 with val_loss: 0.456128
# NFL direct model 89/200 completed
# Range [0.445, 0.450): 1709 train, 190 validation
# Starting training on device: cpu
# Early stopping at epoch 33
# Best epoch: 23, Train Acc: 0.8139, Train Loss: 0.3935, Val Acc: 0.6947, Val Loss: 0.5022
# Restored model from best epoch 23 with val_loss: 0.502151
# NFL direct model 90/200 completed
# Range [0.450, 0.455): 1690 train, 188 validation
# Starting training on device: cpu
# Early stopping at epoch 23
# Best epoch: 13, Train Acc: 0.7870, Train Loss: 0.4512, Val Acc: 0.7287, Val Loss: 0.5292
# Restored model from best epoch 13 with val_loss: 0.529190
# NFL direct model 91/200 completed
# Range [0.455, 0.460): 1691 train, 188 validation
# Starting training on device: cpu
# Early stopping at epoch 23
# Best epoch: 13, Train Acc: 0.7747, Train Loss: 0.4686, Val Acc: 0.7340, Val Loss: 0.4935
# Restored model from best epoch 13 with val_loss: 0.493516
# NFL direct model 92/200 completed
# Range [0.460, 0.465): 1723 train, 192 validation
# Starting training on device: cpu
# Early stopping at epoch 21
# Best epoch: 11, Train Acc: 0.7911, Train Loss: 0.4452, Val Acc: 0.7656, Val Loss: 0.4532
# Restored model from best epoch 11 with val_loss: 0.453232
# NFL direct model 93/200 completed
# Range [0.465, 0.470): 1616 train, 180 validation
# Starting training on device: cpu
# Early stopping at epoch 22
# Best epoch: 12, Train Acc: 0.7964, Train Loss: 0.4290, Val Acc: 0.7278, Val Loss: 0.5145
# Restored model from best epoch 12 with val_loss: 0.514469
# NFL direct model 94/200 completed
# Range [0.470, 0.475): 4663 train, 519 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.7870, Train Loss: 0.4605, Val Acc: 0.7900, Val Loss: 0.4789
# Restored model from best epoch 4 with val_loss: 0.478915
# NFL direct model 95/200 completed
# Range [0.475, 0.480): 2369 train, 264 validation
# Starting training on device: cpu
# Early stopping at epoch 39
# Best epoch: 29, Train Acc: 0.8252, Train Loss: 0.3888, Val Acc: 0.7955, Val Loss: 0.4614
# Restored model from best epoch 29 with val_loss: 0.461401
# NFL direct model 96/200 completed
# Range [0.480, 0.485): 2547 train, 284 validation
# Starting training on device: cpu
# Early stopping at epoch 21
# Best epoch: 11, Train Acc: 0.7923, Train Loss: 0.4337, Val Acc: 0.7958, Val Loss: 0.4074
# Restored model from best epoch 11 with val_loss: 0.407414
# NFL direct model 97/200 completed
# Range [0.485, 0.490): 2877 train, 320 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.7855, Train Loss: 0.4636, Val Acc: 0.7812, Val Loss: 0.4688
# Restored model from best epoch 4 with val_loss: 0.468773
# NFL direct model 98/200 completed
# Range [0.490, 0.495): 3471 train, 386 validation
# Starting training on device: cpu
# Early stopping at epoch 39
# Best epoch: 29, Train Acc: 0.8326, Train Loss: 0.3564, Val Acc: 0.8083, Val Loss: 0.4188
# Restored model from best epoch 29 with val_loss: 0.418764
# NFL direct model 99/200 completed
# Range [0.495, 0.500): 4170 train, 464 validation
# Starting training on device: cpu
# Early stopping at epoch 29
# Best epoch: 19, Train Acc: 0.8151, Train Loss: 0.4061, Val Acc: 0.7759, Val Loss: 0.4290
# Restored model from best epoch 19 with val_loss: 0.429034
# NFL direct model 100/200 completed
# Range [0.500, 0.505): 7587 train, 843 validation
# Starting training on device: cpu
# Early stopping at epoch 34
# Best epoch: 24, Train Acc: 0.8184, Train Loss: 0.4004, Val Acc: 0.7888, Val Loss: 0.4375
# Restored model from best epoch 24 with val_loss: 0.437536
# NFL direct model 101/200 completed
# Range [0.505, 0.510): 983 train, 110 validation
# Starting training on device: cpu
# Early stopping at epoch 28
# Best epoch: 18, Train Acc: 0.8199, Train Loss: 0.4043, Val Acc: 0.8091, Val Loss: 0.4232
# Restored model from best epoch 18 with val_loss: 0.423173
# NFL direct model 102/200 completed
# Range [0.510, 0.515): 1591 train, 177 validation
# Starting training on device: cpu
# Early stopping at epoch 30
# Best epoch: 20, Train Acc: 0.8108, Train Loss: 0.3885, Val Acc: 0.7910, Val Loss: 0.4388
# Restored model from best epoch 20 with val_loss: 0.438774
# NFL direct model 103/200 completed
# Range [0.515, 0.520): 1379 train, 154 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.7970, Train Loss: 0.4417, Val Acc: 0.7597, Val Loss: 0.4691
# Restored model from best epoch 3 with val_loss: 0.469128
# NFL direct model 104/200 completed
# Range [0.520, 0.525): 1559 train, 174 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.7947, Train Loss: 0.4456, Val Acc: 0.8276, Val Loss: 0.3822
# Restored model from best epoch 4 with val_loss: 0.382200
# NFL direct model 105/200 completed
# Range [0.525, 0.530): 1647 train, 184 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.8239, Train Loss: 0.4085, Val Acc: 0.7554, Val Loss: 0.4690
# Restored model from best epoch 6 with val_loss: 0.469019
# NFL direct model 106/200 completed
# Range [0.530, 0.535): 1584 train, 177 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.7771, Train Loss: 0.4555, Val Acc: 0.7797, Val Loss: 0.4540
# Restored model from best epoch 4 with val_loss: 0.454028
# NFL direct model 107/200 completed
# Range [0.535, 0.540): 1665 train, 186 validation
# Starting training on device: cpu
# Early stopping at epoch 21
# Best epoch: 11, Train Acc: 0.8384, Train Loss: 0.3704, Val Acc: 0.8172, Val Loss: 0.3738
# Restored model from best epoch 11 with val_loss: 0.373804
# NFL direct model 108/200 completed
# Range [0.540, 0.545): 1599 train, 178 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.8036, Train Loss: 0.4339, Val Acc: 0.7528, Val Loss: 0.4931
# Restored model from best epoch 7 with val_loss: 0.493139
# NFL direct model 109/200 completed
# Range [0.545, 0.550): 1595 train, 178 validation
# Starting training on device: cpu
# Early stopping at epoch 24
# Best epoch: 14, Train Acc: 0.8176, Train Loss: 0.3927, Val Acc: 0.7697, Val Loss: 0.4765
# Restored model from best epoch 14 with val_loss: 0.476515
# NFL direct model 110/200 completed
# Range [0.550, 0.555): 1640 train, 183 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.8116, Train Loss: 0.3997, Val Acc: 0.7978, Val Loss: 0.4359
# Restored model from best epoch 7 with val_loss: 0.435859
# NFL direct model 111/200 completed
# Range [0.555, 0.560): 1621 train, 181 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.8118, Train Loss: 0.4182, Val Acc: 0.7956, Val Loss: 0.4367
# Restored model from best epoch 7 with val_loss: 0.436684
# NFL direct model 112/200 completed
# Range [0.560, 0.565): 1639 train, 183 validation
# Starting training on device: cpu
# Early stopping at epoch 27
# Best epoch: 17, Train Acc: 0.8273, Train Loss: 0.3807, Val Acc: 0.8525, Val Loss: 0.3808
# Restored model from best epoch 17 with val_loss: 0.380818
# NFL direct model 113/200 completed
# Range [0.565, 0.570): 1677 train, 187 validation
# Starting training on device: cpu
# Early stopping at epoch 22
# Best epoch: 12, Train Acc: 0.8199, Train Loss: 0.3742, Val Acc: 0.7380, Val Loss: 0.4875
# Restored model from best epoch 12 with val_loss: 0.487468
# NFL direct model 114/200 completed
# Range [0.570, 0.575): 1705 train, 190 validation
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 10, Train Acc: 0.8164, Train Loss: 0.3868, Val Acc: 0.8158, Val Loss: 0.4179
# Restored model from best epoch 10 with val_loss: 0.417930
# NFL direct model 115/200 completed
# Range [0.575, 0.580): 1701 train, 190 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.8072, Train Loss: 0.4295, Val Acc: 0.7526, Val Loss: 0.4719
# Restored model from best epoch 4 with val_loss: 0.471868
# NFL direct model 116/200 completed
# Range [0.580, 0.585): 1615 train, 180 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.7907, Train Loss: 0.4300, Val Acc: 0.8389, Val Loss: 0.3627
# Restored model from best epoch 4 with val_loss: 0.362656
# NFL direct model 117/200 completed
# Range [0.585, 0.590): 1638 train, 182 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.7869, Train Loss: 0.4700, Val Acc: 0.7802, Val Loss: 0.4419
# Restored model from best epoch 2 with val_loss: 0.441918
# NFL direct model 118/200 completed
# Range [0.590, 0.595): 1734 train, 193 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.8166, Train Loss: 0.3987, Val Acc: 0.7513, Val Loss: 0.4887
# Restored model from best epoch 6 with val_loss: 0.488688
# NFL direct model 119/200 completed
# Range [0.595, 0.600): 1705 train, 190 validation
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 8, Train Acc: 0.8235, Train Loss: 0.3878, Val Acc: 0.7895, Val Loss: 0.4757
# Restored model from best epoch 8 with val_loss: 0.475738
# NFL direct model 120/200 completed
# Range [0.600, 0.605): 1667 train, 186 validation
# Starting training on device: cpu
# Early stopping at epoch 22
# Best epoch: 12, Train Acc: 0.8248, Train Loss: 0.3787, Val Acc: 0.8011, Val Loss: 0.3749
# Restored model from best epoch 12 with val_loss: 0.374884
# NFL direct model 121/200 completed
# Range [0.605, 0.610): 1710 train, 191 validation
# Starting training on device: cpu
# Early stopping at epoch 29
# Best epoch: 19, Train Acc: 0.8380, Train Loss: 0.3541, Val Acc: 0.7853, Val Loss: 0.4532
# Restored model from best epoch 19 with val_loss: 0.453165
# NFL direct model 122/200 completed
# Range [0.610, 0.615): 1722 train, 192 validation
# Starting training on device: cpu
# Early stopping at epoch 26
# Best epoch: 16, Train Acc: 0.8275, Train Loss: 0.3752, Val Acc: 0.7760, Val Loss: 0.4239
# Restored model from best epoch 16 with val_loss: 0.423874
# NFL direct model 123/200 completed
# Range [0.615, 0.620): 1683 train, 187 validation
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 8, Train Acc: 0.8259, Train Loss: 0.3843, Val Acc: 0.8342, Val Loss: 0.3544
# Restored model from best epoch 8 with val_loss: 0.354367
# NFL direct model 124/200 completed
# Range [0.620, 0.625): 1670 train, 186 validation
# Starting training on device: cpu
# Early stopping at epoch 30
# Best epoch: 20, Train Acc: 0.8275, Train Loss: 0.3786, Val Acc: 0.8172, Val Loss: 0.4201
# Restored model from best epoch 20 with val_loss: 0.420144
# NFL direct model 125/200 completed
# Range [0.625, 0.630): 1734 train, 193 validation
# Starting training on device: cpu
# Early stopping at epoch 15
# Best epoch: 5, Train Acc: 0.8195, Train Loss: 0.3979, Val Acc: 0.7565, Val Loss: 0.4349
# Restored model from best epoch 5 with val_loss: 0.434949
# NFL direct model 126/200 completed
# Range [0.630, 0.635): 1679 train, 187 validation
# Starting training on device: cpu
# Early stopping at epoch 31
# Best epoch: 21, Train Acc: 0.8535, Train Loss: 0.3347, Val Acc: 0.8182, Val Loss: 0.4526
# Restored model from best epoch 21 with val_loss: 0.452637
# NFL direct model 127/200 completed
# Range [0.635, 0.640): 1671 train, 186 validation
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 10, Train Acc: 0.8270, Train Loss: 0.3831, Val Acc: 0.8172, Val Loss: 0.3834
# Restored model from best epoch 10 with val_loss: 0.383434
# NFL direct model 128/200 completed
# Range [0.640, 0.645): 1600 train, 178 validation
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 10, Train Acc: 0.8269, Train Loss: 0.3841, Val Acc: 0.8146, Val Loss: 0.3667
# Restored model from best epoch 10 with val_loss: 0.366679
# NFL direct model 129/200 completed
# Range [0.645, 0.650): 1738 train, 194 validation
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 9, Train Acc: 0.8326, Train Loss: 0.4063, Val Acc: 0.8402, Val Loss: 0.4827
# Restored model from best epoch 9 with val_loss: 0.482729
# NFL direct model 130/200 completed
# Range [0.650, 0.655): 1681 train, 187 validation
# Starting training on device: cpu
# Early stopping at epoch 22
# Best epoch: 12, Train Acc: 0.8227, Train Loss: 0.3804, Val Acc: 0.8235, Val Loss: 0.3791
# Restored model from best epoch 12 with val_loss: 0.379054
# NFL direct model 131/200 completed
# Range [0.655, 0.660): 1713 train, 191 validation
# Starting training on device: cpu
# Early stopping at epoch 30
# Best epoch: 20, Train Acc: 0.8552, Train Loss: 0.3255, Val Acc: 0.8220, Val Loss: 0.3523
# Restored model from best epoch 20 with val_loss: 0.352325
# NFL direct model 132/200 completed
# Range [0.660, 0.665): 1717 train, 191 validation
# Starting training on device: cpu
# Early stopping at epoch 46
# Best epoch: 36, Train Acc: 0.8655, Train Loss: 0.2883, Val Acc: 0.8220, Val Loss: 0.3447
# Restored model from best epoch 36 with val_loss: 0.344651
# NFL direct model 133/200 completed
# Range [0.665, 0.670): 1679 train, 187 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.8338, Train Loss: 0.3803, Val Acc: 0.8182, Val Loss: 0.3902
# Restored model from best epoch 7 with val_loss: 0.390150
# NFL direct model 134/200 completed
# Range [0.670, 0.675): 1689 train, 188 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.8313, Train Loss: 0.3773, Val Acc: 0.8351, Val Loss: 0.3715
# Restored model from best epoch 6 with val_loss: 0.371522
# NFL direct model 135/200 completed
# Range [0.675, 0.680): 1639 train, 183 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.8365, Train Loss: 0.3855, Val Acc: 0.8197, Val Loss: 0.3788
# Restored model from best epoch 6 with val_loss: 0.378784
# NFL direct model 136/200 completed
# Range [0.680, 0.685): 1665 train, 185 validation
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 10, Train Acc: 0.8342, Train Loss: 0.3531, Val Acc: 0.8324, Val Loss: 0.3842
# Restored model from best epoch 10 with val_loss: 0.384235
# NFL direct model 137/200 completed
# Range [0.685, 0.690): 1733 train, 193 validation
# Starting training on device: cpu
# Early stopping at epoch 22
# Best epoch: 12, Train Acc: 0.8350, Train Loss: 0.3617, Val Acc: 0.8394, Val Loss: 0.3130
# Restored model from best epoch 12 with val_loss: 0.312970
# NFL direct model 138/200 completed
# Range [0.690, 0.695): 1687 train, 188 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.8186, Train Loss: 0.3966, Val Acc: 0.8138, Val Loss: 0.3820
# Restored model from best epoch 3 with val_loss: 0.382031
# NFL direct model 139/200 completed
# Range [0.695, 0.700): 1664 train, 185 validation
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 10, Train Acc: 0.8504, Train Loss: 0.3390, Val Acc: 0.8162, Val Loss: 0.3422
# Restored model from best epoch 10 with val_loss: 0.342179
# NFL direct model 140/200 completed
# Range [0.700, 0.705): 1711 train, 191 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.8416, Train Loss: 0.3864, Val Acc: 0.8220, Val Loss: 0.3838
# Restored model from best epoch 3 with val_loss: 0.383805
# NFL direct model 141/200 completed
# Range [0.705, 0.710): 1638 train, 182 validation
# Starting training on device: cpu
# Early stopping at epoch 24
# Best epoch: 14, Train Acc: 0.8437, Train Loss: 0.3337, Val Acc: 0.8242, Val Loss: 0.3462
# Restored model from best epoch 14 with val_loss: 0.346244
# NFL direct model 142/200 completed
# Range [0.710, 0.715): 1639 train, 183 validation
# Starting training on device: cpu
# Early stopping at epoch 31
# Best epoch: 21, Train Acc: 0.8609, Train Loss: 0.3181, Val Acc: 0.8579, Val Loss: 0.3254
# Restored model from best epoch 21 with val_loss: 0.325404
# NFL direct model 143/200 completed
# Range [0.715, 0.720): 1706 train, 190 validation
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 8, Train Acc: 0.8529, Train Loss: 0.3500, Val Acc: 0.7842, Val Loss: 0.4151
# Restored model from best epoch 8 with val_loss: 0.415145
# NFL direct model 144/200 completed
# Range [0.720, 0.725): 1688 train, 188 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.8430, Train Loss: 0.3695, Val Acc: 0.8298, Val Loss: 0.3579
# Restored model from best epoch 4 with val_loss: 0.357857
# NFL direct model 145/200 completed
# Range [0.725, 0.730): 1735 train, 193 validation
# Starting training on device: cpu
# Early stopping at epoch 23
# Best epoch: 13, Train Acc: 0.8352, Train Loss: 0.3526, Val Acc: 0.8446, Val Loss: 0.4197
# Restored model from best epoch 13 with val_loss: 0.419701
# NFL direct model 146/200 completed
# Range [0.730, 0.735): 1721 train, 192 validation
# Starting training on device: cpu
# Early stopping at epoch 22
# Best epoch: 12, Train Acc: 0.8501, Train Loss: 0.3238, Val Acc: 0.7865, Val Loss: 0.3641
# Restored model from best epoch 12 with val_loss: 0.364071
# NFL direct model 147/200 completed
# Range [0.735, 0.740): 1666 train, 186 validation
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 10, Train Acc: 0.8469, Train Loss: 0.3396, Val Acc: 0.8710, Val Loss: 0.3070
# Restored model from best epoch 10 with val_loss: 0.307050
# NFL direct model 148/200 completed
# Range [0.740, 0.745): 1551 train, 173 validation
# Starting training on device: cpu
# Early stopping at epoch 22
# Best epoch: 12, Train Acc: 0.8562, Train Loss: 0.3283, Val Acc: 0.8439, Val Loss: 0.3422
# Restored model from best epoch 12 with val_loss: 0.342243
# NFL direct model 149/200 completed
# Range [0.745, 0.750): 1493 train, 166 validation
# Starting training on device: cpu
# Early stopping at epoch 27
# Best epoch: 17, Train Acc: 0.8721, Train Loss: 0.3208, Val Acc: 0.8193, Val Loss: 0.3501
# Restored model from best epoch 17 with val_loss: 0.350051
# NFL direct model 150/200 completed
# Range [0.750, 0.755): 4825 train, 537 validation
# Starting training on device: cpu
# Early stopping at epoch 55
# Best epoch: 45, Train Acc: 0.8968, Train Loss: 0.2296, Val Acc: 0.8808, Val Loss: 0.2707
# Restored model from best epoch 45 with val_loss: 0.270701
# NFL direct model 151/200 completed
# Range [0.755, 0.760): 993 train, 111 validation
# Starting training on device: cpu
# Early stopping at epoch 26
# Best epoch: 16, Train Acc: 0.8751, Train Loss: 0.2909, Val Acc: 0.9640, Val Loss: 0.1528
# Restored model from best epoch 16 with val_loss: 0.152767
# NFL direct model 152/200 completed
# Range [0.760, 0.765): 1325 train, 148 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.8664, Train Loss: 0.3146, Val Acc: 0.8851, Val Loss: 0.2732
# Restored model from best epoch 7 with val_loss: 0.273233
# NFL direct model 153/200 completed
# Range [0.765, 0.770): 1746 train, 194 validation
# Starting training on device: cpu
# Early stopping at epoch 32
# Best epoch: 22, Train Acc: 0.8826, Train Loss: 0.2756, Val Acc: 0.8402, Val Loss: 0.2628
# Restored model from best epoch 22 with val_loss: 0.262839
# NFL direct model 154/200 completed
# Range [0.770, 0.775): 1511 train, 168 validation
# Starting training on device: cpu
# Early stopping at epoch 28
# Best epoch: 18, Train Acc: 0.8610, Train Loss: 0.2901, Val Acc: 0.8333, Val Loss: 0.3308
# Restored model from best epoch 18 with val_loss: 0.330829
# NFL direct model 155/200 completed
# Range [0.775, 0.780): 1859 train, 207 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.8542, Train Loss: 0.3339, Val Acc: 0.8454, Val Loss: 0.2799
# Restored model from best epoch 3 with val_loss: 0.279937
# NFL direct model 156/200 completed
# Range [0.780, 0.785): 1592 train, 177 validation
# Starting training on device: cpu
# Early stopping at epoch 27
# Best epoch: 17, Train Acc: 0.8731, Train Loss: 0.2973, Val Acc: 0.8362, Val Loss: 0.3693
# Restored model from best epoch 17 with val_loss: 0.369279
# NFL direct model 157/200 completed
# Range [0.785, 0.790): 1737 train, 193 validation
# Starting training on device: cpu
# Early stopping at epoch 38
# Best epoch: 28, Train Acc: 0.8860, Train Loss: 0.2790, Val Acc: 0.8705, Val Loss: 0.3124
# Restored model from best epoch 28 with val_loss: 0.312405
# NFL direct model 158/200 completed
# Range [0.790, 0.795): 1630 train, 182 validation
# Starting training on device: cpu
# Early stopping at epoch 24
# Best epoch: 14, Train Acc: 0.8865, Train Loss: 0.2640, Val Acc: 0.8462, Val Loss: 0.3313
# Restored model from best epoch 14 with val_loss: 0.331346
# NFL direct model 159/200 completed
# Range [0.795, 0.800): 1611 train, 179 validation
# Starting training on device: cpu
# Early stopping at epoch 38
# Best epoch: 28, Train Acc: 0.8858, Train Loss: 0.2567, Val Acc: 0.8547, Val Loss: 0.3503
# Restored model from best epoch 28 with val_loss: 0.350348
# NFL direct model 160/200 completed
# Range [0.800, 0.805): 1800 train, 200 validation
# Starting training on device: cpu
# Early stopping at epoch 37
# Best epoch: 27, Train Acc: 0.8900, Train Loss: 0.2511, Val Acc: 0.8850, Val Loss: 0.2380
# Restored model from best epoch 27 with val_loss: 0.237965
# NFL direct model 161/200 completed
# Range [0.805, 0.810): 1728 train, 193 validation
# Starting training on device: cpu
# Early stopping at epoch 34
# Best epoch: 24, Train Acc: 0.8976, Train Loss: 0.2430, Val Acc: 0.8497, Val Loss: 0.2519
# Restored model from best epoch 24 with val_loss: 0.251931
# NFL direct model 162/200 completed
# Range [0.810, 0.815): 1706 train, 190 validation
# Starting training on device: cpu
# Early stopping at epoch 17
# Best epoch: 7, Train Acc: 0.8716, Train Loss: 0.2922, Val Acc: 0.8684, Val Loss: 0.3554
# Restored model from best epoch 7 with val_loss: 0.355377
# NFL direct model 163/200 completed
# Range [0.815, 0.820): 1681 train, 187 validation
# Starting training on device: cpu
# Early stopping at epoch 22
# Best epoch: 12, Train Acc: 0.8673, Train Loss: 0.2903, Val Acc: 0.8770, Val Loss: 0.2712
# Restored model from best epoch 12 with val_loss: 0.271186
# NFL direct model 164/200 completed
# Range [0.820, 0.825): 1755 train, 195 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.8604, Train Loss: 0.3171, Val Acc: 0.8821, Val Loss: 0.4278
# Restored model from best epoch 6 with val_loss: 0.427783
# NFL direct model 165/200 completed
# Range [0.825, 0.830): 1619 train, 180 validation
# Starting training on device: cpu
# Early stopping at epoch 23
# Best epoch: 13, Train Acc: 0.8826, Train Loss: 0.2767, Val Acc: 0.8056, Val Loss: 0.3572
# Restored model from best epoch 13 with val_loss: 0.357224
# NFL direct model 166/200 completed
# Range [0.830, 0.835): 1687 train, 188 validation
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 10, Train Acc: 0.8743, Train Loss: 0.2898, Val Acc: 0.8777, Val Loss: 0.3223
# Restored model from best epoch 10 with val_loss: 0.322333
# NFL direct model 167/200 completed
# Range [0.835, 0.840): 1695 train, 189 validation
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 10, Train Acc: 0.8944, Train Loss: 0.2656, Val Acc: 0.8677, Val Loss: 0.2897
# Restored model from best epoch 10 with val_loss: 0.289669
# NFL direct model 168/200 completed
# Range [0.840, 0.845): 1687 train, 188 validation
# Starting training on device: cpu
# Early stopping at epoch 14
# Best epoch: 4, Train Acc: 0.8726, Train Loss: 0.2916, Val Acc: 0.8670, Val Loss: 0.3033
# Restored model from best epoch 4 with val_loss: 0.303317
# NFL direct model 169/200 completed
# Range [0.845, 0.850): 1717 train, 191 validation
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 8, Train Acc: 0.8602, Train Loss: 0.3135, Val Acc: 0.8901, Val Loss: 0.2842
# Restored model from best epoch 8 with val_loss: 0.284151
# NFL direct model 170/200 completed
# Range [0.850, 0.855): 1709 train, 190 validation
# Starting training on device: cpu
# Early stopping at epoch 21
# Best epoch: 11, Train Acc: 0.8824, Train Loss: 0.2759, Val Acc: 0.9316, Val Loss: 0.1838
# Restored model from best epoch 11 with val_loss: 0.183813
# NFL direct model 171/200 completed
# Range [0.855, 0.860): 1665 train, 186 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.8787, Train Loss: 0.3971, Val Acc: 0.8817, Val Loss: 0.3109
# Restored model from best epoch 6 with val_loss: 0.310934
# NFL direct model 172/200 completed
# Range [0.860, 0.865): 1709 train, 190 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.8841, Train Loss: 0.2864, Val Acc: 0.8579, Val Loss: 0.3013
# Restored model from best epoch 6 with val_loss: 0.301283
# NFL direct model 173/200 completed
# Range [0.865, 0.870): 1679 train, 187 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.8785, Train Loss: 0.2920, Val Acc: 0.8717, Val Loss: 0.2382
# Restored model from best epoch 6 with val_loss: 0.238250
# NFL direct model 174/200 completed
# Range [0.870, 0.875): 1686 train, 188 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.8387, Train Loss: 0.3893, Val Acc: 0.8404, Val Loss: 0.3172
# Restored model from best epoch 2 with val_loss: 0.317211
# NFL direct model 175/200 completed
# Range [0.875, 0.880): 1739 train, 194 validation
# Starting training on device: cpu
# Early stopping at epoch 13
# Best epoch: 3, Train Acc: 0.8810, Train Loss: 0.3103, Val Acc: 0.8918, Val Loss: 0.2320
# Restored model from best epoch 3 with val_loss: 0.232007
# NFL direct model 176/200 completed
# Range [0.880, 0.885): 1704 train, 190 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.8750, Train Loss: 0.2901, Val Acc: 0.8684, Val Loss: 0.2699
# Restored model from best epoch 6 with val_loss: 0.269867
# NFL direct model 177/200 completed
# Range [0.885, 0.890): 1711 train, 191 validation
# Starting training on device: cpu
# Early stopping at epoch 31
# Best epoch: 21, Train Acc: 0.9036, Train Loss: 0.2337, Val Acc: 0.8743, Val Loss: 0.3356
# Restored model from best epoch 21 with val_loss: 0.335556
# NFL direct model 178/200 completed
# Range [0.890, 0.895): 1736 train, 193 validation
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 10, Train Acc: 0.8796, Train Loss: 0.2716, Val Acc: 0.8912, Val Loss: 0.1860
# Restored model from best epoch 10 with val_loss: 0.186002
# NFL direct model 179/200 completed
# Range [0.895, 0.900): 1753 train, 195 validation
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 8, Train Acc: 0.8967, Train Loss: 0.2453, Val Acc: 0.9026, Val Loss: 0.1686
# Restored model from best epoch 8 with val_loss: 0.168585
# NFL direct model 180/200 completed
# Range [0.900, 0.905): 1698 train, 189 validation
# Starting training on device: cpu
# Early stopping at epoch 16
# Best epoch: 6, Train Acc: 0.8787, Train Loss: 0.2877, Val Acc: 0.8571, Val Loss: 0.3068
# Restored model from best epoch 6 with val_loss: 0.306763
# NFL direct model 181/200 completed
# Range [0.905, 0.910): 1741 train, 194 validation
# Starting training on device: cpu
# Early stopping at epoch 29
# Best epoch: 19, Train Acc: 0.9058, Train Loss: 0.2202, Val Acc: 0.8763, Val Loss: 0.3351
# Restored model from best epoch 19 with val_loss: 0.335119
# NFL direct model 182/200 completed
# Range [0.910, 0.915): 1769 train, 197 validation
# Starting training on device: cpu
# Early stopping at epoch 25
# Best epoch: 15, Train Acc: 0.9011, Train Loss: 0.2256, Val Acc: 0.8680, Val Loss: 0.2349
# Restored model from best epoch 15 with val_loss: 0.234943
# NFL direct model 183/200 completed
# Range [0.915, 0.920): 1763 train, 196 validation
# Starting training on device: cpu
# Early stopping at epoch 24
# Best epoch: 14, Train Acc: 0.9047, Train Loss: 0.2219, Val Acc: 0.8878, Val Loss: 0.2008
# Restored model from best epoch 14 with val_loss: 0.200754
# NFL direct model 184/200 completed
# Range [0.920, 0.925): 1872 train, 208 validation
# Starting training on device: cpu
# Early stopping at epoch 27
# Best epoch: 17, Train Acc: 0.9076, Train Loss: 0.2209, Val Acc: 0.8798, Val Loss: 0.2623
# Restored model from best epoch 17 with val_loss: 0.262279
# NFL direct model 185/200 completed
# Range [0.925, 0.930): 1945 train, 217 validation
# Starting training on device: cpu
# Early stopping at epoch 19
# Best epoch: 9, Train Acc: 0.8972, Train Loss: 0.2365, Val Acc: 0.8848, Val Loss: 0.2598
# Restored model from best epoch 9 with val_loss: 0.259778
# NFL direct model 186/200 completed
# Range [0.930, 0.935): 1921 train, 214 validation
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 10, Train Acc: 0.9037, Train Loss: 0.2131, Val Acc: 0.8879, Val Loss: 0.2314
# Restored model from best epoch 10 with val_loss: 0.231388
# NFL direct model 187/200 completed
# Range [0.935, 0.940): 2052 train, 228 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.8757, Train Loss: 0.3054, Val Acc: 0.9254, Val Loss: 0.1869
# Restored model from best epoch 2 with val_loss: 0.186906
# NFL direct model 188/200 completed
# Range [0.940, 0.945): 2202 train, 245 validation
# Starting training on device: cpu
# Early stopping at epoch 23
# Best epoch: 13, Train Acc: 0.9169, Train Loss: 0.1798, Val Acc: 0.9224, Val Loss: 0.2296
# Restored model from best epoch 13 with val_loss: 0.229616
# NFL direct model 189/200 completed
# Range [0.945, 0.950): 2198 train, 245 validation
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 8, Train Acc: 0.9026, Train Loss: 0.2225, Val Acc: 0.9265, Val Loss: 0.2077
# Restored model from best epoch 8 with val_loss: 0.207734
# NFL direct model 190/200 completed
# Range [0.950, 0.955): 2246 train, 250 validation
# Starting training on device: cpu
# Early stopping at epoch 27
# Best epoch: 17, Train Acc: 0.9043, Train Loss: 0.2108, Val Acc: 0.8840, Val Loss: 0.2013
# Restored model from best epoch 17 with val_loss: 0.201338
# NFL direct model 191/200 completed
# Range [0.955, 0.960): 2124 train, 236 validation
# Starting training on device: cpu
# Early stopping at epoch 38
# Best epoch: 28, Train Acc: 0.9204, Train Loss: 0.1674, Val Acc: 0.8898, Val Loss: 0.2077
# Restored model from best epoch 28 with val_loss: 0.207685
# NFL direct model 192/200 completed
# Range [0.960, 0.965): 2258 train, 251 validation
# Starting training on device: cpu
# Early stopping at epoch 24
# Best epoch: 14, Train Acc: 0.9079, Train Loss: 0.2048, Val Acc: 0.9044, Val Loss: 0.2483
# Restored model from best epoch 14 with val_loss: 0.248329
# NFL direct model 193/200 completed
# Range [0.965, 0.970): 2055 train, 229 validation
# Starting training on device: cpu
# Early stopping at epoch 12
# Best epoch: 2, Train Acc: 0.8798, Train Loss: 0.2701, Val Acc: 0.9258, Val Loss: 0.1997
# Restored model from best epoch 2 with val_loss: 0.199661
# NFL direct model 194/200 completed
# Range [0.970, 0.975): 4770 train, 531 validation
# Starting training on device: cpu
# Early stopping at epoch 18
# Best epoch: 8, Train Acc: 0.9038, Train Loss: 0.2185, Val Acc: 0.8889, Val Loss: 0.2485
# Restored model from best epoch 8 with val_loss: 0.248502
# NFL direct model 195/200 completed
# Range [0.975, 0.980): 2214 train, 247 validation
# Starting training on device: cpu
# Early stopping at epoch 20
# Best epoch: 10, Train Acc: 0.9088, Train Loss: 0.2151, Val Acc: 0.9150, Val Loss: 0.2166
# Restored model from best epoch 10 with val_loss: 0.216618
# NFL direct model 196/200 completed
# Range [0.980, 0.985): 2312 train, 257 validation
# Starting training on device: cpu
# Early stopping at epoch 25
# Best epoch: 15, Train Acc: 0.9286, Train Loss: 0.1553, Val Acc: 0.8911, Val Loss: 0.1874
# Restored model from best epoch 15 with val_loss: 0.187431
# NFL direct model 197/200 completed
# Range [0.985, 0.990): 2234 train, 249 validation
# Starting training on device: cpu
# Early stopping at epoch 26
# Best epoch: 16, Train Acc: 0.9320, Train Loss: 0.1649, Val Acc: 0.9157, Val Loss: 0.2236
# Restored model from best epoch 16 with val_loss: 0.223604
# NFL direct model 198/200 completed
# Range [0.990, 0.995): 2293 train, 255 validation
# Starting training on device: cpu
# Early stopping at epoch 24
# Best epoch: 14, Train Acc: 0.9311, Train Loss: 0.1744, Val Acc: 0.8745, Val Loss: 0.2443
# Restored model from best epoch 14 with val_loss: 0.244322
# NFL direct model 199/200 completed
# Range [0.995, 1.000): 5067 train, 564 validation
# Starting training on device: cpu
# Early stopping at epoch 28
# Best epoch: 18, Train Acc: 0.9445, Train Loss: 0.1271, Val Acc: 0.9468, Val Loss: 0.1229
# Restored model from best epoch 18 with val_loss: 0.122920
# NFL direct model 200/200 completed

# %%
other_features = [
            "home_has_possession", # Binary indicator
            "end.down",            # Down number (1-4, discrete)
            "home_timeouts_left",  # Discrete count (0-3)
            "away_timeouts_left",  # Discrete count (0-3)
        ]
numeric_features = [
    "score_difference",
    "relative_strength", 
    "end.yardsToEndzone", 
    "end.distance", 
    "predicted_drive_points_prob_0_2pts",
    "predicted_drive_points_prob_3_6pts",
    "predicted_drive_points_prob_7plus_pts"
]

# lr_numeric_features= [
#     "score_difference",
#     "relative_strength"
# ]
# lr_other_features = [
#    "home_has_possession" 
# ]
# lr_features = ["relative_strength", "score_difference", "home_has_possession"]
all_models["logistic"] = setup_logistic_regression_models(training_data, None, numeric_features, other_features, features)
# Out:
# Processing timestep: 0.0
# Timestep 0.00% : Training Loss = 0.6112, Accuracy = 0.6650, Test Loss = 0.6256, Test Accuracy = 0.6337
# Processing timestep: 0.005
# Timestep 0.50% : Training Loss = 0.6169, Accuracy = 0.6599, Test Loss = 0.6489, Test Accuracy = 0.5850
# Processing timestep: 0.01
# Timestep 1.00% : Training Loss = 0.6031, Accuracy = 0.6572, Test Loss = 0.6414, Test Accuracy = 0.6154
# Processing timestep: 0.015
# Timestep 1.50% : Training Loss = 0.6260, Accuracy = 0.6552, Test Loss = 0.6160, Test Accuracy = 0.6537
# Processing timestep: 0.02
# Timestep 2.00% : Training Loss = 0.6213, Accuracy = 0.6644, Test Loss = 0.6437, Test Accuracy = 0.6279
# Processing timestep: 0.025
# Timestep 2.50% : Training Loss = 0.6247, Accuracy = 0.6614, Test Loss = 0.6161, Test Accuracy = 0.6579
# Processing timestep: 0.03
# Timestep 3.00% : Training Loss = 0.6043, Accuracy = 0.6774, Test Loss = 0.6614, Test Accuracy = 0.6087
# Processing timestep: 0.035
# Timestep 3.50% : Training Loss = 0.6224, Accuracy = 0.6602, Test Loss = 0.6357, Test Accuracy = 0.5964
# Processing timestep: 0.04
# Timestep 4.00% : Training Loss = 0.6102, Accuracy = 0.6685, Test Loss = 0.6170, Test Accuracy = 0.6603
# Processing timestep: 0.045
# Timestep 4.50% : Training Loss = 0.6119, Accuracy = 0.6713, Test Loss = 0.6300, Test Accuracy = 0.6536
# Processing timestep: 0.05
# Timestep 5.00% : Training Loss = 0.6054, Accuracy = 0.6779, Test Loss = 0.6449, Test Accuracy = 0.5919
# Processing timestep: 0.055
# Timestep 5.50% : Training Loss = 0.6071, Accuracy = 0.6774, Test Loss = 0.6209, Test Accuracy = 0.6616
# Processing timestep: 0.06
# Timestep 6.00% : Training Loss = 0.6045, Accuracy = 0.6782, Test Loss = 0.6206, Test Accuracy = 0.6316
# Processing timestep: 0.065
# Timestep 6.50% : Training Loss = 0.6175, Accuracy = 0.6634, Test Loss = 0.6263, Test Accuracy = 0.6350
# Processing timestep: 0.07
# Timestep 7.00% : Training Loss = 0.5972, Accuracy = 0.6799, Test Loss = 0.6422, Test Accuracy = 0.6429
# Processing timestep: 0.075
# Timestep 7.50% : Training Loss = 0.6091, Accuracy = 0.6743, Test Loss = 0.6163, Test Accuracy = 0.6507
# Processing timestep: 0.08
# Timestep 8.00% : Training Loss = 0.5950, Accuracy = 0.6877, Test Loss = 0.6014, Test Accuracy = 0.6809
# Processing timestep: 0.085
# Timestep 8.50% : Training Loss = 0.6060, Accuracy = 0.6751, Test Loss = 0.6192, Test Accuracy = 0.6573
# Processing timestep: 0.09
# Timestep 9.00% : Training Loss = 0.6062, Accuracy = 0.6813, Test Loss = 0.6271, Test Accuracy = 0.6185
# Processing timestep: 0.095
# Timestep 9.50% : Training Loss = 0.6121, Accuracy = 0.6740, Test Loss = 0.5997, Test Accuracy = 0.6714
# Processing timestep: 0.1
# Timestep 10.00% : Training Loss = 0.5833, Accuracy = 0.6949, Test Loss = 0.6252, Test Accuracy = 0.6295
# Processing timestep: 0.105
# Timestep 10.50% : Training Loss = 0.5890, Accuracy = 0.6838, Test Loss = 0.6167, Test Accuracy = 0.6145
# Processing timestep: 0.11
# Timestep 11.00% : Training Loss = 0.5984, Accuracy = 0.6772, Test Loss = 0.6355, Test Accuracy = 0.6373
# Processing timestep: 0.115
# Timestep 11.50% : Training Loss = 0.5765, Accuracy = 0.6928, Test Loss = 0.6020, Test Accuracy = 0.6557
# Processing timestep: 0.12
# Timestep 12.00% : Training Loss = 0.5866, Accuracy = 0.6941, Test Loss = 0.6404, Test Accuracy = 0.6325
# Processing timestep: 0.125
# Timestep 12.50% : Training Loss = 0.5748, Accuracy = 0.6958, Test Loss = 0.6014, Test Accuracy = 0.6702
# Processing timestep: 0.13
# Timestep 13.00% : Training Loss = 0.5647, Accuracy = 0.7039, Test Loss = 0.6518, Test Accuracy = 0.6560
# Processing timestep: 0.135
# Timestep 13.50% : Training Loss = 0.5956, Accuracy = 0.6862, Test Loss = 0.5997, Test Accuracy = 0.6715
# Processing timestep: 0.14
# Timestep 14.00% : Training Loss = 0.5678, Accuracy = 0.7158, Test Loss = 0.6332, Test Accuracy = 0.6320
# Processing timestep: 0.145
# Timestep 14.50% : Training Loss = 0.5677, Accuracy = 0.7100, Test Loss = 0.5944, Test Accuracy = 0.6775
# Processing timestep: 0.15
# Timestep 15.00% : Training Loss = 0.5718, Accuracy = 0.7099, Test Loss = 0.6260, Test Accuracy = 0.6678
# Processing timestep: 0.155
# Timestep 15.50% : Training Loss = 0.5803, Accuracy = 0.7038, Test Loss = 0.6133, Test Accuracy = 0.6844
# Processing timestep: 0.16
# Timestep 16.00% : Training Loss = 0.5651, Accuracy = 0.7118, Test Loss = 0.6345, Test Accuracy = 0.6565
# Processing timestep: 0.165
# Timestep 16.50% : Training Loss = 0.5789, Accuracy = 0.6873, Test Loss = 0.6160, Test Accuracy = 0.6493
# Processing timestep: 0.17
# Timestep 17.00% : Training Loss = 0.5688, Accuracy = 0.7116, Test Loss = 0.6101, Test Accuracy = 0.6426
# Processing timestep: 0.175
# Timestep 17.50% : Training Loss = 0.5885, Accuracy = 0.6933, Test Loss = 0.5902, Test Accuracy = 0.6771
# Processing timestep: 0.18
# Timestep 18.00% : Training Loss = 0.5595, Accuracy = 0.7165, Test Loss = 0.5965, Test Accuracy = 0.7037
# Processing timestep: 0.185
# Timestep 18.50% : Training Loss = 0.5728, Accuracy = 0.7056, Test Loss = 0.5991, Test Accuracy = 0.6918
# Processing timestep: 0.19
# Timestep 19.00% : Training Loss = 0.5553, Accuracy = 0.7121, Test Loss = 0.5880, Test Accuracy = 0.7037
# Processing timestep: 0.195
# Timestep 19.50% : Training Loss = 0.5498, Accuracy = 0.7114, Test Loss = 0.6262, Test Accuracy = 0.6370
# Processing timestep: 0.2
# Timestep 20.00% : Training Loss = 0.5710, Accuracy = 0.7018, Test Loss = 0.5717, Test Accuracy = 0.6886
# Processing timestep: 0.205
# Timestep 20.50% : Training Loss = 0.5690, Accuracy = 0.6893, Test Loss = 0.5285, Test Accuracy = 0.6957
# Processing timestep: 0.21
# Timestep 21.00% : Training Loss = 0.5499, Accuracy = 0.7173, Test Loss = 0.6053, Test Accuracy = 0.6781
# Processing timestep: 0.215
# Timestep 21.50% : Training Loss = 0.5618, Accuracy = 0.7060, Test Loss = 0.5567, Test Accuracy = 0.6970
# Processing timestep: 0.22
# Timestep 22.00% : Training Loss = 0.5491, Accuracy = 0.7147, Test Loss = 0.5724, Test Accuracy = 0.6879
# Processing timestep: 0.225
# Timestep 22.50% : Training Loss = 0.5471, Accuracy = 0.7136, Test Loss = 0.5952, Test Accuracy = 0.6877
# Processing timestep: 0.23
# Timestep 23.00% : Training Loss = 0.5385, Accuracy = 0.7288, Test Loss = 0.5667, Test Accuracy = 0.6629
# Processing timestep: 0.235
# Timestep 23.50% : Training Loss = 0.5508, Accuracy = 0.7309, Test Loss = 0.5182, Test Accuracy = 0.6993
# Processing timestep: 0.24
# Timestep 24.00% : Training Loss = 0.5677, Accuracy = 0.7065, Test Loss = 0.5883, Test Accuracy = 0.6704
# Processing timestep: 0.245
# Timestep 24.50% : Training Loss = 0.5532, Accuracy = 0.7197, Test Loss = 0.5807, Test Accuracy = 0.6929
# Processing timestep: 0.25
# Timestep 25.00% : Training Loss = 0.5453, Accuracy = 0.7165, Test Loss = 0.5547, Test Accuracy = 0.7058
# Processing timestep: 0.255
# Timestep 25.50% : Training Loss = 0.5523, Accuracy = 0.7072, Test Loss = 0.5175, Test Accuracy = 0.7500
# Processing timestep: 0.26
# Timestep 26.00% : Training Loss = 0.5529, Accuracy = 0.7173, Test Loss = 0.5836, Test Accuracy = 0.6852
# Processing timestep: 0.265
# Timestep 26.50% : Training Loss = 0.5423, Accuracy = 0.7227, Test Loss = 0.5372, Test Accuracy = 0.7457
# Processing timestep: 0.27
# Timestep 27.00% : Training Loss = 0.5400, Accuracy = 0.7257, Test Loss = 0.5530, Test Accuracy = 0.7077
# Processing timestep: 0.275
# Timestep 27.50% : Training Loss = 0.5497, Accuracy = 0.6945, Test Loss = 0.5629, Test Accuracy = 0.6926
# Processing timestep: 0.28
# Timestep 28.00% : Training Loss = 0.5492, Accuracy = 0.7164, Test Loss = 0.5276, Test Accuracy = 0.7354
# Processing timestep: 0.285
# Timestep 28.50% : Training Loss = 0.5356, Accuracy = 0.7362, Test Loss = 0.5405, Test Accuracy = 0.7081
# Processing timestep: 0.29
# Timestep 29.00% : Training Loss = 0.5418, Accuracy = 0.7153, Test Loss = 0.5461, Test Accuracy = 0.7022
# Processing timestep: 0.295
# Timestep 29.50% : Training Loss = 0.5347, Accuracy = 0.7278, Test Loss = 0.5586, Test Accuracy = 0.6833
# Processing timestep: 0.3
# Timestep 30.00% : Training Loss = 0.5461, Accuracy = 0.7159, Test Loss = 0.5421, Test Accuracy = 0.7254
# Processing timestep: 0.305
# Timestep 30.50% : Training Loss = 0.5230, Accuracy = 0.7194, Test Loss = 0.5763, Test Accuracy = 0.7057
# Processing timestep: 0.31
# Timestep 31.00% : Training Loss = 0.5282, Accuracy = 0.7254, Test Loss = 0.5550, Test Accuracy = 0.6877
# Processing timestep: 0.315
# Timestep 31.50% : Training Loss = 0.5606, Accuracy = 0.7050, Test Loss = 0.5625, Test Accuracy = 0.6750
# Processing timestep: 0.32
# Timestep 32.00% : Training Loss = 0.5123, Accuracy = 0.7422, Test Loss = 0.5172, Test Accuracy = 0.7102
# Processing timestep: 0.325
# Timestep 32.50% : Training Loss = 0.5213, Accuracy = 0.7413, Test Loss = 0.5493, Test Accuracy = 0.7122
# Processing timestep: 0.33
# Timestep 33.00% : Training Loss = 0.5170, Accuracy = 0.7401, Test Loss = 0.5376, Test Accuracy = 0.6929
# Processing timestep: 0.335
# Timestep 33.50% : Training Loss = 0.5175, Accuracy = 0.7409, Test Loss = 0.5426, Test Accuracy = 0.7228
# Processing timestep: 0.34
# Timestep 34.00% : Training Loss = 0.5113, Accuracy = 0.7368, Test Loss = 0.5482, Test Accuracy = 0.6920
# Processing timestep: 0.345
# Timestep 34.50% : Training Loss = 0.4957, Accuracy = 0.7630, Test Loss = 0.5399, Test Accuracy = 0.7241
# Processing timestep: 0.35
# Timestep 35.00% : Training Loss = 0.5082, Accuracy = 0.7463, Test Loss = 0.5566, Test Accuracy = 0.7113
# Processing timestep: 0.355
# Timestep 35.50% : Training Loss = 0.5198, Accuracy = 0.7409, Test Loss = 0.5332, Test Accuracy = 0.7340
# Processing timestep: 0.36
# Timestep 36.00% : Training Loss = 0.5318, Accuracy = 0.7341, Test Loss = 0.5636, Test Accuracy = 0.7065
# Processing timestep: 0.365
# Timestep 36.50% : Training Loss = 0.4975, Accuracy = 0.7646, Test Loss = 0.5228, Test Accuracy = 0.7213
# Processing timestep: 0.37
# Timestep 37.00% : Training Loss = 0.5354, Accuracy = 0.7365, Test Loss = 0.5274, Test Accuracy = 0.7316
# Processing timestep: 0.375
# Timestep 37.50% : Training Loss = 0.5011, Accuracy = 0.7428, Test Loss = 0.5647, Test Accuracy = 0.6996
# Processing timestep: 0.38
# Timestep 38.00% : Training Loss = 0.4958, Accuracy = 0.7577, Test Loss = 0.5308, Test Accuracy = 0.7101
# Processing timestep: 0.385
# Timestep 38.50% : Training Loss = 0.5094, Accuracy = 0.7404, Test Loss = 0.5157, Test Accuracy = 0.7509
# Processing timestep: 0.39
# Timestep 39.00% : Training Loss = 0.5016, Accuracy = 0.7422, Test Loss = 0.5502, Test Accuracy = 0.6942
# Processing timestep: 0.395
# Timestep 39.50% : Training Loss = 0.5045, Accuracy = 0.7449, Test Loss = 0.5362, Test Accuracy = 0.7404
# Processing timestep: 0.4
# Timestep 40.00% : Training Loss = 0.5213, Accuracy = 0.7261, Test Loss = 0.5387, Test Accuracy = 0.7384
# Processing timestep: 0.405
# Timestep 40.50% : Training Loss = 0.4784, Accuracy = 0.7685, Test Loss = 0.5048, Test Accuracy = 0.7736
# Processing timestep: 0.41
# Timestep 41.00% : Training Loss = 0.5084, Accuracy = 0.7390, Test Loss = 0.4992, Test Accuracy = 0.7751
# Processing timestep: 0.415
# Timestep 41.50% : Training Loss = 0.5031, Accuracy = 0.7513, Test Loss = 0.5374, Test Accuracy = 0.7168
# Processing timestep: 0.42
# Timestep 42.00% : Training Loss = 0.5079, Accuracy = 0.7391, Test Loss = 0.5763, Test Accuracy = 0.6829
# Processing timestep: 0.425
# Timestep 42.50% : Training Loss = 0.4896, Accuracy = 0.7659, Test Loss = 0.5496, Test Accuracy = 0.7536
# Processing timestep: 0.43
# Timestep 43.00% : Training Loss = 0.4797, Accuracy = 0.7712, Test Loss = 0.5790, Test Accuracy = 0.7061
# Processing timestep: 0.435
# Timestep 43.50% : Training Loss = 0.4933, Accuracy = 0.7621, Test Loss = 0.5072, Test Accuracy = 0.7509
# Processing timestep: 0.44
# Timestep 44.00% : Training Loss = 0.4860, Accuracy = 0.7723, Test Loss = 0.5489, Test Accuracy = 0.7106
# Processing timestep: 0.445
# Timestep 44.50% : Training Loss = 0.4724, Accuracy = 0.7695, Test Loss = 0.5685, Test Accuracy = 0.6912
# Processing timestep: 0.45
# Timestep 45.00% : Training Loss = 0.4824, Accuracy = 0.7738, Test Loss = 0.5654, Test Accuracy = 0.6915
# Processing timestep: 0.455
# Timestep 45.50% : Training Loss = 0.4901, Accuracy = 0.7689, Test Loss = 0.5554, Test Accuracy = 0.6879
# Processing timestep: 0.46
# Timestep 46.00% : Training Loss = 0.4648, Accuracy = 0.7732, Test Loss = 0.5236, Test Accuracy = 0.7465
# Processing timestep: 0.465
# Timestep 46.50% : Training Loss = 0.4559, Accuracy = 0.7851, Test Loss = 0.5297, Test Accuracy = 0.7407
# Processing timestep: 0.47
# Timestep 47.00% : Training Loss = 0.4660, Accuracy = 0.7797, Test Loss = 0.5079, Test Accuracy = 0.7339
# Processing timestep: 0.475
# Timestep 47.50% : Training Loss = 0.4344, Accuracy = 0.7985, Test Loss = 0.5057, Test Accuracy = 0.7519
# Processing timestep: 0.48
# Timestep 48.00% : Training Loss = 0.4489, Accuracy = 0.7893, Test Loss = 0.5107, Test Accuracy = 0.7741
# Processing timestep: 0.485
# Timestep 48.50% : Training Loss = 0.4490, Accuracy = 0.7810, Test Loss = 0.5236, Test Accuracy = 0.7500
# Processing timestep: 0.49
# Timestep 49.00% : Training Loss = 0.4493, Accuracy = 0.7923, Test Loss = 0.5359, Test Accuracy = 0.7340
# Processing timestep: 0.495
# Timestep 49.50% : Training Loss = 0.4444, Accuracy = 0.7958, Test Loss = 0.4940, Test Accuracy = 0.7816
# Processing timestep: 0.5
# Timestep 50.00% : Training Loss = 0.4374, Accuracy = 0.8011, Test Loss = 0.4702, Test Accuracy = 0.7905
# Processing timestep: 0.505
# Timestep 50.50% : Training Loss = 0.4236, Accuracy = 0.7933, Test Loss = 0.5258, Test Accuracy = 0.7927
# Processing timestep: 0.51
# Timestep 51.00% : Training Loss = 0.4295, Accuracy = 0.8043, Test Loss = 0.4736, Test Accuracy = 0.7895
# Processing timestep: 0.515
# Timestep 51.50% : Training Loss = 0.4206, Accuracy = 0.8158, Test Loss = 0.4637, Test Accuracy = 0.8043
# Processing timestep: 0.52
# Timestep 52.00% : Training Loss = 0.4353, Accuracy = 0.7990, Test Loss = 0.4700, Test Accuracy = 0.8192
# Processing timestep: 0.525
# Timestep 52.50% : Training Loss = 0.4070, Accuracy = 0.8136, Test Loss = 0.4589, Test Accuracy = 0.7891
# Processing timestep: 0.53
# Timestep 53.00% : Training Loss = 0.4386, Accuracy = 0.7928, Test Loss = 0.4774, Test Accuracy = 0.7698
# Processing timestep: 0.535
# Timestep 53.50% : Training Loss = 0.3936, Accuracy = 0.8252, Test Loss = 0.4531, Test Accuracy = 0.8022
# Processing timestep: 0.54
# Timestep 54.00% : Training Loss = 0.4277, Accuracy = 0.8066, Test Loss = 0.5183, Test Accuracy = 0.7303
# Processing timestep: 0.545
# Timestep 54.50% : Training Loss = 0.4225, Accuracy = 0.8115, Test Loss = 0.5105, Test Accuracy = 0.7594
# Processing timestep: 0.55
# Timestep 55.00% : Training Loss = 0.3960, Accuracy = 0.8250, Test Loss = 0.4625, Test Accuracy = 0.7737
# Processing timestep: 0.555
# Timestep 55.50% : Training Loss = 0.4235, Accuracy = 0.8138, Test Loss = 0.4300, Test Accuracy = 0.8118
# Processing timestep: 0.56
# Timestep 56.00% : Training Loss = 0.4094, Accuracy = 0.8262, Test Loss = 0.4606, Test Accuracy = 0.7956
# Processing timestep: 0.565
# Timestep 56.50% : Training Loss = 0.4042, Accuracy = 0.8138, Test Loss = 0.4796, Test Accuracy = 0.7607
# Processing timestep: 0.57
# Timestep 57.00% : Training Loss = 0.4086, Accuracy = 0.8217, Test Loss = 0.4718, Test Accuracy = 0.7754
# Processing timestep: 0.575
# Timestep 57.50% : Training Loss = 0.4159, Accuracy = 0.8065, Test Loss = 0.4827, Test Accuracy = 0.7570
# Processing timestep: 0.58
# Timestep 58.00% : Training Loss = 0.4165, Accuracy = 0.8059, Test Loss = 0.4506, Test Accuracy = 0.7741
# Processing timestep: 0.585
# Timestep 58.50% : Training Loss = 0.4176, Accuracy = 0.8151, Test Loss = 0.4225, Test Accuracy = 0.7839
# Processing timestep: 0.59
# Timestep 59.00% : Training Loss = 0.4154, Accuracy = 0.8173, Test Loss = 0.4954, Test Accuracy = 0.7448
# Processing timestep: 0.595
# Timestep 59.50% : Training Loss = 0.4052, Accuracy = 0.8143, Test Loss = 0.4829, Test Accuracy = 0.7439
# Processing timestep: 0.6
# Timestep 60.00% : Training Loss = 0.3978, Accuracy = 0.8083, Test Loss = 0.4583, Test Accuracy = 0.7482
# Processing timestep: 0.605
# Timestep 60.50% : Training Loss = 0.4079, Accuracy = 0.8074, Test Loss = 0.4661, Test Accuracy = 0.7622
# Processing timestep: 0.61
# Timestep 61.00% : Training Loss = 0.3955, Accuracy = 0.8198, Test Loss = 0.4997, Test Accuracy = 0.7396
# Processing timestep: 0.615
# Timestep 61.50% : Training Loss = 0.3769, Accuracy = 0.8213, Test Loss = 0.4576, Test Accuracy = 0.7616
# Processing timestep: 0.62
# Timestep 62.00% : Training Loss = 0.4044, Accuracy = 0.8123, Test Loss = 0.4628, Test Accuracy = 0.7742
# Processing timestep: 0.625
# Timestep 62.50% : Training Loss = 0.4060, Accuracy = 0.8131, Test Loss = 0.4709, Test Accuracy = 0.7586
# Processing timestep: 0.63
# Timestep 63.00% : Training Loss = 0.3872, Accuracy = 0.8304, Test Loss = 0.4482, Test Accuracy = 0.7679
# Processing timestep: 0.635
# Timestep 63.50% : Training Loss = 0.3968, Accuracy = 0.8194, Test Loss = 0.4873, Test Accuracy = 0.7312
# Processing timestep: 0.64
# Timestep 64.00% : Training Loss = 0.3859, Accuracy = 0.8352, Test Loss = 0.5166, Test Accuracy = 0.7453
# Processing timestep: 0.645
# Timestep 64.50% : Training Loss = 0.4036, Accuracy = 0.8234, Test Loss = 0.4597, Test Accuracy = 0.7483
# Processing timestep: 0.65
# Timestep 65.00% : Training Loss = 0.3883, Accuracy = 0.8173, Test Loss = 0.5458, Test Accuracy = 0.7509
# Processing timestep: 0.655
# Timestep 65.50% : Training Loss = 0.3641, Accuracy = 0.8381, Test Loss = 0.4918, Test Accuracy = 0.7587
# Processing timestep: 0.66
# Timestep 66.00% : Training Loss = 0.3648, Accuracy = 0.8427, Test Loss = 0.4662, Test Accuracy = 0.7700
# Processing timestep: 0.665
# Timestep 66.50% : Training Loss = 0.3686, Accuracy = 0.8323, Test Loss = 0.4826, Test Accuracy = 0.7679
# Processing timestep: 0.67
# Timestep 67.00% : Training Loss = 0.3761, Accuracy = 0.8351, Test Loss = 0.4286, Test Accuracy = 0.7766
# Processing timestep: 0.675
# Timestep 67.50% : Training Loss = 0.3723, Accuracy = 0.8346, Test Loss = 0.4244, Test Accuracy = 0.7847
# Processing timestep: 0.68
# Timestep 68.00% : Training Loss = 0.3766, Accuracy = 0.8295, Test Loss = 0.4013, Test Accuracy = 0.7842
# Processing timestep: 0.685
# Timestep 68.50% : Training Loss = 0.3652, Accuracy = 0.8418, Test Loss = 0.4911, Test Accuracy = 0.7474
# Processing timestep: 0.69
# Timestep 69.00% : Training Loss = 0.3788, Accuracy = 0.8286, Test Loss = 0.4042, Test Accuracy = 0.7943
# Processing timestep: 0.695
# Timestep 69.50% : Training Loss = 0.3522, Accuracy = 0.8415, Test Loss = 0.4134, Test Accuracy = 0.7878
# Processing timestep: 0.7
# Timestep 70.00% : Training Loss = 0.3718, Accuracy = 0.8354, Test Loss = 0.3955, Test Accuracy = 0.8112
# Processing timestep: 0.705
# Timestep 70.50% : Training Loss = 0.3552, Accuracy = 0.8332, Test Loss = 0.4081, Test Accuracy = 0.7875
# Processing timestep: 0.71
# Timestep 71.00% : Training Loss = 0.3616, Accuracy = 0.8469, Test Loss = 0.4054, Test Accuracy = 0.7847
# Processing timestep: 0.715
# Timestep 71.50% : Training Loss = 0.3541, Accuracy = 0.8355, Test Loss = 0.4538, Test Accuracy = 0.7825
# Processing timestep: 0.72
# Timestep 72.00% : Training Loss = 0.3472, Accuracy = 0.8444, Test Loss = 0.4126, Test Accuracy = 0.8262
# Processing timestep: 0.725
# Timestep 72.50% : Training Loss = 0.3537, Accuracy = 0.8400, Test Loss = 0.4362, Test Accuracy = 0.7931
# Processing timestep: 0.73
# Timestep 73.00% : Training Loss = 0.3449, Accuracy = 0.8376, Test Loss = 0.4466, Test Accuracy = 0.8153
# Processing timestep: 0.735
# Timestep 73.50% : Training Loss = 0.3377, Accuracy = 0.8564, Test Loss = 0.4244, Test Accuracy = 0.7878
# Processing timestep: 0.74
# Timestep 74.00% : Training Loss = 0.3425, Accuracy = 0.8491, Test Loss = 0.3797, Test Accuracy = 0.8378
# Processing timestep: 0.745
# Timestep 74.50% : Training Loss = 0.3372, Accuracy = 0.8546, Test Loss = 0.4474, Test Accuracy = 0.7992
# Processing timestep: 0.75
# Timestep 75.00% : Training Loss = 0.3391, Accuracy = 0.8464, Test Loss = 0.3901, Test Accuracy = 0.8050
# Processing timestep: 0.755
# Timestep 75.50% : Training Loss = 0.3085, Accuracy = 0.8710, Test Loss = 0.3710, Test Accuracy = 0.8494
# Processing timestep: 0.76
# Timestep 76.00% : Training Loss = 0.3237, Accuracy = 0.8554, Test Loss = 0.3847, Test Accuracy = 0.8507
# Processing timestep: 0.765
# Timestep 76.50% : Training Loss = 0.3086, Accuracy = 0.8690, Test Loss = 0.4226, Test Accuracy = 0.8213
# Processing timestep: 0.77
# Timestep 77.00% : Training Loss = 0.3213, Accuracy = 0.8549, Test Loss = 0.4263, Test Accuracy = 0.8016
# Processing timestep: 0.775
# Timestep 77.50% : Training Loss = 0.3173, Accuracy = 0.8593, Test Loss = 0.3195, Test Accuracy = 0.8774
# Processing timestep: 0.78
# Timestep 78.00% : Training Loss = 0.3307, Accuracy = 0.8476, Test Loss = 0.3910, Test Accuracy = 0.8308
# Processing timestep: 0.785
# Timestep 78.50% : Training Loss = 0.3227, Accuracy = 0.8579, Test Loss = 0.4090, Test Accuracy = 0.8276
# Processing timestep: 0.79
# Timestep 79.00% : Training Loss = 0.2964, Accuracy = 0.8734, Test Loss = 0.3401, Test Accuracy = 0.8382
# Processing timestep: 0.795
# Timestep 79.50% : Training Loss = 0.3331, Accuracy = 0.8468, Test Loss = 0.3504, Test Accuracy = 0.8401
# Processing timestep: 0.8
# Timestep 80.00% : Training Loss = 0.3077, Accuracy = 0.8659, Test Loss = 0.3657, Test Accuracy = 0.8467
# Processing timestep: 0.805
# Timestep 80.50% : Training Loss = 0.3069, Accuracy = 0.8597, Test Loss = 0.3688, Test Accuracy = 0.8408
# Processing timestep: 0.81
# Timestep 81.00% : Training Loss = 0.3023, Accuracy = 0.8628, Test Loss = 0.3793, Test Accuracy = 0.8351
# Processing timestep: 0.815
# Timestep 81.50% : Training Loss = 0.3004, Accuracy = 0.8664, Test Loss = 0.3745, Test Accuracy = 0.8256
# Processing timestep: 0.82
# Timestep 82.00% : Training Loss = 0.2951, Accuracy = 0.8666, Test Loss = 0.3621, Test Accuracy = 0.8362
# Processing timestep: 0.825
# Timestep 82.50% : Training Loss = 0.3074, Accuracy = 0.8587, Test Loss = 0.3410, Test Accuracy = 0.8593
# Processing timestep: 0.83
# Timestep 83.00% : Training Loss = 0.2905, Accuracy = 0.8657, Test Loss = 0.3536, Test Accuracy = 0.8298
# Processing timestep: 0.835
# Timestep 83.50% : Training Loss = 0.2697, Accuracy = 0.8838, Test Loss = 0.2905, Test Accuracy = 0.8763
# Processing timestep: 0.84
# Timestep 84.00% : Training Loss = 0.2704, Accuracy = 0.8788, Test Loss = 0.3173, Test Accuracy = 0.8617
# Processing timestep: 0.845
# Timestep 84.50% : Training Loss = 0.3038, Accuracy = 0.8600, Test Loss = 0.3649, Test Accuracy = 0.8397
# Processing timestep: 0.85
# Timestep 85.00% : Training Loss = 0.2754, Accuracy = 0.8699, Test Loss = 0.3595, Test Accuracy = 0.8316
# Processing timestep: 0.855
# Timestep 85.50% : Training Loss = 0.2714, Accuracy = 0.8830, Test Loss = 0.3681, Test Accuracy = 0.8201
# Processing timestep: 0.86
# Timestep 86.00% : Training Loss = 0.2683, Accuracy = 0.8724, Test Loss = 0.3556, Test Accuracy = 0.8316
# Processing timestep: 0.865
# Timestep 86.50% : Training Loss = 0.2811, Accuracy = 0.8707, Test Loss = 0.2921, Test Accuracy = 0.8750
# Processing timestep: 0.87
# Timestep 87.00% : Training Loss = 0.2807, Accuracy = 0.8668, Test Loss = 0.4114, Test Accuracy = 0.7943
# Processing timestep: 0.875
# Timestep 87.50% : Training Loss = 0.2791, Accuracy = 0.8758, Test Loss = 0.2735, Test Accuracy = 0.9034
# Processing timestep: 0.88
# Timestep 88.00% : Training Loss = 0.2672, Accuracy = 0.8769, Test Loss = 0.3458, Test Accuracy = 0.8491
# Processing timestep: 0.885
# Timestep 88.50% : Training Loss = 0.2848, Accuracy = 0.8700, Test Loss = 0.3313, Test Accuracy = 0.8392
# Processing timestep: 0.89
# Timestep 89.00% : Training Loss = 0.2792, Accuracy = 0.8725, Test Loss = 0.3844, Test Accuracy = 0.8207
# Processing timestep: 0.895
# Timestep 89.50% : Training Loss = 0.2538, Accuracy = 0.8900, Test Loss = 0.2596, Test Accuracy = 0.8805
# Processing timestep: 0.9
# Timestep 90.00% : Training Loss = 0.2940, Accuracy = 0.8690, Test Loss = 0.3485, Test Accuracy = 0.8380
# Processing timestep: 0.905
# Timestep 90.50% : Training Loss = 0.2484, Accuracy = 0.8893, Test Loss = 0.2995, Test Accuracy = 0.8591
# Processing timestep: 0.91
# Timestep 91.00% : Training Loss = 0.2560, Accuracy = 0.8893, Test Loss = 0.2832, Test Accuracy = 0.8610
# Processing timestep: 0.915
# Timestep 91.50% : Training Loss = 0.2467, Accuracy = 0.8961, Test Loss = 0.2816, Test Accuracy = 0.8707
# Processing timestep: 0.92
# Timestep 92.00% : Training Loss = 0.2653, Accuracy = 0.8801, Test Loss = 0.2987, Test Accuracy = 0.8590
# Processing timestep: 0.925
# Timestep 92.50% : Training Loss = 0.2489, Accuracy = 0.8922, Test Loss = 0.2394, Test Accuracy = 0.9015
# Processing timestep: 0.93
# Timestep 93.00% : Training Loss = 0.2447, Accuracy = 0.9008, Test Loss = 0.2603, Test Accuracy = 0.8816
# Processing timestep: 0.935
# Timestep 93.50% : Training Loss = 0.2412, Accuracy = 0.8968, Test Loss = 0.2942, Test Accuracy = 0.8655
# Processing timestep: 0.94
# Timestep 94.00% : Training Loss = 0.2133, Accuracy = 0.9101, Test Loss = 0.2456, Test Accuracy = 0.9022
# Processing timestep: 0.945
# Timestep 94.50% : Training Loss = 0.2225, Accuracy = 0.9099, Test Loss = 0.2593, Test Accuracy = 0.8747
# Processing timestep: 0.95
# Timestep 95.00% : Training Loss = 0.2406, Accuracy = 0.8925, Test Loss = 0.2961, Test Accuracy = 0.8747
# Processing timestep: 0.955
# Timestep 95.50% : Training Loss = 0.2382, Accuracy = 0.8913, Test Loss = 0.2363, Test Accuracy = 0.9124
# Processing timestep: 0.96
# Timestep 96.00% : Training Loss = 0.2443, Accuracy = 0.8931, Test Loss = 0.2566, Test Accuracy = 0.8966
# Processing timestep: 0.965
# Timestep 96.50% : Training Loss = 0.2284, Accuracy = 0.9011, Test Loss = 0.2358, Test Accuracy = 0.8805
# Processing timestep: 0.97
# Timestep 97.00% : Training Loss = 0.2368, Accuracy = 0.9070, Test Loss = 0.2382, Test Accuracy = 0.8894
# Processing timestep: 0.975
# Timestep 97.50% : Training Loss = 0.2447, Accuracy = 0.9010, Test Loss = 0.2493, Test Accuracy = 0.8892
# Processing timestep: 0.98
# Timestep 98.00% : Training Loss = 0.2006, Accuracy = 0.9189, Test Loss = 0.2726, Test Accuracy = 0.8523
# Processing timestep: 0.985
# Timestep 98.50% : Training Loss = 0.2152, Accuracy = 0.9109, Test Loss = 0.2196, Test Accuracy = 0.9035
# Processing timestep: 0.99
# Timestep 99.00% : Training Loss = 0.2412, Accuracy = 0.8965, Test Loss = 0.2347, Test Accuracy = 0.8825
# Processing timestep: 0.995
# Timestep 99.50% : Training Loss = 0.2329, Accuracy = 0.9080, Test Loss = 0.2435, Test Accuracy = 0.8889
# Processing timestep: 1.0
# Timestep 100.00% : Training Loss = 0.1752, Accuracy = 0.9399, Test Loss = 0.1653, Test Accuracy = 0.9272

# %%
all_models["xgboost"] = setup_xgboost_models(training_data, None, numeric_features, other_features, features)
# Out:
# Timestep 0.00%(Calibrated): Training Loss = 0.2058, Accuracy = 0.6729, Validation Loss = 0.2131, Validation Accuracy = 0.6556
# Timestep 0.50%(Calibrated): Training Loss = 0.2200, Accuracy = 0.6608, Validation Loss = 0.2170, Validation Accuracy = 0.6531
# Timestep 1.00%(Calibrated): Training Loss = 0.2079, Accuracy = 0.6593, Validation Loss = 0.2065, Validation Accuracy = 0.6718
# Timestep 1.50%(Calibrated): Training Loss = 0.2170, Accuracy = 0.6571, Validation Loss = 0.2135, Validation Accuracy = 0.6719
# Timestep 2.00%(Calibrated): Training Loss = 0.2124, Accuracy = 0.6545, Validation Loss = 0.2180, Validation Accuracy = 0.6442
# Timestep 2.50%(Calibrated): Training Loss = 0.2134, Accuracy = 0.6659, Validation Loss = 0.2117, Validation Accuracy = 0.6682
# Timestep 3.00%(Calibrated): Training Loss = 0.2098, Accuracy = 0.6817, Validation Loss = 0.2164, Validation Accuracy = 0.6635
# Timestep 3.50%(Calibrated): Training Loss = 0.2123, Accuracy = 0.6448, Validation Loss = 0.2203, Validation Accuracy = 0.6332
# Timestep 4.00%(Calibrated): Training Loss = 0.2073, Accuracy = 0.6779, Validation Loss = 0.2079, Validation Accuracy = 0.6743
# Timestep 4.50%(Calibrated): Training Loss = 0.2100, Accuracy = 0.6788, Validation Loss = 0.2058, Validation Accuracy = 0.6745
# Timestep 5.00%(Calibrated): Training Loss = 0.2113, Accuracy = 0.6519, Validation Loss = 0.2117, Validation Accuracy = 0.6490
# Timestep 5.50%(Calibrated): Training Loss = 0.2122, Accuracy = 0.6636, Validation Loss = 0.2187, Validation Accuracy = 0.6476
# Timestep 6.00%(Calibrated): Training Loss = 0.2087, Accuracy = 0.6655, Validation Loss = 0.2073, Validation Accuracy = 0.6779
# Timestep 6.50%(Calibrated): Training Loss = 0.2118, Accuracy = 0.6732, Validation Loss = 0.2168, Validation Accuracy = 0.6521
# Timestep 7.00%(Calibrated): Training Loss = 0.2111, Accuracy = 0.6710, Validation Loss = 0.2132, Validation Accuracy = 0.6609
# Timestep 7.50%(Calibrated): Training Loss = 0.2140, Accuracy = 0.6573, Validation Loss = 0.2111, Validation Accuracy = 0.6534
# Timestep 8.00%(Calibrated): Training Loss = 0.2091, Accuracy = 0.6716, Validation Loss = 0.2052, Validation Accuracy = 0.6851
# Timestep 8.50%(Calibrated): Training Loss = 0.2090, Accuracy = 0.6837, Validation Loss = 0.2096, Validation Accuracy = 0.6513
# Timestep 9.00%(Calibrated): Training Loss = 0.2124, Accuracy = 0.6610, Validation Loss = 0.2082, Validation Accuracy = 0.6622
# Timestep 9.50%(Calibrated): Training Loss = 0.2131, Accuracy = 0.6851, Validation Loss = 0.2057, Validation Accuracy = 0.6688
# Timestep 10.00%(Calibrated): Training Loss = 0.1978, Accuracy = 0.6962, Validation Loss = 0.2053, Validation Accuracy = 0.6753
# Timestep 10.50%(Calibrated): Training Loss = 0.2055, Accuracy = 0.6708, Validation Loss = 0.2028, Validation Accuracy = 0.6594
# Timestep 11.00%(Calibrated): Training Loss = 0.2054, Accuracy = 0.6709, Validation Loss = 0.1974, Validation Accuracy = 0.6850
# Timestep 11.50%(Calibrated): Training Loss = 0.2046, Accuracy = 0.6554, Validation Loss = 0.1854, Validation Accuracy = 0.7033
# Timestep 12.00%(Calibrated): Training Loss = 0.2079, Accuracy = 0.6624, Validation Loss = 0.1928, Validation Accuracy = 0.6992
# Timestep 12.50%(Calibrated): Training Loss = 0.1903, Accuracy = 0.6882, Validation Loss = 0.1972, Validation Accuracy = 0.6737
# Timestep 13.00%(Calibrated): Training Loss = 0.2022, Accuracy = 0.6596, Validation Loss = 0.1982, Validation Accuracy = 0.6908
# Timestep 13.50%(Calibrated): Training Loss = 0.1997, Accuracy = 0.6869, Validation Loss = 0.1915, Validation Accuracy = 0.6926
# Timestep 14.00%(Calibrated): Training Loss = 0.2026, Accuracy = 0.7159, Validation Loss = 0.1911, Validation Accuracy = 0.6741
# Timestep 14.50%(Calibrated): Training Loss = 0.1948, Accuracy = 0.6996, Validation Loss = 0.1869, Validation Accuracy = 0.6891
# Timestep 15.00%(Calibrated): Training Loss = 0.1944, Accuracy = 0.7215, Validation Loss = 0.2000, Validation Accuracy = 0.6960
# Timestep 15.50%(Calibrated): Training Loss = 0.1930, Accuracy = 0.7093, Validation Loss = 0.1957, Validation Accuracy = 0.7032
# Timestep 16.00%(Calibrated): Training Loss = 0.1947, Accuracy = 0.7082, Validation Loss = 0.1989, Validation Accuracy = 0.6871
# Timestep 16.50%(Calibrated): Training Loss = 0.1987, Accuracy = 0.6966, Validation Loss = 0.2048, Validation Accuracy = 0.6637
# Timestep 17.00%(Calibrated): Training Loss = 0.1890, Accuracy = 0.7079, Validation Loss = 0.1921, Validation Accuracy = 0.7093
# Timestep 17.50%(Calibrated): Training Loss = 0.1995, Accuracy = 0.7089, Validation Loss = 0.1994, Validation Accuracy = 0.6681
# Timestep 18.00%(Calibrated): Training Loss = 0.1897, Accuracy = 0.7123, Validation Loss = 0.1856, Validation Accuracy = 0.7261
# Timestep 18.50%(Calibrated): Training Loss = 0.1921, Accuracy = 0.6995, Validation Loss = 0.1839, Validation Accuracy = 0.7155
# Timestep 19.00%(Calibrated): Training Loss = 0.1882, Accuracy = 0.7192, Validation Loss = 0.1796, Validation Accuracy = 0.7283
# Timestep 19.50%(Calibrated): Training Loss = 0.1843, Accuracy = 0.7102, Validation Loss = 0.1924, Validation Accuracy = 0.6938
# Timestep 20.00%(Calibrated): Training Loss = 0.1961, Accuracy = 0.7053, Validation Loss = 0.1813, Validation Accuracy = 0.7121
# Timestep 20.50%(Calibrated): Training Loss = 0.1866, Accuracy = 0.7182, Validation Loss = 0.1837, Validation Accuracy = 0.7174
# Timestep 21.00%(Calibrated): Training Loss = 0.1839, Accuracy = 0.7037, Validation Loss = 0.1875, Validation Accuracy = 0.7058
# Timestep 21.50%(Calibrated): Training Loss = 0.1865, Accuracy = 0.7156, Validation Loss = 0.1825, Validation Accuracy = 0.7244
# Timestep 22.00%(Calibrated): Training Loss = 0.1839, Accuracy = 0.7313, Validation Loss = 0.1829, Validation Accuracy = 0.7106
# Timestep 22.50%(Calibrated): Training Loss = 0.1827, Accuracy = 0.7238, Validation Loss = 0.1835, Validation Accuracy = 0.7263
# Timestep 23.00%(Calibrated): Training Loss = 0.1845, Accuracy = 0.7168, Validation Loss = 0.1852, Validation Accuracy = 0.7140
# Timestep 23.50%(Calibrated): Training Loss = 0.1848, Accuracy = 0.7292, Validation Loss = 0.1760, Validation Accuracy = 0.7296
# Timestep 24.00%(Calibrated): Training Loss = 0.1930, Accuracy = 0.6919, Validation Loss = 0.1859, Validation Accuracy = 0.7022
# Timestep 24.50%(Calibrated): Training Loss = 0.1903, Accuracy = 0.7148, Validation Loss = 0.1829, Validation Accuracy = 0.7370
# Completed 50/201 timesteps
# Timestep 25.00%(Calibrated): Training Loss = 0.1698, Accuracy = 0.7456, Validation Loss = 0.1800, Validation Accuracy = 0.7195
# Timestep 25.50%(Calibrated): Training Loss = 0.2009, Accuracy = 0.6288, Validation Loss = 0.1734, Validation Accuracy = 0.7190
# Timestep 26.00%(Calibrated): Training Loss = 0.1913, Accuracy = 0.7037, Validation Loss = 0.1822, Validation Accuracy = 0.7167
# Timestep 26.50%(Calibrated): Training Loss = 0.1954, Accuracy = 0.7111, Validation Loss = 0.1609, Validation Accuracy = 0.7629
# Timestep 27.00%(Calibrated): Training Loss = 0.1888, Accuracy = 0.7005, Validation Loss = 0.1769, Validation Accuracy = 0.7189
# Timestep 27.50%(Calibrated): Training Loss = 0.1847, Accuracy = 0.7113, Validation Loss = 0.1784, Validation Accuracy = 0.7262
# Timestep 28.00%(Calibrated): Training Loss = 0.1826, Accuracy = 0.7270, Validation Loss = 0.1814, Validation Accuracy = 0.7220
# Timestep 28.50%(Calibrated): Training Loss = 0.1829, Accuracy = 0.7253, Validation Loss = 0.1625, Validation Accuracy = 0.7460
# Timestep 29.00%(Calibrated): Training Loss = 0.1878, Accuracy = 0.7129, Validation Loss = 0.1693, Validation Accuracy = 0.7478
# Timestep 29.50%(Calibrated): Training Loss = 0.1837, Accuracy = 0.7273, Validation Loss = 0.1749, Validation Accuracy = 0.7238
# Timestep 30.00%(Calibrated): Training Loss = 0.1859, Accuracy = 0.7182, Validation Loss = 0.1855, Validation Accuracy = 0.7040
# Timestep 30.50%(Calibrated): Training Loss = 0.1798, Accuracy = 0.7343, Validation Loss = 0.1877, Validation Accuracy = 0.7120
# Timestep 31.00%(Calibrated): Training Loss = 0.1759, Accuracy = 0.7456, Validation Loss = 0.1744, Validation Accuracy = 0.7411
# Timestep 31.50%(Calibrated): Training Loss = 0.1863, Accuracy = 0.7101, Validation Loss = 0.1906, Validation Accuracy = 0.6953
# Timestep 32.00%(Calibrated): Training Loss = 0.1740, Accuracy = 0.7355, Validation Loss = 0.1687, Validation Accuracy = 0.7389
# Timestep 32.50%(Calibrated): Training Loss = 0.1739, Accuracy = 0.7417, Validation Loss = 0.1742, Validation Accuracy = 0.7428
# Timestep 33.00%(Calibrated): Training Loss = 0.1725, Accuracy = 0.7332, Validation Loss = 0.1688, Validation Accuracy = 0.7366
# Timestep 33.50%(Calibrated): Training Loss = 0.1785, Accuracy = 0.7273, Validation Loss = 0.1707, Validation Accuracy = 0.7326
# Timestep 34.00%(Calibrated): Training Loss = 0.1757, Accuracy = 0.7433, Validation Loss = 0.1795, Validation Accuracy = 0.7211
# Timestep 34.50%(Calibrated): Training Loss = 0.1676, Accuracy = 0.7709, Validation Loss = 0.1698, Validation Accuracy = 0.7448
# Timestep 35.00%(Calibrated): Training Loss = 0.1719, Accuracy = 0.7444, Validation Loss = 0.1766, Validation Accuracy = 0.7394
# Timestep 35.50%(Calibrated): Training Loss = 0.1753, Accuracy = 0.7562, Validation Loss = 0.1699, Validation Accuracy = 0.7420
# Timestep 36.00%(Calibrated): Training Loss = 0.1742, Accuracy = 0.7168, Validation Loss = 0.1649, Validation Accuracy = 0.7457
# Timestep 36.50%(Calibrated): Training Loss = 0.1617, Accuracy = 0.7486, Validation Loss = 0.1787, Validation Accuracy = 0.7364
# Timestep 37.00%(Calibrated): Training Loss = 0.1738, Accuracy = 0.7447, Validation Loss = 0.1728, Validation Accuracy = 0.7335
# Timestep 37.50%(Calibrated): Training Loss = 0.1716, Accuracy = 0.7360, Validation Loss = 0.1702, Validation Accuracy = 0.7331
# Timestep 38.00%(Calibrated): Training Loss = 0.1655, Accuracy = 0.7342, Validation Loss = 0.1729, Validation Accuracy = 0.7298
# Timestep 38.50%(Calibrated): Training Loss = 0.1634, Accuracy = 0.7636, Validation Loss = 0.1702, Validation Accuracy = 0.7424
# Timestep 39.00%(Calibrated): Training Loss = 0.1694, Accuracy = 0.7266, Validation Loss = 0.1743, Validation Accuracy = 0.7322
# Timestep 39.50%(Calibrated): Training Loss = 0.1661, Accuracy = 0.7635, Validation Loss = 0.1731, Validation Accuracy = 0.7368
# Timestep 40.00%(Calibrated): Training Loss = 0.1697, Accuracy = 0.7586, Validation Loss = 0.1723, Validation Accuracy = 0.7306
# Timestep 40.50%(Calibrated): Training Loss = 0.1618, Accuracy = 0.7695, Validation Loss = 0.1544, Validation Accuracy = 0.7732
# Timestep 41.00%(Calibrated): Training Loss = 0.1636, Accuracy = 0.7588, Validation Loss = 0.1594, Validation Accuracy = 0.7593
# Timestep 41.50%(Calibrated): Training Loss = 0.1648, Accuracy = 0.7613, Validation Loss = 0.1648, Validation Accuracy = 0.7457
# Timestep 42.00%(Calibrated): Training Loss = 0.1675, Accuracy = 0.7462, Validation Loss = 0.1770, Validation Accuracy = 0.7259
# Timestep 42.50%(Calibrated): Training Loss = 0.1655, Accuracy = 0.7568, Validation Loss = 0.1646, Validation Accuracy = 0.7559
# Timestep 43.00%(Calibrated): Training Loss = 0.1579, Accuracy = 0.7601, Validation Loss = 0.1634, Validation Accuracy = 0.7505
# Timestep 43.50%(Calibrated): Training Loss = 0.1583, Accuracy = 0.7803, Validation Loss = 0.1623, Validation Accuracy = 0.7443
# Timestep 44.00%(Calibrated): Training Loss = 0.1633, Accuracy = 0.7625, Validation Loss = 0.1663, Validation Accuracy = 0.7538
# Timestep 44.50%(Calibrated): Training Loss = 0.1525, Accuracy = 0.7816, Validation Loss = 0.1593, Validation Accuracy = 0.7579
# Timestep 45.00%(Calibrated): Training Loss = 0.1635, Accuracy = 0.7507, Validation Loss = 0.1674, Validation Accuracy = 0.7553
# Timestep 45.50%(Calibrated): Training Loss = 0.1639, Accuracy = 0.7651, Validation Loss = 0.1676, Validation Accuracy = 0.7489
# Timestep 46.00%(Calibrated): Training Loss = 0.1556, Accuracy = 0.7604, Validation Loss = 0.1485, Validation Accuracy = 0.7850
# Timestep 46.50%(Calibrated): Training Loss = 0.1548, Accuracy = 0.7684, Validation Loss = 0.1559, Validation Accuracy = 0.7773
# Timestep 47.00%(Calibrated): Training Loss = 0.1416, Accuracy = 0.7846, Validation Loss = 0.1562, Validation Accuracy = 0.7623
# Timestep 47.50%(Calibrated): Training Loss = 0.1362, Accuracy = 0.7948, Validation Loss = 0.1492, Validation Accuracy = 0.7800
# Timestep 48.00%(Calibrated): Training Loss = 0.1431, Accuracy = 0.7857, Validation Loss = 0.1536, Validation Accuracy = 0.7698
# Timestep 48.50%(Calibrated): Training Loss = 0.1413, Accuracy = 0.7864, Validation Loss = 0.1545, Validation Accuracy = 0.7675
# Timestep 49.00%(Calibrated): Training Loss = 0.1397, Accuracy = 0.8050, Validation Loss = 0.1634, Validation Accuracy = 0.7575
# Timestep 49.50%(Calibrated): Training Loss = 0.1388, Accuracy = 0.7931, Validation Loss = 0.1404, Validation Accuracy = 0.7998
# Completed 100/201 timesteps
# Timestep 50.00%(Calibrated): Training Loss = 0.1325, Accuracy = 0.8111, Validation Loss = 0.1391, Validation Accuracy = 0.8074
# Timestep 50.50%(Calibrated): Training Loss = 0.1449, Accuracy = 0.8034, Validation Loss = 0.1690, Validation Accuracy = 0.7482
# Timestep 51.00%(Calibrated): Training Loss = 0.1426, Accuracy = 0.7911, Validation Loss = 0.1462, Validation Accuracy = 0.7964
# Timestep 51.50%(Calibrated): Training Loss = 0.1355, Accuracy = 0.8103, Validation Loss = 0.1519, Validation Accuracy = 0.7865
# Timestep 52.00%(Calibrated): Training Loss = 0.1476, Accuracy = 0.7898, Validation Loss = 0.1319, Validation Accuracy = 0.8295
# Timestep 52.50%(Calibrated): Training Loss = 0.1322, Accuracy = 0.8128, Validation Loss = 0.1364, Validation Accuracy = 0.8122
# Timestep 53.00%(Calibrated): Training Loss = 0.1454, Accuracy = 0.7977, Validation Loss = 0.1556, Validation Accuracy = 0.7823
# Timestep 53.50%(Calibrated): Training Loss = 0.1267, Accuracy = 0.8329, Validation Loss = 0.1371, Validation Accuracy = 0.8078
# Timestep 54.00%(Calibrated): Training Loss = 0.1361, Accuracy = 0.8116, Validation Loss = 0.1633, Validation Accuracy = 0.7640
# Timestep 54.50%(Calibrated): Training Loss = 0.1413, Accuracy = 0.8014, Validation Loss = 0.1477, Validation Accuracy = 0.7995
# Timestep 55.00%(Calibrated): Training Loss = 0.1297, Accuracy = 0.8186, Validation Loss = 0.1410, Validation Accuracy = 0.8048
# Timestep 55.50%(Calibrated): Training Loss = 0.1361, Accuracy = 0.8157, Validation Loss = 0.1380, Validation Accuracy = 0.8071
# Timestep 56.00%(Calibrated): Training Loss = 0.1349, Accuracy = 0.8184, Validation Loss = 0.1420, Validation Accuracy = 0.7982
# Timestep 56.50%(Calibrated): Training Loss = 0.1346, Accuracy = 0.8126, Validation Loss = 0.1498, Validation Accuracy = 0.7811
# Timestep 57.00%(Calibrated): Training Loss = 0.1342, Accuracy = 0.8177, Validation Loss = 0.1352, Validation Accuracy = 0.8165
# Timestep 57.50%(Calibrated): Training Loss = 0.1338, Accuracy = 0.7793, Validation Loss = 0.1503, Validation Accuracy = 0.7759
# Timestep 58.00%(Calibrated): Training Loss = 0.1368, Accuracy = 0.8031, Validation Loss = 0.1368, Validation Accuracy = 0.8040
# Timestep 58.50%(Calibrated): Training Loss = 0.1351, Accuracy = 0.8168, Validation Loss = 0.1299, Validation Accuracy = 0.8176
# Timestep 59.00%(Calibrated): Training Loss = 0.1370, Accuracy = 0.8131, Validation Loss = 0.1479, Validation Accuracy = 0.7884
# Timestep 59.50%(Calibrated): Training Loss = 0.1334, Accuracy = 0.8023, Validation Loss = 0.1385, Validation Accuracy = 0.8017
# Timestep 60.00%(Calibrated): Training Loss = 0.1317, Accuracy = 0.8071, Validation Loss = 0.1404, Validation Accuracy = 0.8039
# Timestep 60.50%(Calibrated): Training Loss = 0.1283, Accuracy = 0.8204, Validation Loss = 0.1340, Validation Accuracy = 0.8025
# Timestep 61.00%(Calibrated): Training Loss = 0.1310, Accuracy = 0.8139, Validation Loss = 0.1363, Validation Accuracy = 0.8038
# Timestep 61.50%(Calibrated): Training Loss = 0.1237, Accuracy = 0.8245, Validation Loss = 0.1258, Validation Accuracy = 0.8141
# Timestep 62.00%(Calibrated): Training Loss = 0.1308, Accuracy = 0.8132, Validation Loss = 0.1352, Validation Accuracy = 0.8060
# Timestep 62.50%(Calibrated): Training Loss = 0.1317, Accuracy = 0.8201, Validation Loss = 0.1295, Validation Accuracy = 0.8237
# Timestep 63.00%(Calibrated): Training Loss = 0.1249, Accuracy = 0.8292, Validation Loss = 0.1375, Validation Accuracy = 0.8030
# Timestep 63.50%(Calibrated): Training Loss = 0.1302, Accuracy = 0.8075, Validation Loss = 0.1360, Validation Accuracy = 0.8043
# Timestep 64.00%(Calibrated): Training Loss = 0.1260, Accuracy = 0.8260, Validation Loss = 0.1441, Validation Accuracy = 0.7775
# Timestep 64.50%(Calibrated): Training Loss = 0.1321, Accuracy = 0.8137, Validation Loss = 0.1284, Validation Accuracy = 0.8199
# Timestep 65.00%(Calibrated): Training Loss = 0.1307, Accuracy = 0.8223, Validation Loss = 0.1524, Validation Accuracy = 0.7602
# Timestep 65.50%(Calibrated): Training Loss = 0.1183, Accuracy = 0.8368, Validation Loss = 0.1493, Validation Accuracy = 0.7689
# Timestep 66.00%(Calibrated): Training Loss = 0.1204, Accuracy = 0.8400, Validation Loss = 0.1302, Validation Accuracy = 0.8050
# Timestep 66.50%(Calibrated): Training Loss = 0.1184, Accuracy = 0.8356, Validation Loss = 0.1348, Validation Accuracy = 0.8009
# Timestep 67.00%(Calibrated): Training Loss = 0.1208, Accuracy = 0.8387, Validation Loss = 0.1333, Validation Accuracy = 0.8170
# Timestep 67.50%(Calibrated): Training Loss = 0.1199, Accuracy = 0.8404, Validation Loss = 0.1360, Validation Accuracy = 0.7917
# Timestep 68.00%(Calibrated): Training Loss = 0.1211, Accuracy = 0.8284, Validation Loss = 0.1296, Validation Accuracy = 0.8078
# Timestep 68.50%(Calibrated): Training Loss = 0.1146, Accuracy = 0.8400, Validation Loss = 0.1357, Validation Accuracy = 0.8050
# Timestep 69.00%(Calibrated): Training Loss = 0.1232, Accuracy = 0.8364, Validation Loss = 0.1313, Validation Accuracy = 0.7996
# Timestep 69.50%(Calibrated): Training Loss = 0.1116, Accuracy = 0.8442, Validation Loss = 0.1264, Validation Accuracy = 0.8164
# Timestep 70.00%(Calibrated): Training Loss = 0.1221, Accuracy = 0.8058, Validation Loss = 0.1201, Validation Accuracy = 0.8235
# Timestep 70.50%(Calibrated): Training Loss = 0.1130, Accuracy = 0.8447, Validation Loss = 0.1209, Validation Accuracy = 0.8264
# Timestep 71.00%(Calibrated): Training Loss = 0.1125, Accuracy = 0.8309, Validation Loss = 0.1237, Validation Accuracy = 0.8136
# Timestep 71.50%(Calibrated): Training Loss = 0.1191, Accuracy = 0.8361, Validation Loss = 0.1296, Validation Accuracy = 0.8080
# Timestep 72.00%(Calibrated): Training Loss = 0.1135, Accuracy = 0.8244, Validation Loss = 0.1096, Validation Accuracy = 0.8465
# Timestep 72.50%(Calibrated): Training Loss = 0.1123, Accuracy = 0.8382, Validation Loss = 0.1288, Validation Accuracy = 0.8112
# Timestep 73.00%(Calibrated): Training Loss = 0.1059, Accuracy = 0.8543, Validation Loss = 0.1321, Validation Accuracy = 0.8142
# Timestep 73.50%(Calibrated): Training Loss = 0.1114, Accuracy = 0.8596, Validation Loss = 0.1260, Validation Accuracy = 0.8186
# Timestep 74.00%(Calibrated): Training Loss = 0.1078, Accuracy = 0.8554, Validation Loss = 0.1230, Validation Accuracy = 0.8237
# Timestep 74.50%(Calibrated): Training Loss = 0.1116, Accuracy = 0.8537, Validation Loss = 0.1238, Validation Accuracy = 0.8145
# Completed 150/201 timesteps
# Timestep 75.00%(Calibrated): Training Loss = 0.0993, Accuracy = 0.8622, Validation Loss = 0.1179, Validation Accuracy = 0.8352
# Timestep 75.50%(Calibrated): Training Loss = 0.1067, Accuracy = 0.8708, Validation Loss = 0.1161, Validation Accuracy = 0.8333
# Timestep 76.00%(Calibrated): Training Loss = 0.1063, Accuracy = 0.8587, Validation Loss = 0.1146, Validation Accuracy = 0.8320
# Timestep 76.50%(Calibrated): Training Loss = 0.0993, Accuracy = 0.8680, Validation Loss = 0.1208, Validation Accuracy = 0.8289
# Timestep 77.00%(Calibrated): Training Loss = 0.1098, Accuracy = 0.8642, Validation Loss = 0.1305, Validation Accuracy = 0.8071
# Timestep 77.50%(Calibrated): Training Loss = 0.0975, Accuracy = 0.8606, Validation Loss = 0.1100, Validation Accuracy = 0.8453
# Timestep 78.00%(Calibrated): Training Loss = 0.1076, Accuracy = 0.8673, Validation Loss = 0.1296, Validation Accuracy = 0.8081
# Timestep 78.50%(Calibrated): Training Loss = 0.1029, Accuracy = 0.8611, Validation Loss = 0.1238, Validation Accuracy = 0.8219
# Timestep 79.00%(Calibrated): Training Loss = 0.0973, Accuracy = 0.8749, Validation Loss = 0.1010, Validation Accuracy = 0.8543
# Timestep 79.50%(Calibrated): Training Loss = 0.1060, Accuracy = 0.8443, Validation Loss = 0.1116, Validation Accuracy = 0.8393
# Timestep 80.00%(Calibrated): Training Loss = 0.0976, Accuracy = 0.8713, Validation Loss = 0.1028, Validation Accuracy = 0.8620
# Timestep 80.50%(Calibrated): Training Loss = 0.0991, Accuracy = 0.8681, Validation Loss = 0.1081, Validation Accuracy = 0.8482
# Timestep 81.00%(Calibrated): Training Loss = 0.0964, Accuracy = 0.8748, Validation Loss = 0.1188, Validation Accuracy = 0.8333
# Timestep 81.50%(Calibrated): Training Loss = 0.0949, Accuracy = 0.8729, Validation Loss = 0.1127, Validation Accuracy = 0.8330
# Timestep 82.00%(Calibrated): Training Loss = 0.0954, Accuracy = 0.8632, Validation Loss = 0.1058, Validation Accuracy = 0.8299
# Timestep 82.50%(Calibrated): Training Loss = 0.0951, Accuracy = 0.8688, Validation Loss = 0.1125, Validation Accuracy = 0.8467
# Timestep 83.00%(Calibrated): Training Loss = 0.0961, Accuracy = 0.8542, Validation Loss = 0.0988, Validation Accuracy = 0.8507
# Timestep 83.50%(Calibrated): Training Loss = 0.0845, Accuracy = 0.8868, Validation Loss = 0.0881, Validation Accuracy = 0.8832
# Timestep 84.00%(Calibrated): Training Loss = 0.0877, Accuracy = 0.8841, Validation Loss = 0.0952, Validation Accuracy = 0.8593
# Timestep 84.50%(Calibrated): Training Loss = 0.1019, Accuracy = 0.8477, Validation Loss = 0.1059, Validation Accuracy = 0.8491
# Timestep 85.00%(Calibrated): Training Loss = 0.0865, Accuracy = 0.8771, Validation Loss = 0.1032, Validation Accuracy = 0.8526
# Timestep 85.50%(Calibrated): Training Loss = 0.0887, Accuracy = 0.8523, Validation Loss = 0.1151, Validation Accuracy = 0.8380
# Timestep 86.00%(Calibrated): Training Loss = 0.0905, Accuracy = 0.8673, Validation Loss = 0.0931, Validation Accuracy = 0.8568
# Timestep 86.50%(Calibrated): Training Loss = 0.0894, Accuracy = 0.8735, Validation Loss = 0.0825, Validation Accuracy = 0.8887
# Timestep 87.00%(Calibrated): Training Loss = 0.0955, Accuracy = 0.8584, Validation Loss = 0.1083, Validation Accuracy = 0.8380
# Timestep 87.50%(Calibrated): Training Loss = 0.0934, Accuracy = 0.8696, Validation Loss = 0.0732, Validation Accuracy = 0.9029
# Timestep 88.00%(Calibrated): Training Loss = 0.0828, Accuracy = 0.8761, Validation Loss = 0.0979, Validation Accuracy = 0.8608
# Timestep 88.50%(Calibrated): Training Loss = 0.0910, Accuracy = 0.8569, Validation Loss = 0.0967, Validation Accuracy = 0.8571
# Timestep 89.00%(Calibrated): Training Loss = 0.0890, Accuracy = 0.8707, Validation Loss = 0.1018, Validation Accuracy = 0.8468
# Timestep 89.50%(Calibrated): Training Loss = 0.0758, Accuracy = 0.8987, Validation Loss = 0.0827, Validation Accuracy = 0.8871
# Timestep 90.00%(Calibrated): Training Loss = 0.0887, Accuracy = 0.8742, Validation Loss = 0.1026, Validation Accuracy = 0.8517
# Timestep 90.50%(Calibrated): Training Loss = 0.0795, Accuracy = 0.8787, Validation Loss = 0.0871, Validation Accuracy = 0.8740
# Timestep 91.00%(Calibrated): Training Loss = 0.0805, Accuracy = 0.8684, Validation Loss = 0.0798, Validation Accuracy = 0.8780
# Timestep 91.50%(Calibrated): Training Loss = 0.0768, Accuracy = 0.8918, Validation Loss = 0.0848, Validation Accuracy = 0.8857
# Timestep 92.00%(Calibrated): Training Loss = 0.0830, Accuracy = 0.8795, Validation Loss = 0.0857, Validation Accuracy = 0.8827
# Timestep 92.50%(Calibrated): Training Loss = 0.0775, Accuracy = 0.8896, Validation Loss = 0.0723, Validation Accuracy = 0.8965
# Timestep 93.00%(Calibrated): Training Loss = 0.0750, Accuracy = 0.8932, Validation Loss = 0.0729, Validation Accuracy = 0.8989
# Timestep 93.50%(Calibrated): Training Loss = 0.0759, Accuracy = 0.8953, Validation Loss = 0.0883, Validation Accuracy = 0.8825
# Timestep 94.00%(Calibrated): Training Loss = 0.0682, Accuracy = 0.9079, Validation Loss = 0.0806, Validation Accuracy = 0.8889
# Timestep 94.50%(Calibrated): Training Loss = 0.0725, Accuracy = 0.9078, Validation Loss = 0.0761, Validation Accuracy = 0.8838
# Timestep 95.00%(Calibrated): Training Loss = 0.0758, Accuracy = 0.8953, Validation Loss = 0.0907, Validation Accuracy = 0.8734
# Timestep 95.50%(Calibrated): Training Loss = 0.0736, Accuracy = 0.8921, Validation Loss = 0.0793, Validation Accuracy = 0.8814
# Timestep 96.00%(Calibrated): Training Loss = 0.0768, Accuracy = 0.8905, Validation Loss = 0.0882, Validation Accuracy = 0.8742
# Timestep 96.50%(Calibrated): Training Loss = 0.0689, Accuracy = 0.8973, Validation Loss = 0.0733, Validation Accuracy = 0.8967
# Timestep 97.00%(Calibrated): Training Loss = 0.0691, Accuracy = 0.8976, Validation Loss = 0.0791, Validation Accuracy = 0.8778
# Timestep 97.50%(Calibrated): Training Loss = 0.0746, Accuracy = 0.9073, Validation Loss = 0.0801, Validation Accuracy = 0.8766
# Timestep 98.00%(Calibrated): Training Loss = 0.0605, Accuracy = 0.9216, Validation Loss = 0.0717, Validation Accuracy = 0.9020
# Timestep 98.50%(Calibrated): Training Loss = 0.0639, Accuracy = 0.9173, Validation Loss = 0.0617, Validation Accuracy = 0.9082
# Timestep 99.00%(Calibrated): Training Loss = 0.0753, Accuracy = 0.9011, Validation Loss = 0.0579, Validation Accuracy = 0.9231
# Timestep 99.50%(Calibrated): Training Loss = 0.0688, Accuracy = 0.9016, Validation Loss = 0.0620, Validation Accuracy = 0.9127
# Completed 200/201 timesteps
# Timestep 100.00%(Calibrated): Training Loss = 0.0501, Accuracy = 0.9254, Validation Loss = 0.0363, Validation Accuracy = 0.9512
# Completed 201/201 timesteps

# %%
from collections import defaultdict
import numpy as np
print(all_models.keys())
all_models_order = ["xgboost", "nn", "logistic", "lstm"] # Strict ordering of models
# all_models_order = ["xgboost", "nn", "logistic"] # Strict ordering of models

def generate_ensemble_matrix(models, all_models_order, data_dict_seq):
    """Generate predictions from a specific model type on given data"""
    predictions = {}
    # predictions:
        # timestep:
            # "predictions": [model_1_predictions, model_2_predictions, ..., model_n_predictions, 
            # model_1_predictions_seq, model_2_predictions_seq, ..., model_n_predictions_seq],
            # "y_true": y_true
    for timestep in data_dict_seq:
        print(f"Generating predictions for timestep {timestep}")
        # For each entry, take the last array from the "rows" list and pair with its label
        non_sequential_data_for_timestep = [{"rows": entry["rows"][-1], "label": entry["label"]} for entry in data_dict_seq[timestep]]
        X = np.array([row["rows"] for row in non_sequential_data_for_timestep])
        y = np.array([row["label"] for row in non_sequential_data_for_timestep])
        X_seq = np.array([row["rows"] for row in data_dict_seq[timestep]])
        predictions[timestep] = {"predictions": [], "y_true": []}
        for i in range(len(X)):
            predictions[timestep]["predictions"].append(np.array([
                models[model][timestep].predict_proba(np.expand_dims(X_seq[i], axis=0))[:, 1].item() if model == "lstm" else models[model][timestep].predict_proba(np.expand_dims(X[i], axis=0))[:, 1].item()
                for model in all_models_order
            ]))
            predictions[timestep]["y_true"].append(y[i])
        predictions[timestep]["y_true"] = np.array(predictions[timestep]["y_true"])
        predictions[timestep]["predictions"] = np.array(predictions[timestep]["predictions"])
    return predictions

ensemble_matrices = generate_ensemble_matrix(all_models, all_models_order, ensemble_data_seq)
# Out:
# dict_keys(['lstm', 'nn', 'logistic', 'xgboost'])
# Generating predictions for timestep 0.0
# Generating predictions for timestep 0.005
# Generating predictions for timestep 0.01
# Generating predictions for timestep 0.015
# Generating predictions for timestep 0.02
# Generating predictions for timestep 0.025
# Generating predictions for timestep 0.03
# Generating predictions for timestep 0.035
# Generating predictions for timestep 0.04
# Generating predictions for timestep 0.045
# Generating predictions for timestep 0.05
# Generating predictions for timestep 0.055
# Generating predictions for timestep 0.06
# Generating predictions for timestep 0.065
# Generating predictions for timestep 0.07
# Generating predictions for timestep 0.075
# Generating predictions for timestep 0.08
# Generating predictions for timestep 0.085
# Generating predictions for timestep 0.09
# Generating predictions for timestep 0.095
# Generating predictions for timestep 0.1
# Generating predictions for timestep 0.105
# Generating predictions for timestep 0.11
# Generating predictions for timestep 0.115
# Generating predictions for timestep 0.12
# Generating predictions for timestep 0.125
# Generating predictions for timestep 0.13
# Generating predictions for timestep 0.135
# Generating predictions for timestep 0.14
# Generating predictions for timestep 0.145
# Generating predictions for timestep 0.15
# Generating predictions for timestep 0.155
# Generating predictions for timestep 0.16
# Generating predictions for timestep 0.165
# Generating predictions for timestep 0.17
# Generating predictions for timestep 0.175
# Generating predictions for timestep 0.18
# Generating predictions for timestep 0.185
# Generating predictions for timestep 0.19
# Generating predictions for timestep 0.195
# Generating predictions for timestep 0.2
# Generating predictions for timestep 0.205
# Generating predictions for timestep 0.21
# Generating predictions for timestep 0.215
# Generating predictions for timestep 0.22
# Generating predictions for timestep 0.225
# Generating predictions for timestep 0.23
# Generating predictions for timestep 0.235
# Generating predictions for timestep 0.24
# Generating predictions for timestep 0.245
# Generating predictions for timestep 0.25
# Generating predictions for timestep 0.255
# Generating predictions for timestep 0.26
# Generating predictions for timestep 0.265
# Generating predictions for timestep 0.27
# Generating predictions for timestep 0.275
# Generating predictions for timestep 0.28
# Generating predictions for timestep 0.285
# Generating predictions for timestep 0.29
# Generating predictions for timestep 0.295
# Generating predictions for timestep 0.3
# Generating predictions for timestep 0.305
# Generating predictions for timestep 0.31
# Generating predictions for timestep 0.315
# Generating predictions for timestep 0.32
# Generating predictions for timestep 0.325
# Generating predictions for timestep 0.33
# Generating predictions for timestep 0.335
# Generating predictions for timestep 0.34
# Generating predictions for timestep 0.345
# Generating predictions for timestep 0.35
# Generating predictions for timestep 0.355
# Generating predictions for timestep 0.36
# Generating predictions for timestep 0.365
# Generating predictions for timestep 0.37
# Generating predictions for timestep 0.375
# Generating predictions for timestep 0.38
# Generating predictions for timestep 0.385
# Generating predictions for timestep 0.39
# Generating predictions for timestep 0.395
# Generating predictions for timestep 0.4
# Generating predictions for timestep 0.405
# Generating predictions for timestep 0.41
# Generating predictions for timestep 0.415
# Generating predictions for timestep 0.42
# Generating predictions for timestep 0.425
# Generating predictions for timestep 0.43
# Generating predictions for timestep 0.435
# Generating predictions for timestep 0.44
# Generating predictions for timestep 0.445
# Generating predictions for timestep 0.45
# Generating predictions for timestep 0.455
# Generating predictions for timestep 0.46
# Generating predictions for timestep 0.465
# Generating predictions for timestep 0.47
# Generating predictions for timestep 0.475
# Generating predictions for timestep 0.48
# Generating predictions for timestep 0.485
# Generating predictions for timestep 0.49
# Generating predictions for timestep 0.495
# Generating predictions for timestep 0.5
# Generating predictions for timestep 0.505
# Generating predictions for timestep 0.51
# Generating predictions for timestep 0.515
# Generating predictions for timestep 0.52
# Generating predictions for timestep 0.525
# Generating predictions for timestep 0.53
# Generating predictions for timestep 0.535
# Generating predictions for timestep 0.54
# Generating predictions for timestep 0.545
# Generating predictions for timestep 0.55
# Generating predictions for timestep 0.555
# Generating predictions for timestep 0.56
# Generating predictions for timestep 0.565
# Generating predictions for timestep 0.57
# Generating predictions for timestep 0.575
# Generating predictions for timestep 0.58
# Generating predictions for timestep 0.585
# Generating predictions for timestep 0.59
# Generating predictions for timestep 0.595
# Generating predictions for timestep 0.6
# Generating predictions for timestep 0.605
# Generating predictions for timestep 0.61
# Generating predictions for timestep 0.615
# Generating predictions for timestep 0.62
# Generating predictions for timestep 0.625
# Generating predictions for timestep 0.63
# Generating predictions for timestep 0.635
# Generating predictions for timestep 0.64
# Generating predictions for timestep 0.645
# Generating predictions for timestep 0.65
# Generating predictions for timestep 0.655
# Generating predictions for timestep 0.66
# Generating predictions for timestep 0.665
# Generating predictions for timestep 0.67
# Generating predictions for timestep 0.675
# Generating predictions for timestep 0.68
# Generating predictions for timestep 0.685
# Generating predictions for timestep 0.69
# Generating predictions for timestep 0.695
# Generating predictions for timestep 0.7
# Generating predictions for timestep 0.705
# Generating predictions for timestep 0.71
# Generating predictions for timestep 0.715
# Generating predictions for timestep 0.72
# Generating predictions for timestep 0.725
# Generating predictions for timestep 0.73
# Generating predictions for timestep 0.735
# Generating predictions for timestep 0.74
# Generating predictions for timestep 0.745
# Generating predictions for timestep 0.75
# Generating predictions for timestep 0.755
# Generating predictions for timestep 0.76
# Generating predictions for timestep 0.765
# Generating predictions for timestep 0.77
# Generating predictions for timestep 0.775
# Generating predictions for timestep 0.78
# Generating predictions for timestep 0.785
# Generating predictions for timestep 0.79
# Generating predictions for timestep 0.795
# Generating predictions for timestep 0.8
# Generating predictions for timestep 0.805
# Generating predictions for timestep 0.81
# Generating predictions for timestep 0.815
# Generating predictions for timestep 0.82
# Generating predictions for timestep 0.825
# Generating predictions for timestep 0.83
# Generating predictions for timestep 0.835
# Generating predictions for timestep 0.84
# Generating predictions for timestep 0.845
# Generating predictions for timestep 0.85
# Generating predictions for timestep 0.855
# Generating predictions for timestep 0.86
# Generating predictions for timestep 0.865
# Generating predictions for timestep 0.87
# Generating predictions for timestep 0.875
# Generating predictions for timestep 0.88
# Generating predictions for timestep 0.885
# Generating predictions for timestep 0.89
# Generating predictions for timestep 0.895
# Generating predictions for timestep 0.9
# Generating predictions for timestep 0.905
# Generating predictions for timestep 0.91
# Generating predictions for timestep 0.915
# Generating predictions for timestep 0.92
# Generating predictions for timestep 0.925
# Generating predictions for timestep 0.93
# Generating predictions for timestep 0.935
# Generating predictions for timestep 0.94
# Generating predictions for timestep 0.945
# Generating predictions for timestep 0.95
# Generating predictions for timestep 0.955
# Generating predictions for timestep 0.96
# Generating predictions for timestep 0.965
# Generating predictions for timestep 0.97
# Generating predictions for timestep 0.975
# Generating predictions for timestep 0.98
# Generating predictions for timestep 0.985
# Generating predictions for timestep 0.99
# Generating predictions for timestep 0.995
# Generating predictions for timestep 1.0

# %%
class LogisticRegressionMetaModel:
    def __init__(self):
        self.meta_model = LogisticRegression(random_state=42, max_iter=1000)

    def fit(self, X, y, X_val=None, y_val=None):
        self.meta_model.fit(X, y)
        if X_val is not None and y_val is not None:
            self.meta_model.fit(X_val, y_val)
    def predict(self, X):
        return 1 if self.meta_model.predict_proba(X)[:, 1] > 0.5 else 0
    def predict_proba(self, X):
        return self.meta_model.predict_proba(X)

import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.base import BaseEstimator, ClassifierMixin

class SimpleMetaNN(nn.Module):
    def __init__(self, input_dim):
        super(SimpleMetaNN, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 8),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(8, 1),
            nn.Sigmoid()
        )
    def forward(self, x):
        return self.net(x)

class NeuralNetworkMetaModel(BaseEstimator, ClassifierMixin):
    def __init__(self, input_dim=None, lr=0.01, epochs=30, batch_size=32, device=None):
        self.input_dim = input_dim
        self.lr = lr
        self.epochs = epochs
        self.batch_size = batch_size
        self.device = device or ("cuda" if torch.cuda.is_available() else "cpu")
        self.model = None

    def fit(self, X, y, X_val=None, y_val=None):
        if self.input_dim is None:
            self.input_dim = X.shape[1]
        self.model = SimpleMetaNN(self.input_dim).to(self.device)
        criterion = nn.BCELoss()
        optimizer = optim.Adam(self.model.parameters(), lr=self.lr)
        X_tensor = torch.tensor(X, dtype=torch.float32).to(self.device)
        y_tensor = torch.tensor(y, dtype=torch.float32).view(-1, 1).to(self.device)
        dataset = torch.utils.data.TensorDataset(X_tensor, y_tensor)
        loader = torch.utils.data.DataLoader(dataset, batch_size=self.batch_size, shuffle=True)
        self.model.train()
        for epoch in range(self.epochs):
            for xb, yb in loader:
                optimizer.zero_grad()
                preds = self.model(xb)
                loss = criterion(preds, yb)
                loss.backward()
                optimizer.step()
        return self

    def predict(self, X):
        self.model.eval()
        X_tensor = torch.tensor(X, dtype=torch.float32).to(self.device)
        with torch.no_grad():
            probs = self.model(X_tensor).cpu().numpy().flatten()
        return (probs > 0.5).astype(int)

    def predict_proba(self, X):
        self.model.eval()
        X_tensor = torch.tensor(X, dtype=torch.float32).to(self.device)
        with torch.no_grad():
            probs = self.model(X_tensor).cpu().numpy().flatten()
        return np.column_stack([1 - probs, probs])

# %%
def setup_meta_models(ensemble_matrices, all_models, all_models_order, strategy='meta_model', meta_model=None):
    models = {}
    for timestep in ensemble_matrices:
        print(f"Training meta-model for timestep {timestep}")
        ensemble_matrix = ensemble_matrices[timestep]
        x_train = ensemble_matrix["predictions"]
        y_train = ensemble_matrix["y_true"]
        all_models_for_timestep = {model_name: all_models[model_name][timestep] for model_name in all_models_order}
        models[timestep] = EnsemblePredictor(all_models_for_timestep, all_models_order, features, strategy, meta_model)
        models[timestep].train_ensemble(x_train, y_train, objective='brier')
    return models

ensemble_models = setup_meta_models(ensemble_matrices, all_models, all_models_order, strategy='weighted_average', meta_model=LogisticRegressionMetaModel())
# Out:
# Training meta-model for timestep 0.0
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2591, 'nn': 0.1161, 'logistic': 0.6248, 'lstm': 0.0} (score: 0.230990)
# Training meta-model for timestep 0.005
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1033, 'nn': 0.0743, 'logistic': 0.5493, 'lstm': 0.2732} (score: 0.241636)
# Training meta-model for timestep 0.01
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2033, 'nn': 0.1197, 'logistic': 0.5599, 'lstm': 0.1172} (score: 0.229940)
# Training meta-model for timestep 0.015
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.067, 'logistic': 0.649, 'lstm': 0.284} (score: 0.226852)
# Training meta-model for timestep 0.02
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0574, 'nn': 0.0656, 'logistic': 0.0, 'lstm': 0.8769} (score: 0.228171)
# Training meta-model for timestep 0.025
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.5361, 'nn': 0.0, 'logistic': 0.3542, 'lstm': 0.1097} (score: 0.228086)
# Training meta-model for timestep 0.03
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.7375, 'nn': 0.0009, 'logistic': 0.2616, 'lstm': 0.0} (score: 0.221127)
# Training meta-model for timestep 0.035
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1205, 'nn': 0.0, 'logistic': 0.8795, 'lstm': 0.0} (score: 0.227627)
# Training meta-model for timestep 0.04
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.4725, 'nn': 0.0, 'logistic': 0.0, 'lstm': 0.5275} (score: 0.230611)
# Training meta-model for timestep 0.045
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0865, 'nn': 0.1524, 'logistic': 0.1817, 'lstm': 0.5793} (score: 0.234420)
# Training meta-model for timestep 0.05
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.4103, 'nn': 0.0, 'logistic': 0.2904, 'lstm': 0.2993} (score: 0.227633)
# Training meta-model for timestep 0.055
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2492, 'nn': 0.0, 'logistic': 0.4972, 'lstm': 0.2537} (score: 0.218559)
# Training meta-model for timestep 0.06
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0235, 'nn': 0.313, 'logistic': 0.0, 'lstm': 0.6635} (score: 0.229486)
# Training meta-model for timestep 0.065
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2878, 'nn': 0.0, 'logistic': 0.0, 'lstm': 0.7122} (score: 0.226978)
# Training meta-model for timestep 0.07
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0945, 'nn': 0.0019, 'logistic': 0.9036, 'lstm': 0.0} (score: 0.228035)
# Training meta-model for timestep 0.075
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2283, 'nn': 0.4436, 'logistic': 0.3281, 'lstm': 0.0} (score: 0.223200)
# Training meta-model for timestep 0.08
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.045, 'nn': 0.0, 'logistic': 0.7629, 'lstm': 0.1921} (score: 0.220047)
# Training meta-model for timestep 0.085
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1786, 'nn': 0.1427, 'logistic': 0.6653, 'lstm': 0.0135} (score: 0.216053)
# Training meta-model for timestep 0.09
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2601, 'nn': 0.3144, 'logistic': 0.4255, 'lstm': 0.0} (score: 0.219783)
# Training meta-model for timestep 0.095
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2093, 'nn': 0.0641, 'logistic': 0.7265, 'lstm': 0.0} (score: 0.204106)
# Training meta-model for timestep 0.1
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.0103, 'logistic': 0.6436, 'lstm': 0.346} (score: 0.219374)
# Training meta-model for timestep 0.105
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1688, 'nn': 0.0, 'logistic': 0.2308, 'lstm': 0.6004} (score: 0.211864)
# Training meta-model for timestep 0.11
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0226, 'nn': 0.3778, 'logistic': 0.3132, 'lstm': 0.2864} (score: 0.221881)
# Training meta-model for timestep 0.115
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1899, 'nn': 0.0907, 'logistic': 0.3578, 'lstm': 0.3615} (score: 0.215326)
# Training meta-model for timestep 0.12
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.0246, 'logistic': 0.5954, 'lstm': 0.3801} (score: 0.215479)
# Training meta-model for timestep 0.125
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.5025, 'nn': 0.0, 'logistic': 0.3147, 'lstm': 0.1828} (score: 0.230153)
# Training meta-model for timestep 0.13
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1932, 'nn': 0.101, 'logistic': 0.424, 'lstm': 0.2817} (score: 0.212750)
# Training meta-model for timestep 0.135
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0195, 'nn': 0.3334, 'logistic': 0.2805, 'lstm': 0.3666} (score: 0.221050)
# Training meta-model for timestep 0.14
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.0, 'logistic': 0.0, 'lstm': 1.0} (score: 0.215336)
# Training meta-model for timestep 0.145
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.0, 'logistic': 0.7222, 'lstm': 0.2778} (score: 0.221455)
# Training meta-model for timestep 0.15
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.0, 'logistic': 1.0, 'lstm': 0.0} (score: 0.211342)
# Training meta-model for timestep 0.155
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2703, 'nn': 0.0, 'logistic': 0.4796, 'lstm': 0.2501} (score: 0.197339)
# Training meta-model for timestep 0.16
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1772, 'nn': 0.2505, 'logistic': 0.5723, 'lstm': 0.0} (score: 0.209573)
# Training meta-model for timestep 0.165
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2296, 'nn': 0.0, 'logistic': 0.6754, 'lstm': 0.0949} (score: 0.218112)
# Training meta-model for timestep 0.17
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.0371, 'logistic': 0.5702, 'lstm': 0.3927} (score: 0.217708)
# Training meta-model for timestep 0.175
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.0, 'logistic': 0.3977, 'lstm': 0.6023} (score: 0.217680)
# Training meta-model for timestep 0.18
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1032, 'nn': 0.0, 'logistic': 0.7615, 'lstm': 0.1353} (score: 0.207403)
# Training meta-model for timestep 0.185
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1754, 'nn': 0.0, 'logistic': 0.6563, 'lstm': 0.1683} (score: 0.214918)
# Training meta-model for timestep 0.19
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.3142, 'nn': 0.0, 'logistic': 0.3168, 'lstm': 0.3691} (score: 0.219725)
# Training meta-model for timestep 0.195
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.079, 'nn': 0.0, 'logistic': 0.7953, 'lstm': 0.1257} (score: 0.201662)
# Training meta-model for timestep 0.2
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1752, 'nn': 0.0, 'logistic': 0.8248, 'lstm': 0.0} (score: 0.207501)
# Training meta-model for timestep 0.205
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.0, 'logistic': 0.8129, 'lstm': 0.1871} (score: 0.214290)
# Training meta-model for timestep 0.21
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.0, 'logistic': 0.5035, 'lstm': 0.4965} (score: 0.212593)
# Training meta-model for timestep 0.215
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1056, 'nn': 0.0, 'logistic': 0.8944, 'lstm': 0.0} (score: 0.214169)
# Training meta-model for timestep 0.22
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2105, 'nn': 0.0, 'logistic': 0.7058, 'lstm': 0.0836} (score: 0.209310)
# Training meta-model for timestep 0.225
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.0006, 'logistic': 0.4819, 'lstm': 0.5174} (score: 0.200357)
# Training meta-model for timestep 0.23
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2367, 'nn': 0.516, 'logistic': 0.1273, 'lstm': 0.1199} (score: 0.222405)
# Training meta-model for timestep 0.235
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.164, 'nn': 0.0, 'logistic': 0.6043, 'lstm': 0.2317} (score: 0.201599)
# Training meta-model for timestep 0.24
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.5191, 'nn': 0.1358, 'logistic': 0.1863, 'lstm': 0.1587} (score: 0.204872)
# Training meta-model for timestep 0.245
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.294, 'nn': 0.0, 'logistic': 0.706, 'lstm': 0.0} (score: 0.213582)
# Training meta-model for timestep 0.25
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1184, 'nn': 0.0, 'logistic': 0.8816, 'lstm': 0.0} (score: 0.211758)
# Training meta-model for timestep 0.255
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.3307, 'nn': 0.0, 'logistic': 0.0, 'lstm': 0.6693} (score: 0.198793)
# Training meta-model for timestep 0.26
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0675, 'nn': 0.0, 'logistic': 0.8697, 'lstm': 0.0628} (score: 0.206091)
# Training meta-model for timestep 0.265
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.4256, 'nn': 0.0, 'logistic': 0.2783, 'lstm': 0.2961} (score: 0.214393)
# Training meta-model for timestep 0.27
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2114, 'nn': 0.0, 'logistic': 0.3066, 'lstm': 0.4821} (score: 0.207089)
# Training meta-model for timestep 0.275
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1181, 'nn': 0.0, 'logistic': 0.4747, 'lstm': 0.4072} (score: 0.202840)
# Training meta-model for timestep 0.28
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1885, 'nn': 0.0, 'logistic': 0.7275, 'lstm': 0.084} (score: 0.205637)
# Training meta-model for timestep 0.285
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2392, 'nn': 0.0, 'logistic': 0.7608, 'lstm': 0.0} (score: 0.197598)
# Training meta-model for timestep 0.29
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.045, 'nn': 0.0, 'logistic': 0.4546, 'lstm': 0.5004} (score: 0.214875)
# Training meta-model for timestep 0.295
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.0, 'logistic': 1.0, 'lstm': 0.0} (score: 0.215310)
# Training meta-model for timestep 0.3
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0414, 'nn': 0.0, 'logistic': 0.5392, 'lstm': 0.4194} (score: 0.198984)
# Training meta-model for timestep 0.305
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.4037, 'nn': 0.2971, 'logistic': 0.0783, 'lstm': 0.221} (score: 0.210327)
# Training meta-model for timestep 0.31
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2538, 'nn': 0.0617, 'logistic': 0.268, 'lstm': 0.4165} (score: 0.193167)
# Training meta-model for timestep 0.315
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.0, 'logistic': 1.0, 'lstm': 0.0} (score: 0.197516)
# Training meta-model for timestep 0.32
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.4824, 'nn': 0.1681, 'logistic': 0.1228, 'lstm': 0.2267} (score: 0.216947)
# Training meta-model for timestep 0.325
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0333, 'nn': 0.1942, 'logistic': 0.7725, 'lstm': 0.0} (score: 0.211469)
# Training meta-model for timestep 0.33
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0286, 'nn': 0.0, 'logistic': 0.9714, 'lstm': 0.0} (score: 0.212169)
# Training meta-model for timestep 0.335
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0727, 'nn': 0.0, 'logistic': 0.9273, 'lstm': 0.0} (score: 0.191495)
# Training meta-model for timestep 0.34
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.0, 'logistic': 0.4715, 'lstm': 0.5285} (score: 0.186127)
# Training meta-model for timestep 0.345
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2767, 'nn': 0.0, 'logistic': 0.4659, 'lstm': 0.2574} (score: 0.205808)
# Training meta-model for timestep 0.35
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2525, 'nn': 0.0297, 'logistic': 0.4621, 'lstm': 0.2556} (score: 0.207406)
# Training meta-model for timestep 0.355
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1343, 'nn': 0.1875, 'logistic': 0.5018, 'lstm': 0.1764} (score: 0.199459)
# Training meta-model for timestep 0.36
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.0, 'logistic': 0.9552, 'lstm': 0.0448} (score: 0.194794)
# Training meta-model for timestep 0.365
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1107, 'nn': 0.0, 'logistic': 0.3262, 'lstm': 0.5632} (score: 0.205037)
# Training meta-model for timestep 0.37
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.1104, 'logistic': 0.8896, 'lstm': 0.0} (score: 0.202995)
# Training meta-model for timestep 0.375
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.0, 'logistic': 0.7158, 'lstm': 0.2842} (score: 0.195113)
# Training meta-model for timestep 0.38
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1563, 'nn': 0.0, 'logistic': 0.8437, 'lstm': 0.0} (score: 0.190456)
# Training meta-model for timestep 0.385
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.051, 'nn': 0.0, 'logistic': 0.1185, 'lstm': 0.8305} (score: 0.202541)
# Training meta-model for timestep 0.39
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1959, 'nn': 0.0, 'logistic': 0.3874, 'lstm': 0.4167} (score: 0.197659)
# Training meta-model for timestep 0.395
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0626, 'nn': 0.0, 'logistic': 0.3803, 'lstm': 0.5571} (score: 0.203102)
# Training meta-model for timestep 0.4
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.0452, 'logistic': 0.3621, 'lstm': 0.5927} (score: 0.192302)
# Training meta-model for timestep 0.405
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1456, 'nn': 0.8537, 'logistic': 0.0006, 'lstm': 0.0} (score: 0.187215)
# Training meta-model for timestep 0.41
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.5349, 'logistic': 0.2825, 'lstm': 0.1826} (score: 0.212221)
# Training meta-model for timestep 0.415
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0874, 'nn': 0.2, 'logistic': 0.6689, 'lstm': 0.0436} (score: 0.198255)
# Training meta-model for timestep 0.42
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.3007, 'logistic': 0.3104, 'lstm': 0.3889} (score: 0.201500)
# Training meta-model for timestep 0.425
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.0, 'logistic': 0.6824, 'lstm': 0.3176} (score: 0.190146)
# Training meta-model for timestep 0.43
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.0515, 'logistic': 0.4748, 'lstm': 0.4737} (score: 0.194365)
# Training meta-model for timestep 0.435
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.0, 'logistic': 0.9075, 'lstm': 0.0925} (score: 0.189739)
# Training meta-model for timestep 0.44
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.3042, 'nn': 0.0984, 'logistic': 0.2869, 'lstm': 0.3106} (score: 0.181452)
# Training meta-model for timestep 0.445
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1981, 'nn': 0.0092, 'logistic': 0.7927, 'lstm': 0.0} (score: 0.205446)
# Training meta-model for timestep 0.45
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1284, 'nn': 0.0234, 'logistic': 0.5071, 'lstm': 0.3411} (score: 0.182266)
# Training meta-model for timestep 0.455
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.069, 'nn': 0.0784, 'logistic': 0.4213, 'lstm': 0.4313} (score: 0.189377)
# Training meta-model for timestep 0.46
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2389, 'nn': 0.4013, 'logistic': 0.1425, 'lstm': 0.2172} (score: 0.179859)
# Training meta-model for timestep 0.465
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1148, 'nn': 0.0018, 'logistic': 0.5414, 'lstm': 0.342} (score: 0.182817)
# Training meta-model for timestep 0.47
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.5822, 'nn': 0.0, 'logistic': 0.2689, 'lstm': 0.1489} (score: 0.185636)
# Training meta-model for timestep 0.475
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1779, 'nn': 0.0, 'logistic': 0.8028, 'lstm': 0.0193} (score: 0.194918)
# Training meta-model for timestep 0.48
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0101, 'nn': 0.0, 'logistic': 0.7097, 'lstm': 0.2802} (score: 0.173688)
# Training meta-model for timestep 0.485
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.6157, 'nn': 0.0, 'logistic': 0.3843, 'lstm': 0.0} (score: 0.172679)
# Training meta-model for timestep 0.49
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.3573, 'nn': 0.0, 'logistic': 0.4822, 'lstm': 0.1605} (score: 0.176957)
# Training meta-model for timestep 0.495
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0033, 'nn': 0.0, 'logistic': 0.7716, 'lstm': 0.2251} (score: 0.173894)
# Training meta-model for timestep 0.5
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0556, 'nn': 0.0, 'logistic': 0.9444, 'lstm': 0.0} (score: 0.177558)
# Training meta-model for timestep 0.505
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0397, 'nn': 0.4792, 'logistic': 0.1765, 'lstm': 0.3046} (score: 0.168633)
# Training meta-model for timestep 0.51
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2405, 'nn': 0.0, 'logistic': 0.7595, 'lstm': 0.0} (score: 0.167707)
# Training meta-model for timestep 0.515
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.5174, 'nn': 0.4826, 'logistic': 0.0, 'lstm': 0.0} (score: 0.181227)
# Training meta-model for timestep 0.52
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0293, 'nn': 0.0, 'logistic': 0.9707, 'lstm': 0.0} (score: 0.180793)
# Training meta-model for timestep 0.525
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.6138, 'nn': 0.0414, 'logistic': 0.3448, 'lstm': 0.0} (score: 0.173483)
# Training meta-model for timestep 0.53
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.29, 'nn': 0.0, 'logistic': 0.71, 'lstm': 0.0} (score: 0.174074)
# Training meta-model for timestep 0.535
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.3009, 'nn': 0.0, 'logistic': 0.6991, 'lstm': 0.0} (score: 0.174723)
# Training meta-model for timestep 0.54
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.3637, 'nn': 0.0, 'logistic': 0.6363, 'lstm': 0.0} (score: 0.163905)
# Training meta-model for timestep 0.545
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2687, 'nn': 0.0, 'logistic': 0.7313, 'lstm': 0.0} (score: 0.184746)
# Training meta-model for timestep 0.55
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.4316, 'nn': 0.0, 'logistic': 0.5684, 'lstm': 0.0} (score: 0.175820)
# Training meta-model for timestep 0.555
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.4101, 'nn': 0.0, 'logistic': 0.5899, 'lstm': 0.0} (score: 0.170704)
# Training meta-model for timestep 0.56
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.32, 'nn': 0.0, 'logistic': 0.68, 'lstm': 0.0} (score: 0.156729)
# Training meta-model for timestep 0.565
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.4533, 'nn': 0.0, 'logistic': 0.5467, 'lstm': 0.0} (score: 0.163475)
# Training meta-model for timestep 0.57
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.0392, 'logistic': 0.9608, 'lstm': 0.0} (score: 0.168820)
# Training meta-model for timestep 0.575
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1609, 'nn': 0.0614, 'logistic': 0.7648, 'lstm': 0.0129} (score: 0.179179)
# Training meta-model for timestep 0.58
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0743, 'nn': 0.0, 'logistic': 0.9257, 'lstm': 0.0} (score: 0.165315)
# Training meta-model for timestep 0.585
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0167, 'nn': 0.0, 'logistic': 0.9833, 'lstm': 0.0} (score: 0.165745)
# Training meta-model for timestep 0.59
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.6868, 'nn': 0.0425, 'logistic': 0.2707, 'lstm': 0.0} (score: 0.174371)
# Training meta-model for timestep 0.595
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2372, 'nn': 0.012, 'logistic': 0.7508, 'lstm': 0.0} (score: 0.160127)
# Training meta-model for timestep 0.6
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.3686, 'nn': 0.2705, 'logistic': 0.1769, 'lstm': 0.1839} (score: 0.175954)
# Training meta-model for timestep 0.605
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.3589, 'nn': 0.2081, 'logistic': 0.433, 'lstm': 0.0} (score: 0.166271)
# Training meta-model for timestep 0.61
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.5739, 'nn': 0.0, 'logistic': 0.3708, 'lstm': 0.0553} (score: 0.165409)
# Training meta-model for timestep 0.615
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.0, 'logistic': 1.0, 'lstm': 0.0} (score: 0.162924)
# Training meta-model for timestep 0.62
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.399, 'nn': 0.0, 'logistic': 0.601, 'lstm': 0.0} (score: 0.168053)
# Training meta-model for timestep 0.625
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0158, 'nn': 0.0, 'logistic': 0.9842, 'lstm': 0.0} (score: 0.158007)
# Training meta-model for timestep 0.63
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2634, 'nn': 0.0181, 'logistic': 0.5478, 'lstm': 0.1707} (score: 0.155665)
# Training meta-model for timestep 0.635
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.5749, 'nn': 0.0579, 'logistic': 0.3672, 'lstm': 0.0} (score: 0.162150)
# Training meta-model for timestep 0.64
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.4202, 'nn': 0.1692, 'logistic': 0.4106, 'lstm': 0.0} (score: 0.158556)
# Training meta-model for timestep 0.645
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0936, 'nn': 0.2686, 'logistic': 0.5385, 'lstm': 0.0993} (score: 0.168434)
# Training meta-model for timestep 0.65
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2542, 'nn': 0.0665, 'logistic': 0.5478, 'lstm': 0.1316} (score: 0.158137)
# Training meta-model for timestep 0.655
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.4633, 'nn': 0.095, 'logistic': 0.0901, 'lstm': 0.3516} (score: 0.151928)
# Training meta-model for timestep 0.66
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2905, 'nn': 0.0, 'logistic': 0.7095, 'lstm': 0.0} (score: 0.164881)
# Training meta-model for timestep 0.665
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.633, 'nn': 0.0202, 'logistic': 0.2976, 'lstm': 0.0492} (score: 0.142678)
# Training meta-model for timestep 0.67
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1906, 'nn': 0.0, 'logistic': 0.316, 'lstm': 0.4934} (score: 0.153659)
# Training meta-model for timestep 0.675
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.3157, 'nn': 0.0184, 'logistic': 0.1109, 'lstm': 0.5549} (score: 0.172449)
# Training meta-model for timestep 0.68
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.291, 'nn': 0.1762, 'logistic': 0.2898, 'lstm': 0.2429} (score: 0.166111)
# Training meta-model for timestep 0.685
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.5733, 'nn': 0.0, 'logistic': 0.4267, 'lstm': 0.0} (score: 0.151325)
# Training meta-model for timestep 0.69
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2351, 'nn': 0.3014, 'logistic': 0.4635, 'lstm': 0.0} (score: 0.144376)
# Training meta-model for timestep 0.695
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2949, 'nn': 0.0951, 'logistic': 0.6099, 'lstm': 0.0} (score: 0.150564)
# Training meta-model for timestep 0.7
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.2688, 'logistic': 0.7312, 'lstm': 0.0} (score: 0.151202)
# Training meta-model for timestep 0.705
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0778, 'nn': 0.0, 'logistic': 0.7654, 'lstm': 0.1568} (score: 0.151374)
# Training meta-model for timestep 0.71
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.6818, 'nn': 0.0, 'logistic': 0.0155, 'lstm': 0.3027} (score: 0.149791)
# Training meta-model for timestep 0.715
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.3819, 'nn': 0.0079, 'logistic': 0.5982, 'lstm': 0.0121} (score: 0.169006)
# Training meta-model for timestep 0.72
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.239, 'nn': 0.2692, 'logistic': 0.0, 'lstm': 0.4919} (score: 0.146470)
# Training meta-model for timestep 0.725
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1439, 'nn': 0.3964, 'logistic': 0.4289, 'lstm': 0.0308} (score: 0.147009)
# Training meta-model for timestep 0.73
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0759, 'nn': 0.0, 'logistic': 0.5304, 'lstm': 0.3938} (score: 0.147825)
# Training meta-model for timestep 0.735
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.3951, 'nn': 0.4322, 'logistic': 0.1518, 'lstm': 0.0209} (score: 0.151737)
# Training meta-model for timestep 0.74
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.3253, 'nn': 0.0, 'logistic': 0.3125, 'lstm': 0.3622} (score: 0.140255)
# Training meta-model for timestep 0.745
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.5962, 'nn': 0.0337, 'logistic': 0.0, 'lstm': 0.3701} (score: 0.152037)
# Training meta-model for timestep 0.75
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.3503, 'nn': 0.0, 'logistic': 0.3335, 'lstm': 0.3162} (score: 0.153665)
# Training meta-model for timestep 0.755
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2993, 'nn': 0.2092, 'logistic': 0.4915, 'lstm': 0.0} (score: 0.147434)
# Training meta-model for timestep 0.76
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0109, 'nn': 0.1531, 'logistic': 0.2503, 'lstm': 0.5857} (score: 0.147614)
# Training meta-model for timestep 0.765
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.5044, 'nn': 0.0, 'logistic': 0.2827, 'lstm': 0.2129} (score: 0.124804)
# Training meta-model for timestep 0.77
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.3104, 'nn': 0.0, 'logistic': 0.1475, 'lstm': 0.5421} (score: 0.151786)
# Training meta-model for timestep 0.775
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.614, 'nn': 0.386, 'logistic': 0.0, 'lstm': 0.0} (score: 0.145192)
# Training meta-model for timestep 0.78
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1942, 'nn': 0.1868, 'logistic': 0.45, 'lstm': 0.169} (score: 0.140523)
# Training meta-model for timestep 0.785
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0886, 'nn': 0.0358, 'logistic': 0.7396, 'lstm': 0.136} (score: 0.130111)
# Training meta-model for timestep 0.79
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.3845, 'nn': 0.0, 'logistic': 0.3083, 'lstm': 0.3072} (score: 0.125611)
# Training meta-model for timestep 0.795
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2988, 'nn': 0.2089, 'logistic': 0.4922, 'lstm': 0.0} (score: 0.145369)
# Training meta-model for timestep 0.8
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.2364, 'logistic': 0.423, 'lstm': 0.3406} (score: 0.128686)
# Training meta-model for timestep 0.805
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1396, 'nn': 0.1213, 'logistic': 0.5095, 'lstm': 0.2296} (score: 0.135641)
# Training meta-model for timestep 0.81
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.3354, 'nn': 0.1993, 'logistic': 0.266, 'lstm': 0.1992} (score: 0.135917)
# Training meta-model for timestep 0.815
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0185, 'nn': 0.0125, 'logistic': 0.7646, 'lstm': 0.2044} (score: 0.130383)
# Training meta-model for timestep 0.82
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1215, 'nn': 0.0278, 'logistic': 0.0819, 'lstm': 0.7689} (score: 0.144893)
# Training meta-model for timestep 0.825
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0773, 'nn': 0.0, 'logistic': 0.9227, 'lstm': 0.0} (score: 0.133050)
# Training meta-model for timestep 0.83
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0782, 'nn': 0.1475, 'logistic': 0.7743, 'lstm': 0.0} (score: 0.129637)
# Training meta-model for timestep 0.835
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0251, 'nn': 0.4599, 'logistic': 0.515, 'lstm': 0.0} (score: 0.137227)
# Training meta-model for timestep 0.84
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2816, 'nn': 0.0, 'logistic': 0.5445, 'lstm': 0.1739} (score: 0.129667)
# Training meta-model for timestep 0.845
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.063, 'nn': 0.0, 'logistic': 0.6465, 'lstm': 0.2905} (score: 0.115273)
# Training meta-model for timestep 0.85
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2921, 'nn': 0.0, 'logistic': 0.7079, 'lstm': 0.0} (score: 0.132511)
# Training meta-model for timestep 0.855
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2857, 'nn': 0.0, 'logistic': 0.7143, 'lstm': 0.0} (score: 0.133581)
# Training meta-model for timestep 0.86
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.1477, 'logistic': 0.8198, 'lstm': 0.0325} (score: 0.123536)
# Training meta-model for timestep 0.865
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0054, 'nn': 0.072, 'logistic': 0.9226, 'lstm': 0.0} (score: 0.122727)
# Training meta-model for timestep 0.87
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1186, 'nn': 0.0, 'logistic': 0.8814, 'lstm': 0.0} (score: 0.123979)
# Training meta-model for timestep 0.875
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.0, 'logistic': 1.0, 'lstm': 0.0} (score: 0.124450)
# Training meta-model for timestep 0.88
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0969, 'nn': 0.0, 'logistic': 0.9031, 'lstm': 0.0} (score: 0.109669)
# Training meta-model for timestep 0.885
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2984, 'nn': 0.0, 'logistic': 0.7016, 'lstm': 0.0} (score: 0.126637)
# Training meta-model for timestep 0.89
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.4218, 'nn': 0.0, 'logistic': 0.5174, 'lstm': 0.0608} (score: 0.102273)
# Training meta-model for timestep 0.895
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1046, 'nn': 0.0, 'logistic': 0.8954, 'lstm': 0.0} (score: 0.090695)
# Training meta-model for timestep 0.9
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.5849, 'nn': 0.0342, 'logistic': 0.3809, 'lstm': 0.0} (score: 0.110279)
# Training meta-model for timestep 0.905
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0408, 'nn': 0.0, 'logistic': 0.9592, 'lstm': 0.0} (score: 0.109730)
# Training meta-model for timestep 0.91
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.0, 'logistic': 1.0, 'lstm': 0.0} (score: 0.118677)
# Training meta-model for timestep 0.915
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2578, 'nn': 0.0, 'logistic': 0.7422, 'lstm': 0.0} (score: 0.086537)
# Training meta-model for timestep 0.92
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.366, 'nn': 0.2374, 'logistic': 0.3233, 'lstm': 0.0733} (score: 0.100573)
# Training meta-model for timestep 0.925
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0036, 'nn': 0.0, 'logistic': 0.9964, 'lstm': 0.0} (score: 0.106395)
# Training meta-model for timestep 0.93
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1457, 'nn': 0.3013, 'logistic': 0.1801, 'lstm': 0.3729} (score: 0.095519)
# Training meta-model for timestep 0.935
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.346, 'nn': 0.0, 'logistic': 0.4422, 'lstm': 0.2118} (score: 0.096948)
# Training meta-model for timestep 0.94
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2893, 'nn': 0.0, 'logistic': 0.7107, 'lstm': 0.0} (score: 0.095171)
# Training meta-model for timestep 0.945
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.3434, 'nn': 0.1199, 'logistic': 0.4529, 'lstm': 0.0839} (score: 0.103543)
# Training meta-model for timestep 0.95
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.293, 'nn': 0.1535, 'logistic': 0.3031, 'lstm': 0.2503} (score: 0.101202)
# Training meta-model for timestep 0.955
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.0023, 'logistic': 0.8325, 'lstm': 0.1652} (score: 0.098110)
# Training meta-model for timestep 0.96
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.2362, 'nn': 0.2407, 'logistic': 0.1556, 'lstm': 0.3675} (score: 0.105424)
# Training meta-model for timestep 0.965
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.0152, 'logistic': 0.9848, 'lstm': 0.0} (score: 0.104453)
# Training meta-model for timestep 0.97
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.1931, 'logistic': 0.5651, 'lstm': 0.2417} (score: 0.088893)
# Training meta-model for timestep 0.975
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.3036, 'nn': 0.0, 'logistic': 0.3252, 'lstm': 0.3712} (score: 0.091096)
# Training meta-model for timestep 0.98
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.1689, 'nn': 0.1013, 'logistic': 0.3882, 'lstm': 0.3416} (score: 0.094010)
# Training meta-model for timestep 0.985
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0407, 'nn': 0.5165, 'logistic': 0.4428, 'lstm': 0.0} (score: 0.072748)
# Training meta-model for timestep 0.99
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.3516, 'logistic': 0.1952, 'lstm': 0.4533} (score: 0.077999)
# Training meta-model for timestep 0.995
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.0, 'nn': 0.1771, 'logistic': 0.2, 'lstm': 0.6229} (score: 0.076638)
# Training meta-model for timestep 1.0
# Training ensemble for this timestep...
# Optimizing ensemble weights for this timestep...
#   Optimized weights: {'xgboost': 0.5497, 'nn': 0.3736, 'logistic': 0.0, 'lstm': 0.0768} (score: 0.052746)

# %%
# Test accuracy and Brier score of model for each timestep on test data and plot
accuracies = []
brier_scores = []
timesteps = []
def brier_loss(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

for timestep, i in zip(ensemble_models, test_data.keys()):
    model = ensemble_models[timestep]
    # Convert test data to array
    y_test = np.array([row["label"] for row in test_data_seq[i]])
    X_test = np.array([row["rows"] for row in test_data_seq[i]])
    
    # Calculate accuracy
    accuracy = model.score(X_test, y_test)
    
    # Calculate Brier score
    y_test_pred_proba = model.predict_proba(X_test)[:, 1]  # Get probability predictions
    brier_score = brier_loss(y_test, y_test_pred_proba)
    
    print(f"Timestep {timestep:.2%}: Accuracy = {accuracy:.4f}, Brier Score = {brier_score:.4f}")
    accuracies.append(accuracy)
    brier_scores.append(brier_score)
    timesteps.append(timestep)

# Create subplots for both metrics
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Plot accuracy
ax1.plot(timesteps, accuracies, 'b-', linewidth=2, marker='o', markersize=3)
ax1.set_xlabel("Timestep")
ax1.set_ylabel("Accuracy")
ax1.set_title("Test Accuracy vs Timestep")
ax1.grid(True, alpha=0.3)
ax1.set_ylim([min(accuracies) * 0.95, max(accuracies) * 1.05])

# Plot Brier score
ax2.plot(timesteps, brier_scores, 'r-', linewidth=2, marker='s', markersize=3)
ax2.set_xlabel("Timestep")
ax2.set_ylabel("Brier Score")
ax2.set_title("Test Brier Score vs Timestep")
ax2.grid(True, alpha=0.3)
ax2.set_ylim([min(brier_scores) * 0.95, max(brier_scores) * 1.05])

plt.tight_layout()
plt.show()

# Print summary statistics
print(f"\nSummary Statistics:")
print(f"Average Accuracy: {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Average Brier Score: {np.mean(brier_scores):.4f} ± {np.std(brier_scores):.4f}")
print(f"Best Accuracy: {max(accuracies):.4f} at timestep {timesteps[np.argmax(accuracies)]:.2%}")
print(f"Best Brier Score: {min(brier_scores):.4f} at timestep {timesteps[np.argmin(brier_scores)]:.2%}")
# Out:
# Timestep 0.00%: Accuracy = 0.6576, Brier Score = 0.2238
# Timestep 0.50%: Accuracy = 0.6424, Brier Score = 0.2258
# Timestep 1.00%: Accuracy = 0.6589, Brier Score = 0.2207
# Timestep 1.50%: Accuracy = 0.6667, Brier Score = 0.2197
# Timestep 2.00%: Accuracy = 0.6464, Brier Score = 0.2210
# Timestep 2.50%: Accuracy = 0.6529, Brier Score = 0.2143
# Timestep 3.00%: Accuracy = 0.6521, Brier Score = 0.2197
# Timestep 3.50%: Accuracy = 0.6698, Brier Score = 0.2188
# Timestep 4.00%: Accuracy = 0.6657, Brier Score = 0.2196
# Timestep 4.50%: Accuracy = 0.6396, Brier Score = 0.2221
# Timestep 5.00%: Accuracy = 0.6892, Brier Score = 0.2138
# Timestep 5.50%: Accuracy = 0.6695, Brier Score = 0.2209
# Timestep 6.00%: Accuracy = 0.6656, Brier Score = 0.2166
# Timestep 6.50%: Accuracy = 0.6692, Brier Score = 0.2206
# Timestep 7.00%: Accuracy = 0.6579, Brier Score = 0.2265
# Timestep 7.50%: Accuracy = 0.6605, Brier Score = 0.2183
# Timestep 8.00%: Accuracy = 0.6721, Brier Score = 0.2114
# Timestep 8.50%: Accuracy = 0.6844, Brier Score = 0.2115
# Timestep 9.00%: Accuracy = 0.6681, Brier Score = 0.2189
# Timestep 9.50%: Accuracy = 0.6537, Brier Score = 0.2183
# Timestep 10.00%: Accuracy = 0.6652, Brier Score = 0.2176
# Timestep 10.50%: Accuracy = 0.6677, Brier Score = 0.2163
# Timestep 11.00%: Accuracy = 0.6510, Brier Score = 0.2194
# Timestep 11.50%: Accuracy = 0.6681, Brier Score = 0.2173
# Timestep 12.00%: Accuracy = 0.6734, Brier Score = 0.2178
# Timestep 12.50%: Accuracy = 0.6691, Brier Score = 0.2107
# Timestep 13.00%: Accuracy = 0.6651, Brier Score = 0.2161
# Timestep 13.50%: Accuracy = 0.6542, Brier Score = 0.2193
# Timestep 14.00%: Accuracy = 0.6333, Brier Score = 0.2147
# Timestep 14.50%: Accuracy = 0.6509, Brier Score = 0.2203
# Timestep 15.00%: Accuracy = 0.6622, Brier Score = 0.2091
# Timestep 15.50%: Accuracy = 0.6784, Brier Score = 0.2058
# Timestep 16.00%: Accuracy = 0.6490, Brier Score = 0.2186
# Timestep 16.50%: Accuracy = 0.6734, Brier Score = 0.2128
# Timestep 17.00%: Accuracy = 0.6776, Brier Score = 0.2022
# Timestep 17.50%: Accuracy = 0.6386, Brier Score = 0.2185
# Timestep 18.00%: Accuracy = 0.6785, Brier Score = 0.2063
# Timestep 18.50%: Accuracy = 0.6642, Brier Score = 0.2126
# Timestep 19.00%: Accuracy = 0.6667, Brier Score = 0.2093
# Timestep 19.50%: Accuracy = 0.6707, Brier Score = 0.2037
# Timestep 20.00%: Accuracy = 0.6787, Brier Score = 0.2025
# Timestep 20.50%: Accuracy = 0.6579, Brier Score = 0.2090
# Timestep 21.00%: Accuracy = 0.6842, Brier Score = 0.1973
# Timestep 21.50%: Accuracy = 0.6579, Brier Score = 0.2082
# Timestep 22.00%: Accuracy = 0.6600, Brier Score = 0.2102
# Timestep 22.50%: Accuracy = 0.6586, Brier Score = 0.2163
# Timestep 23.00%: Accuracy = 0.6691, Brier Score = 0.2040
# Timestep 23.50%: Accuracy = 0.6413, Brier Score = 0.2103
# Timestep 24.00%: Accuracy = 0.6536, Brier Score = 0.2088
# Timestep 24.50%: Accuracy = 0.6636, Brier Score = 0.2081
# Timestep 25.00%: Accuracy = 0.6700, Brier Score = 0.2045
# Timestep 25.50%: Accuracy = 0.6414, Brier Score = 0.2205
# Timestep 26.00%: Accuracy = 0.6614, Brier Score = 0.2039
# Timestep 26.50%: Accuracy = 0.6840, Brier Score = 0.1958
# Timestep 27.00%: Accuracy = 0.6953, Brier Score = 0.1955
# Timestep 27.50%: Accuracy = 0.6606, Brier Score = 0.2094
# Timestep 28.00%: Accuracy = 0.7012, Brier Score = 0.1944
# Timestep 28.50%: Accuracy = 0.6652, Brier Score = 0.2080
# Timestep 29.00%: Accuracy = 0.6746, Brier Score = 0.2045
# Timestep 29.50%: Accuracy = 0.6870, Brier Score = 0.1963
# Timestep 30.00%: Accuracy = 0.6777, Brier Score = 0.1979
# Timestep 30.50%: Accuracy = 0.6839, Brier Score = 0.1955
# Timestep 31.00%: Accuracy = 0.6772, Brier Score = 0.2056
# Timestep 31.50%: Accuracy = 0.7063, Brier Score = 0.1884
# Timestep 32.00%: Accuracy = 0.7003, Brier Score = 0.1931
# Timestep 32.50%: Accuracy = 0.6736, Brier Score = 0.2115
# Timestep 33.00%: Accuracy = 0.6730, Brier Score = 0.2034
# Timestep 33.50%: Accuracy = 0.6692, Brier Score = 0.1995
# Timestep 34.00%: Accuracy = 0.6829, Brier Score = 0.1982
# Timestep 34.50%: Accuracy = 0.6875, Brier Score = 0.1941
# Timestep 35.00%: Accuracy = 0.6910, Brier Score = 0.1907
# Timestep 35.50%: Accuracy = 0.6999, Brier Score = 0.1914
# Timestep 36.00%: Accuracy = 0.7346, Brier Score = 0.1778
# Timestep 36.50%: Accuracy = 0.6895, Brier Score = 0.1910
# Timestep 37.00%: Accuracy = 0.6987, Brier Score = 0.1898
# Timestep 37.50%: Accuracy = 0.7255, Brier Score = 0.1844
# Timestep 38.00%: Accuracy = 0.7251, Brier Score = 0.1786
# Timestep 38.50%: Accuracy = 0.7030, Brier Score = 0.1839
# Timestep 39.00%: Accuracy = 0.7183, Brier Score = 0.1798
# Timestep 39.50%: Accuracy = 0.7217, Brier Score = 0.1761
# Timestep 40.00%: Accuracy = 0.7258, Brier Score = 0.1781
# Timestep 40.50%: Accuracy = 0.7300, Brier Score = 0.1788
# Timestep 41.00%: Accuracy = 0.7239, Brier Score = 0.1779
# Timestep 41.50%: Accuracy = 0.7271, Brier Score = 0.1708
# Timestep 42.00%: Accuracy = 0.7288, Brier Score = 0.1774
# Timestep 42.50%: Accuracy = 0.7391, Brier Score = 0.1692
# Timestep 43.00%: Accuracy = 0.7493, Brier Score = 0.1712
# Timestep 43.50%: Accuracy = 0.7278, Brier Score = 0.1726
# Timestep 44.00%: Accuracy = 0.7339, Brier Score = 0.1798
# Timestep 44.50%: Accuracy = 0.7397, Brier Score = 0.1687
# Timestep 45.00%: Accuracy = 0.7391, Brier Score = 0.1744
# Timestep 45.50%: Accuracy = 0.7233, Brier Score = 0.1777
# Timestep 46.00%: Accuracy = 0.7351, Brier Score = 0.1778
# Timestep 46.50%: Accuracy = 0.7534, Brier Score = 0.1649
# Timestep 47.00%: Accuracy = 0.7581, Brier Score = 0.1648
# Timestep 47.50%: Accuracy = 0.7521, Brier Score = 0.1687
# Timestep 48.00%: Accuracy = 0.7425, Brier Score = 0.1665
# Timestep 48.50%: Accuracy = 0.7616, Brier Score = 0.1541
# Timestep 49.00%: Accuracy = 0.7719, Brier Score = 0.1510
# Timestep 49.50%: Accuracy = 0.7680, Brier Score = 0.1617
# Timestep 50.00%: Accuracy = 0.7623, Brier Score = 0.1556
# Timestep 50.50%: Accuracy = 0.7601, Brier Score = 0.1632
# Timestep 51.00%: Accuracy = 0.7581, Brier Score = 0.1577
# Timestep 51.50%: Accuracy = 0.7596, Brier Score = 0.1605
# Timestep 52.00%: Accuracy = 0.7772, Brier Score = 0.1510
# Timestep 52.50%: Accuracy = 0.7562, Brier Score = 0.1669
# Timestep 53.00%: Accuracy = 0.7449, Brier Score = 0.1704
# Timestep 53.50%: Accuracy = 0.7481, Brier Score = 0.1700
# Timestep 54.00%: Accuracy = 0.7564, Brier Score = 0.1656
# Timestep 54.50%: Accuracy = 0.7680, Brier Score = 0.1525
# Timestep 55.00%: Accuracy = 0.7534, Brier Score = 0.1656
# Timestep 55.50%: Accuracy = 0.7500, Brier Score = 0.1553
# Timestep 56.00%: Accuracy = 0.7478, Brier Score = 0.1642
# Timestep 56.50%: Accuracy = 0.7747, Brier Score = 0.1531
# Timestep 57.00%: Accuracy = 0.7634, Brier Score = 0.1541
# Timestep 57.50%: Accuracy = 0.7980, Brier Score = 0.1396
# Timestep 58.00%: Accuracy = 0.8009, Brier Score = 0.1401
# Timestep 58.50%: Accuracy = 0.7961, Brier Score = 0.1423
# Timestep 59.00%: Accuracy = 0.8017, Brier Score = 0.1484
# Timestep 59.50%: Accuracy = 0.7881, Brier Score = 0.1491
# Timestep 60.00%: Accuracy = 0.7920, Brier Score = 0.1427
# Timestep 60.50%: Accuracy = 0.7657, Brier Score = 0.1482
# Timestep 61.00%: Accuracy = 0.7843, Brier Score = 0.1495
# Timestep 61.50%: Accuracy = 0.7704, Brier Score = 0.1474
# Timestep 62.00%: Accuracy = 0.7847, Brier Score = 0.1428
# Timestep 62.50%: Accuracy = 0.7957, Brier Score = 0.1371
# Timestep 63.00%: Accuracy = 0.7929, Brier Score = 0.1413
# Timestep 63.50%: Accuracy = 0.8074, Brier Score = 0.1316
# Timestep 64.00%: Accuracy = 0.8094, Brier Score = 0.1380
# Timestep 64.50%: Accuracy = 0.7955, Brier Score = 0.1483
# Timestep 65.00%: Accuracy = 0.7741, Brier Score = 0.1479
# Timestep 65.50%: Accuracy = 0.7927, Brier Score = 0.1348
# Timestep 66.00%: Accuracy = 0.7737, Brier Score = 0.1456
# Timestep 66.50%: Accuracy = 0.7895, Brier Score = 0.1427
# Timestep 67.00%: Accuracy = 0.8027, Brier Score = 0.1358
# Timestep 67.50%: Accuracy = 0.7989, Brier Score = 0.1357
# Timestep 68.00%: Accuracy = 0.8068, Brier Score = 0.1307
# Timestep 68.50%: Accuracy = 0.7952, Brier Score = 0.1408
# Timestep 69.00%: Accuracy = 0.7835, Brier Score = 0.1447
# Timestep 69.50%: Accuracy = 0.8179, Brier Score = 0.1280
# Timestep 70.00%: Accuracy = 0.8051, Brier Score = 0.1343
# Timestep 70.50%: Accuracy = 0.8173, Brier Score = 0.1259
# Timestep 71.00%: Accuracy = 0.8178, Brier Score = 0.1338
# Timestep 71.50%: Accuracy = 0.8206, Brier Score = 0.1200
# Timestep 72.00%: Accuracy = 0.8161, Brier Score = 0.1351
# Timestep 72.50%: Accuracy = 0.8174, Brier Score = 0.1238
# Timestep 73.00%: Accuracy = 0.8210, Brier Score = 0.1310
# Timestep 73.50%: Accuracy = 0.8196, Brier Score = 0.1302
# Timestep 74.00%: Accuracy = 0.8207, Brier Score = 0.1249
# Timestep 74.50%: Accuracy = 0.8154, Brier Score = 0.1339
# Timestep 75.00%: Accuracy = 0.8345, Brier Score = 0.1175
# Timestep 75.50%: Accuracy = 0.8358, Brier Score = 0.1138
# Timestep 76.00%: Accuracy = 0.8347, Brier Score = 0.1195
# Timestep 76.50%: Accuracy = 0.8472, Brier Score = 0.1161
# Timestep 77.00%: Accuracy = 0.8425, Brier Score = 0.1146
# Timestep 77.50%: Accuracy = 0.8440, Brier Score = 0.1183
# Timestep 78.00%: Accuracy = 0.8543, Brier Score = 0.1111
# Timestep 78.50%: Accuracy = 0.8439, Brier Score = 0.1184
# Timestep 79.00%: Accuracy = 0.8498, Brier Score = 0.1163
# Timestep 79.50%: Accuracy = 0.8245, Brier Score = 0.1249
# Timestep 80.00%: Accuracy = 0.8426, Brier Score = 0.1189
# Timestep 80.50%: Accuracy = 0.8393, Brier Score = 0.1195
# Timestep 81.00%: Accuracy = 0.8195, Brier Score = 0.1203
# Timestep 81.50%: Accuracy = 0.8478, Brier Score = 0.1066
# Timestep 82.00%: Accuracy = 0.8338, Brier Score = 0.1134
# Timestep 82.50%: Accuracy = 0.8619, Brier Score = 0.0977
# Timestep 83.00%: Accuracy = 0.8391, Brier Score = 0.1168
# Timestep 83.50%: Accuracy = 0.8540, Brier Score = 0.1055
# Timestep 84.00%: Accuracy = 0.8484, Brier Score = 0.1123
# Timestep 84.50%: Accuracy = 0.8381, Brier Score = 0.1089
# Timestep 85.00%: Accuracy = 0.8540, Brier Score = 0.1007
# Timestep 85.50%: Accuracy = 0.8315, Brier Score = 0.1241
# Timestep 86.00%: Accuracy = 0.8499, Brier Score = 0.1058
# Timestep 86.50%: Accuracy = 0.8637, Brier Score = 0.0986
# Timestep 87.00%: Accuracy = 0.8585, Brier Score = 0.1043
# Timestep 87.50%: Accuracy = 0.8757, Brier Score = 0.0951
# Timestep 88.00%: Accuracy = 0.8668, Brier Score = 0.0990
# Timestep 88.50%: Accuracy = 0.8696, Brier Score = 0.0942
# Timestep 89.00%: Accuracy = 0.8736, Brier Score = 0.0955
# Timestep 89.50%: Accuracy = 0.8910, Brier Score = 0.0867
# Timestep 90.00%: Accuracy = 0.8608, Brier Score = 0.0981
# Timestep 90.50%: Accuracy = 0.8782, Brier Score = 0.0929
# Timestep 91.00%: Accuracy = 0.8887, Brier Score = 0.0868
# Timestep 91.50%: Accuracy = 0.8828, Brier Score = 0.0904
# Timestep 92.00%: Accuracy = 0.8632, Brier Score = 0.0954
# Timestep 92.50%: Accuracy = 0.8798, Brier Score = 0.0869
# Timestep 93.00%: Accuracy = 0.8658, Brier Score = 0.0938
# Timestep 93.50%: Accuracy = 0.8802, Brier Score = 0.0839
# Timestep 94.00%: Accuracy = 0.8863, Brier Score = 0.0793
# Timestep 94.50%: Accuracy = 0.8698, Brier Score = 0.0852
# Timestep 95.00%: Accuracy = 0.8710, Brier Score = 0.0908
# Timestep 95.50%: Accuracy = 0.8743, Brier Score = 0.0848
# Timestep 96.00%: Accuracy = 0.8820, Brier Score = 0.0856
# Timestep 96.50%: Accuracy = 0.8677, Brier Score = 0.0890
# Timestep 97.00%: Accuracy = 0.8991, Brier Score = 0.0748
# Timestep 97.50%: Accuracy = 0.8868, Brier Score = 0.0831
# Timestep 98.00%: Accuracy = 0.8897, Brier Score = 0.0825
# Timestep 98.50%: Accuracy = 0.8873, Brier Score = 0.0802
# Timestep 99.00%: Accuracy = 0.8974, Brier Score = 0.0749
# Timestep 99.50%: Accuracy = 0.8731, Brier Score = 0.0847
# Timestep 100.00%: Accuracy = 0.8895, Brier Score = 0.0767
# Summary Statistics:
# Average Accuracy: 0.7560 ± 0.0794
# Average Brier Score: 0.1608 ± 0.0452
# Best Accuracy: 0.8991 at timestep 97.00%
# Best Brier Score: 0.0748 at timestep 97.00%

# %%
model = ensemble_models[0.995]
features = ["relative_strength", "score_difference", "home_has_possession", "end.down", "end.distance", "end.yardsToEndzone",  "home_timeouts_left", "away_timeouts_left"]
data_point = [[0.5, -4, 1, 1, 1, 1, 1, 1], [0.5, -4, 1, 1, 1, 1, 1, 1], [0.5, -4, 1, 1, 1, 1, 1, 1], [0.5, -4, 1, 1, 1, 1, 1, 1], [0.5, -4, 1, 1, 1, 1, 1, 1]]
model.predict_proba(np.array([data_point]))

# %%
model = ensemble_models[0]
model.predict_proba(np.arange(110).reshape(2, 5, 11))
# Out:
# Model name:  xgboost
# (2, 5, 11)
# (2, 11)
# [[0.         1.        ]
#  [0.19230769 0.80769231]]
# Model name:  nn
# (2, 5, 11)
# (2, 11)
# [[1. 0.]
#  [1. 0.]]
# Model name:  logistic
# (2, 5, 11)
# (2, 11)
# [[0. 1.]
#  [0. 1.]]
# Model name:  lstm
# (2, 5, 11)
# [[0.79934996 0.20065005]
#  [0.7205218  0.27947822]]
# array([[0.48275698, 0.51724302],
#        [0.44681822, 0.55318178]])

# %%
# Write predictions to csv file
from process_data import write_predictions
write_predictions(ensemble_models, interpolated_dir, [2024, 2025], 4, features, replace_nan_val = 0, phat_b = "ensemble_phat_b_model")
# Out:
# Loading data for 2025
# Processed file:  game_401772888.csv
# Processed file:  game_401772863.csv
# Processed file:  game_401772877.csv
# Processed file:  game_401772730.csv
# Processed file:  game_401772724.csv
# Processed file:  game_401772718.csv
# Processed file:  game_401772917.csv
# Processed file:  game_401772903.csv
# Processed file:  game_401772902.csv
# Processed file:  game_401772916.csv
# Processed file:  game_401772719.csv
# Processed file:  game_401772725.csv
# Processed file:  game_401772731.csv
# Processed file:  game_401772876.csv
# Processed file:  game_401772862.csv
# Processed file:  game_401772889.csv
# Processed file:  game_401772848.csv
# Processed file:  game_401772874.csv
# Processed file:  game_401772860.csv
# Processed file:  game_401772727.csv
# Processed file:  game_401772733.csv
# Processed file:  game_401772928.csv
# Processed file:  game_401772900.csv
# Processed file:  game_401772914.csv
# Processed file:  game_401772915.csv
# Processed file:  game_401772901.csv
# Processed file:  game_401772929.csv
# Processed file:  game_401772732.csv
# Processed file:  game_401772726.csv
# Processed file:  game_401772861.csv
# Processed file:  game_401772875.csv
# Processed file:  game_401772849.csv
# Processed file:  game_401772871.csv
# Processed file:  game_401772865.csv
# Processed file:  game_401772859.csv
# Processed file:  game_401772722.csv
# Processed file:  game_401772736.csv
# Processed file:  game_401772905.csv
# Processed file:  game_401772911.csv
# Processed file:  game_401772939.csv
# Processed file:  game_401772938.csv
# Processed file:  game_401772910.csv
# Processed file:  game_401772904.csv
# Processed file:  game_401772737.csv
# Processed file:  game_401772723.csv
# Processed file:  game_401772858.csv
# Processed file:  game_401772694.csv
# Processed file:  game_401772864.csv
# Processed file:  game_401772870.csv
# Processed file:  game_401772899.csv
# Processed file:  game_401772866.csv
# Processed file:  game_401772872.csv
# Processed file:  game_401772735.csv
# Processed file:  game_401772721.csv
# Processed file:  game_401772912.csv
# Processed file:  game_401772906.csv
# Processed file:  game_401772907.csv
# Processed file:  game_401772913.csv
# Processed file:  game_401772720.csv
# Processed file:  game_401772734.csv
# Processed file:  game_401772873.csv
# Processed file:  game_401772867.csv
# Processed file:  game_401772898.csv
# Processed file:  game_401772633.csv
# Processed file:  game_401772828.csv
# Processed file:  game_401772800.csv
# Processed file:  game_401772814.csv
# Processed file:  game_401772753.csv
# Processed file:  game_401772747.csv
# Processed file:  game_401772948.csv
# Processed file:  game_401772790.csv
# Processed file:  game_401772784.csv
# Processed file:  game_401772960.csv
# Processed file:  game_401772961.csv
# Processed file:  game_401772785.csv
# Processed file:  game_401772791.csv
# Processed file:  game_401772949.csv
# Processed file:  game_401772746.csv
# Processed file:  game_401772752.csv
# Processed file:  game_401772815.csv
# Processed file:  game_401772801.csv
# Processed file:  game_401772829.csv
# Processed file:  game_401772632.csv
# Processed file:  game_401772630.csv
# Processed file:  game_401772817.csv
# Processed file:  game_401772803.csv
# Processed file:  game_401772744.csv
# Processed file:  game_401772750.csv
# Processed file:  game_401772778.csv
# Processed file:  game_401772787.csv
# Processed file:  game_401772793.csv
# Processed file:  game_401772963.csv
# Processed file:  game_401772962.csv
# Processed file:  game_401772792.csv
# Processed file:  game_401772786.csv
# Processed file:  game_401772779.csv
# Processed file:  game_401772751.csv
# Processed file:  game_401772745.csv
# Processed file:  game_401772802.csv
# Processed file:  game_401772816.csv
# Processed file:  game_401772631.csv
# Processed file:  game_401772635.csv
# Processed file:  game_401772621.csv
# Processed file:  game_401772812.csv
# Processed file:  game_401772806.csv
# Processed file:  game_401772769.csv
# Processed file:  game_401772741.csv
# Processed file:  game_401772755.csv
# Processed file:  game_401772966.csv
# Processed file:  game_401772782.csv
# Processed file:  game_401772796.csv
# Processed file:  game_401772797.csv
# Processed file:  game_401772783.csv
# Processed file:  game_401772967.csv
# Processed file:  game_401772754.csv
# Processed file:  game_401772740.csv
# Processed file:  game_401772768.csv
# Processed file:  game_401772807.csv
# Processed file:  game_401772813.csv
# Processed file:  game_401772634.csv
# Processed file:  game_401772622.csv
# Processed file:  game_401772636.csv
# Processed file:  game_401772805.csv
# Processed file:  game_401772811.csv
# Processed file:  game_401772839.csv
# Processed file:  game_401772756.csv
# Processed file:  game_401772742.csv
# Processed file:  game_401772965.csv
# Processed file:  game_401772795.csv
# Processed file:  game_401772959.csv
# Processed file:  game_401772781.csv
# Processed file:  game_401772780.csv
# Processed file:  game_401772958.csv
# Processed file:  game_401772794.csv
# Processed file:  game_401772964.csv
# Processed file:  game_401772970.csv
# Processed file:  game_401772743.csv
# Processed file:  game_401772757.csv
# Processed file:  game_401772838.csv
# Processed file:  game_401772810.csv
# Processed file:  game_401772804.csv
# Processed file:  game_401772612.csv
# Processed file:  game_401772809.csv
# Processed file:  game_401772821.csv
# Processed file:  game_401772835.csv
# Processed file:  game_401772772.csv
# Processed file:  game_401772766.csv
# Processed file:  game_401772969.csv
# Processed file:  game_401772955.csv
# Processed file:  game_401772941.csv
# Processed file:  game_401772799.csv
# Processed file:  game_401772798.csv
# Processed file:  game_401772940.csv
# Processed file:  game_401772954.csv
# Processed file:  game_401772968.csv
# Processed file:  game_401772767.csv
# Processed file:  game_401772773.csv
# Processed file:  game_401772834.csv
# Processed file:  game_401772820.csv
# Processed file:  game_401772808.csv
# Processed file:  game_401772613.csv
# Processed file:  game_401772836.csv
# Processed file:  game_401772822.csv
# Processed file:  game_401772765.csv
# Processed file:  game_401772771.csv
# Processed file:  game_401772759.csv
# Processed file:  game_401772942.csv
# Processed file:  game_401772956.csv
# Processed file:  game_401772957.csv
# Processed file:  game_401772943.csv
# Processed file:  game_401772758.csv
# Processed file:  game_401772770.csv
# Processed file:  game_401772764.csv
# Processed file:  game_401772823.csv
# Processed file:  game_401772837.csv
# Processed file:  game_401772833.csv
# Processed file:  game_401772827.csv
# Processed file:  game_401772748.csv
# Processed file:  game_401772760.csv
# Processed file:  game_401772774.csv
# Processed file:  game_401772947.csv
# Processed file:  game_401772953.csv
# Processed file:  game_401772952.csv
# Processed file:  game_401772946.csv
# Processed file:  game_401772775.csv
# Processed file:  game_401772761.csv
# Processed file:  game_401772749.csv
# Processed file:  game_401772826.csv
# Processed file:  game_401772832.csv
# Processed file:  game_401772824.csv
# Processed file:  game_401772830.csv
# Processed file:  game_401772818.csv
# Processed file:  game_401772777.csv
# Processed file:  game_401772763.csv
# Processed file:  game_401772950.csv
# Processed file:  game_401772788.csv
# Processed file:  game_401772944.csv
# Processed file:  game_401772945.csv
# Processed file:  game_401772789.csv
# Processed file:  game_401772951.csv
# Processed file:  game_401772762.csv
# Processed file:  game_401772776.csv
# Processed file:  game_401772819.csv
# Processed file:  game_401772831.csv
# Processed file:  game_401772825.csv
# Processed file:  game_401772881.csv
# Processed file:  game_401772895.csv
# Processed file:  game_401772842.csv
# Processed file:  game_401772856.csv
# Processed file:  game_401772711.csv
# Processed file:  game_401772739.csv
# Processed file:  game_401772936.csv
# Processed file:  game_401772922.csv
# Processed file:  game_401772923.csv
# Processed file:  game_401772937.csv
# Processed file:  game_401772738.csv
# Processed file:  game_401772710.csv
# Processed file:  game_401772857.csv
# Processed file:  game_401772843.csv
# Processed file:  game_401772894.csv
# Processed file:  game_401772880.csv
# Processed file:  game_401772896.csv
# Processed file:  game_401772882.csv
# Processed file:  game_401772869.csv
# Processed file:  game_401772855.csv
# Processed file:  game_401772841.csv
# Processed file:  game_401772909.csv
# Processed file:  game_401772921.csv
# Processed file:  game_401772935.csv
# Processed file:  game_401772510.csv
# Processed file:  game_401772934.csv
# Processed file:  game_401772920.csv
# Processed file:  game_401772908.csv
# Processed file:  game_401772840.csv
# Processed file:  game_401772854.csv
# Processed file:  game_401772868.csv
# Processed file:  game_401772883.csv
# Processed file:  game_401772897.csv
# Processed file:  game_401772893.csv
# Processed file:  game_401772887.csv
# Processed file:  game_401772850.csv
# Processed file:  game_401772844.csv
# Processed file:  game_401772878.csv
# Processed file:  game_401772717.csv
# Processed file:  game_401772924.csv
# Processed file:  game_401772930.csv
# Processed file:  game_401772918.csv
# Processed file:  game_401772919.csv
# Processed file:  game_401772931.csv
# Processed file:  game_401772925.csv
# Processed file:  game_401772716.csv
# Processed file:  game_401772879.csv
# Processed file:  game_401772845.csv
# Processed file:  game_401772851.csv
# Processed file:  game_401772886.csv
# Processed file:  game_401772892.csv
# Processed file:  game_401772884.csv
# Processed file:  game_401772890.csv
# Processed file:  game_401772847.csv
# Processed file:  game_401772853.csv
# Processed file:  game_401772728.csv
# Processed file:  game_401772714.csv
# Processed file:  game_401772933.csv
# Processed file:  game_401772927.csv
# Processed file:  game_401772926.csv
# Processed file:  game_401772932.csv
# Processed file:  game_401772715.csv
# Processed file:  game_401772729.csv
# Processed file:  game_401772852.csv
# Processed file:  game_401772846.csv
# Processed file:  game_401772891.csv
# Processed file:  game_401772885.csv
# Loading data for 2024
# Processed file:  game_401671629.csv
# Processed file:  game_401671601.csv
# Processed file:  game_401671826.csv
# Processed file:  game_401671832.csv
# Processed file:  game_401671749.csv
# Processed file:  game_401671775.csv
# Processed file:  game_401671761.csv
# Processed file:  game_401671760.csv
# Processed file:  game_401671774.csv
# Processed file:  game_401671748.csv
# Processed file:  game_401671833.csv
# Processed file:  game_401671827.csv
# Processed file:  game_401671600.csv
# Processed file:  game_401671628.csv
# Processed file:  game_401671616.csv
# Processed file:  game_401671831.csv
# Processed file:  game_401671825.csv
# Processed file:  game_401671819.csv
# Processed file:  game_401671762.csv
# Processed file:  game_401671776.csv
# Processed file:  game_401671789.csv
# Processed file:  game_401671788.csv
# Processed file:  game_401671777.csv
# Processed file:  game_401671763.csv
# Processed file:  game_401671818.csv
# Processed file:  game_401671824.csv
# Processed file:  game_401671830.csv
# Processed file:  game_401671617.csv
# Processed file:  game_401671808.csv
# Processed file:  game_401671834.csv
# Processed file:  game_401671820.csv
# Processed file:  game_401671767.csv
# Processed file:  game_401671773.csv
# Processed file:  game_401671798.csv
# Processed file:  game_401671799.csv
# Processed file:  game_401671772.csv
# Processed file:  game_401671766.csv
# Processed file:  game_401671821.csv
# Processed file:  game_401671835.csv
# Processed file:  game_401671809.csv
# Processed file:  game_401671638.csv
# Processed file:  game_401671823.csv
# Processed file:  game_401671837.csv
# Processed file:  game_401671599.csv
# Processed file:  game_401671770.csv
# Processed file:  game_401671764.csv
# Processed file:  game_401671758.csv
# Processed file:  game_401671759.csv
# Processed file:  game_401671765.csv
# Processed file:  game_401671771.csv
# Processed file:  game_401671836.csv
# Processed file:  game_401671822.csv
# Processed file:  game_401671639.csv
# Processed file:  game_401671662.csv
# Processed file:  game_401671676.csv
# Processed file:  game_401671845.csv
# Processed file:  game_401671851.csv
# Processed file:  game_401671689.csv
# Processed file:  game_401671716.csv
# Processed file:  game_401671702.csv
# Processed file:  game_401671703.csv
# Processed file:  game_401671717.csv
# Processed file:  game_401671688.csv
# Processed file:  game_401671850.csv
# Processed file:  game_401671844.csv
# Processed file:  game_401671677.csv
# Processed file:  game_401671663.csv
# Processed file:  game_401671649.csv
# Processed file:  game_401671675.csv
# Processed file:  game_401671661.csv
# Processed file:  game_401671852.csv
# Processed file:  game_401671846.csv
# Processed file:  game_401671729.csv
# Processed file:  game_401671701.csv
# Processed file:  game_401671715.csv
# Processed file:  game_401671714.csv
# Processed file:  game_401671700.csv
# Processed file:  game_401671728.csv
# Processed file:  game_401671489.csv
# Processed file:  game_401671847.csv
# Processed file:  game_401671853.csv
# Processed file:  game_401671660.csv
# Processed file:  game_401671674.csv
# Processed file:  game_401671648.csv
# Processed file:  game_401671670.csv
# Processed file:  game_401671664.csv
# Processed file:  game_401671658.csv
# Processed file:  game_401671857.csv
# Processed file:  game_401671843.csv
# Processed file:  game_401671704.csv
# Processed file:  game_401671710.csv
# Processed file:  game_401671738.csv
# Processed file:  game_401671739.csv
# Processed file:  game_401671711.csv
# Processed file:  game_401671705.csv
# Processed file:  game_401671842.csv
# Processed file:  game_401671856.csv
# Processed file:  game_401671659.csv
# Processed file:  game_401671665.csv
# Processed file:  game_401671671.csv
# Processed file:  game_401671667.csv
# Processed file:  game_401671673.csv
# Processed file:  game_401671868.csv
# Processed file:  game_401671840.csv
# Processed file:  game_401671698.csv
# Processed file:  game_401671854.csv
# Processed file:  game_401671713.csv
# Processed file:  game_401671707.csv
# Processed file:  game_401671706.csv
# Processed file:  game_401671712.csv
# Processed file:  game_401671855.csv
# Processed file:  game_401671699.csv
# Processed file:  game_401671841.csv
# Processed file:  game_401671869.csv
# Processed file:  game_401671672.csv
# Processed file:  game_401671666.csv
# Processed file:  game_401671643.csv
# Processed file:  game_401671657.csv
# Processed file:  game_401671864.csv
# Processed file:  game_401671870.csv
# Processed file:  game_401671858.csv
# Processed file:  game_401671680.csv
# Processed file:  game_401671694.csv
# Processed file:  game_401671737.csv
# Processed file:  game_401671723.csv
# Processed file:  game_401671722.csv
# Processed file:  game_401671736.csv
# Processed file:  game_401671695.csv
# Processed file:  game_401671681.csv
# Processed file:  game_401671859.csv
# Processed file:  game_401671871.csv
# Processed file:  game_401671865.csv
# Processed file:  game_401671656.csv
# Processed file:  game_401671642.csv
# Processed file:  game_401671668.csv
# Processed file:  game_401671654.csv
# Processed file:  game_401671640.csv
# Processed file:  game_401671873.csv
# Processed file:  game_401671867.csv
# Processed file:  game_401671697.csv
# Processed file:  game_401671683.csv
# Processed file:  game_401671495.csv
# Processed file:  game_401671708.csv
# Processed file:  game_401671720.csv
# Processed file:  game_401671734.csv
# Processed file:  game_401671735.csv
# Processed file:  game_401671721.csv
# Processed file:  game_401671709.csv
# Processed file:  game_401671494.csv
# Processed file:  game_401671682.csv
# Processed file:  game_401671696.csv
# Processed file:  game_401671866.csv
# Processed file:  game_401671872.csv
# Processed file:  game_401671641.csv
# Processed file:  game_401671655.csv
# Processed file:  game_401671669.csv
# Processed file:  game_401671651.csv
# Processed file:  game_401671645.csv
# Processed file:  game_401671679.csv
# Processed file:  game_401671692.csv
# Processed file:  game_401671686.csv
# Processed file:  game_401671876.csv
# Processed file:  game_401671862.csv
# Processed file:  game_401671490.csv
# Processed file:  game_401671725.csv
# Processed file:  game_401671731.csv
# Processed file:  game_401671719.csv
# Processed file:  game_401671718.csv
# Processed file:  game_401671730.csv
# Processed file:  game_401671724.csv
# Processed file:  game_401671491.csv
# Processed file:  game_401671863.csv
# Processed file:  game_401671877.csv
# Processed file:  game_401671687.csv
# Processed file:  game_401671693.csv
# Processed file:  game_401671678.csv
# Processed file:  game_401671644.csv
# Processed file:  game_401671650.csv
# Processed file:  game_401671646.csv
# Processed file:  game_401671652.csv
# Processed file:  game_401671685.csv
# Processed file:  game_401671849.csv
# Processed file:  game_401671691.csv
# Processed file:  game_401671861.csv
# Processed file:  game_401671875.csv
# Processed file:  game_401671493.csv
# Processed file:  game_401671732.csv
# Processed file:  game_401671726.csv
# Processed file:  game_401671727.csv
# Processed file:  game_401671733.csv
# Processed file:  game_401671492.csv
# Processed file:  game_401671874.csv
# Processed file:  game_401671860.csv
# Processed file:  game_401671690.csv
# Processed file:  game_401671848.csv
# Processed file:  game_401671684.csv
# Processed file:  game_401671653.csv
# Processed file:  game_401671647.csv
# Processed file:  game_401671620.csv
# Processed file:  game_401671634.csv
# Processed file:  game_401671807.csv
# Processed file:  game_401671813.csv
# Processed file:  game_401671768.csv
# Processed file:  game_401671754.csv
# Processed file:  game_401671740.csv
# Processed file:  game_401671797.csv
# Processed file:  game_401671783.csv
# Processed file:  game_401671782.csv
# Processed file:  game_401671796.csv
# Processed file:  game_401671741.csv
# Processed file:  game_401671755.csv
# Processed file:  game_401671769.csv
# Processed file:  game_401671812.csv
# Processed file:  game_401671806.csv
# Processed file:  game_401671635.csv
# Processed file:  game_401671621.csv
# Processed file:  game_401671637.csv
# Processed file:  game_401671623.csv
# Processed file:  game_401671810.csv
# Processed file:  game_401671804.csv
# Processed file:  game_401671838.csv
# Processed file:  game_401671743.csv
# Processed file:  game_401671757.csv
# Processed file:  game_401671780.csv
# Processed file:  game_401671794.csv
# Processed file:  game_401671795.csv
# Processed file:  game_401671781.csv
# Processed file:  game_401671756.csv
# Processed file:  game_401671742.csv
# Processed file:  game_401671839.csv
# Processed file:  game_401671805.csv
# Processed file:  game_401671811.csv
# Processed file:  game_401671622.csv
# Processed file:  game_401671636.csv
# Processed file:  game_401671632.csv
# Processed file:  game_401671626.csv
# Processed file:  game_401671829.csv
# Processed file:  game_401671815.csv
# Processed file:  game_401671801.csv
# Processed file:  game_401671746.csv
# Processed file:  game_401671752.csv
# Processed file:  game_401671785.csv
# Processed file:  game_401671791.csv
# Processed file:  game_401671790.csv
# Processed file:  game_401671784.csv
# Processed file:  game_401671753.csv
# Processed file:  game_401671747.csv
# Processed file:  game_401671800.csv
# Processed file:  game_401671814.csv
# Processed file:  game_401671828.csv
# Processed file:  game_401671627.csv
# Processed file:  game_401671633.csv
# Processed file:  game_401671625.csv
# Processed file:  game_401671631.csv
# Processed file:  game_401671619.csv
# Processed file:  game_401671802.csv
# Processed file:  game_401671816.csv
# Processed file:  game_401671751.csv
# Processed file:  game_401671745.csv
# Processed file:  game_401671779.csv
# Processed file:  game_401671792.csv
# Processed file:  game_401671786.csv
# Processed file:  game_401671787.csv
# Processed file:  game_401671793.csv
# Processed file:  game_401671778.csv
# Processed file:  game_401671744.csv
# Processed file:  game_401671750.csv
# Processed file:  game_401671817.csv
# Processed file:  game_401671803.csv
# Processed file:  game_401671618.csv
# Processed file:  game_401671630.csv
# Processed file:  game_401671624.csv

# %%
import os
import shutil

# Define the ancestor directory and the parent directory
src_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
dest_dir = os.path.abspath(os.path.join(os.getcwd(), "../../"))

# Specify a list of directories to copy
sources = [
    os.path.join(src_dir, "dataset_interpolated_fixed", "2024"),
    os.path.join(src_dir, "dataset_interpolated_fixed", "2025")
]

destination = os.path.join(dest_dir, "test_9", "ensemble_model")

# Iterate through each source and copy
for source in sources:
    if os.path.exists(source):
        # Extract the year/folder name from source
        if os.path.isdir(source):
            shutil.copytree(source, destination, dirs_exist_ok=True)
        else:
            shutil.copy2(source, destination)
        print(f"Copied '{source}' to '{destination}'")
    else:
        print(f"Source '{source}' does not exist")
# Out:
# Copied '/Users/aly/Documents/University_of_Waterloo/Winter 2025/Research/code/NFL/ML/dataset_interpolated_fixed/2024' to '/Users/aly/Documents/University_of_Waterloo/Winter 2025/Research/code/NFL/test_9/ensemble_model'
# Copied '/Users/aly/Documents/University_of_Waterloo/Winter 2025/Research/code/NFL/ML/dataset_interpolated_fixed/2025' to '/Users/aly/Documents/University_of_Waterloo/Winter 2025/Research/code/NFL/test_9/ensemble_model'
